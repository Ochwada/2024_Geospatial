# %% [markdown]
# # DataFrames 101
#
# ## Selecting subsets

# %%
# %matplotlib inline
import geopandas as gpd

# %% [markdown]
# ## Referencing series (columns, fields, series, attributes, properties)
#
# Method 1 - dot notation
#
#     df.fieldname
#
# Method 2 - bracket notation
#
#     df['fieldname']
#
# We will be using bracket notation for this course.  I think dot natation is confusing because it could be misinterpreted as a method or property.  Also you can't use variables to refer to column names which limit their usefulness.

# %%
raptors = gpd.read_file("data/Raptor_Nests.shp")
raptors.head()
# Out:
#    postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0       361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1       362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2         1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3         2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4         3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
#
#       recentstat  Nest_ID                     geometry
# 0  INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1  INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 2  INACTIVE NEST        1  POINT (-105.50223 38.68694)
# 3  INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4    ACTIVE NEST        3  POINT (-104.74466 40.18571)

# %%
raptors.recentspec
# Out:
# 0        Swainsons Hawk
# 1        Swainsons Hawk
# 2        Swainsons Hawk
# 3        Swainsons Hawk
# 4        Swainsons Hawk
#              ...
# 874       Red-tail Hawk
# 875       Red-tail Hawk
# 876    Northern Harrier
# 877                SWHA
# 878                RTHA
# Name: recentspec, Length: 879, dtype: object

# %%
raptors['recentspec']
# Out:
# 0        Swainsons Hawk
# 1        Swainsons Hawk
# 2        Swainsons Hawk
# 3        Swainsons Hawk
# 4        Swainsons Hawk
#              ...
# 874       Red-tail Hawk
# 875       Red-tail Hawk
# 876    Northern Harrier
# 877                SWHA
# 878                RTHA
# Name: recentspec, Length: 879, dtype: object

# %% [markdown]
# You can refer to a column using a variable with bracket notation

# %%
fldname = 'recentspec'
raptors[fldname]
# Out:
# 0        Swainsons Hawk
# 1        Swainsons Hawk
# 2        Swainsons Hawk
# 3        Swainsons Hawk
# 4        Swainsons Hawk
#              ...
# 874       Red-tail Hawk
# 875       Red-tail Hawk
# 876    Northern Harrier
# 877                SWHA
# 878                RTHA
# Name: recentspec, Length: 879, dtype: object

# %% [markdown]
# But you can't use a variable with dot notation

# %% [markdown]
# You can get a list of column names using the dataframes columns attribute

# %%
raptors.columns
# Out:
# Index(['postgis_fi', 'lat_y_dd', 'long_x_dd', 'lastsurvey', 'recentspec',
#        'recentstat', 'Nest_ID', 'geometry'],
#       dtype='object')

# %%
raptors.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  876 non-null    float64
#  1   lat_y_dd    877 non-null    float64
#  2   long_x_dd   877 non-null    float64
#  3   lastsurvey  878 non-null    object
#  4   recentspec  879 non-null    object
#  5   recentstat  879 non-null    object
#  6   Nest_ID     879 non-null    int64
#  7   geometry    879 non-null    geometry
# dtypes: float64(3), geometry(1), int64(1), object(3)
# memory usage: 55.1+ KB

# %% [markdown]
# And knowing this we can loop through the columns and print out the unique values for all string columns that have less than 20 unique values with just a few lines of code

# %%
for fld in raptors.columns:
    if raptors[fld].dtype == 'object' and raptors[fld].nunique()<20:
        print(raptors[fld].name, raptors[fld].unique())
# Out:
# recentspec ['Swainsons Hawk' 'Red-tail Hawk' 'Northern Harrier' 'SWHA' 'RTHA']
# recentstat ['INACTIVE NEST' 'ACTIVE NEST' 'FLEDGED NEST' 'COULD NOT SEE NEST']

# %% [markdown]
# ### Subset of columns

# %%
raptors.head()
# Out:
#    postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0       361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1       362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2         1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3         2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4         3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
#
#       recentstat  Nest_ID                     geometry
# 0  INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1  INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 2  INACTIVE NEST        1  POINT (-105.50223 38.68694)
# 3  INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4    ACTIVE NEST        3  POINT (-104.74466 40.18571)

# %%
raptor_cols = raptors[["Nest_ID", "recentspec", "recentstat", "lastsurvey", 'geometry']]
raptor_cols.tail()
# Out:
#      Nest_ID        recentspec     recentstat  lastsurvey  \
# 874      911     Red-tail Hawk  INACTIVE NEST  2015-08-18
# 875      912     Red-tail Hawk  INACTIVE NEST  2015-09-01
# 876     9991  Northern Harrier  INACTIVE NEST  2020-05-08
# 877     1001              SWHA  INACTIVE NEST  2020-05-05
# 878     1002              RTHA   FLEDGED NEST        None
#
#                         geometry
# 874  POINT (-104.98394 40.00297)
# 875  POINT (-104.84766 39.96975)
# 876  POINT (-104.95039 40.24432)
# 877  POINT (-104.94502 40.24443)
# 878  POINT (-104.93717 40.24387)

# %%
# %whos
# Out:
# Variable      Type            Data/Info
# ---------------------------------------
# fld           str             geometry
# fldname       str             recentspec
# gpd           module          <module 'geopandas' from <...>s/geopandas/__init__.py'>
# raptor_cols   GeoDataFrame         Nest_ID        recen<...>n\n[879 rows x 5 columns]
# raptors       GeoDataFrame         postgis_fi   lat_y_d<...>n\n[879 rows x 8 columns]

# %% [markdown]
# ### Subset by attributes (multiple condition)
#
# * Wrap each condition in parentheses
# * Use & and | rather than **and** and **or**

# %%
raptors[(raptors['recentstat']=='ACTIVE NEST') | (raptors['recentspec']=='Swainsons Hawk')]
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2           1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
# ..          ...        ...         ...         ...             ...
# 860       897.0  40.417061 -104.800156  2015-07-07   Red-tail Hawk
# 862       899.0  40.187254 -105.005608  2015-07-10  Swainsons Hawk
# 863       900.0  40.169258 -104.889567  2015-07-13  Swainsons Hawk
# 865       902.0  40.045190 -104.727397  2015-08-14  Swainsons Hawk
# 872       909.0  39.999138 -104.899116  2015-08-18  Swainsons Hawk
#
#         recentstat  Nest_ID                     geometry
# 0    INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1    INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 2    INACTIVE NEST        1  POINT (-105.50223 38.68694)
# 3    INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4      ACTIVE NEST        3  POINT (-104.74466 40.18571)
# ..             ...      ...                          ...
# 860    ACTIVE NEST      897  POINT (-104.72328 40.47858)
# 862  INACTIVE NEST      899  POINT (-104.97637 40.14121)
# 863  INACTIVE NEST      900  POINT (-104.90353 40.23230)
# 865  INACTIVE NEST      902  POINT (-104.63442 40.00987)
# 872  INACTIVE NEST      909  POINT (-104.91958 40.00116)
#
# [519 rows x 8 columns]

# %% [markdown]
# ### Subset by coordinates
#
# bounding box using python slice notation

# %%
raptors.plot()
# Out:
# <Axes: >

# %%
raptors.cx[:-104.5, 39.5:].plot()
# Out:
# <Axes: >

# %%
raptors = raptors.cx[:-104.3, 39.5:40.6]
raptors.plot()
# Out:
# <Axes: >

# %%
y_min=raptors["lat_y_dd"].min()
y_max=raptors["lat_y_dd"].max()
y_step = (y_max-y_min)/3
for i in range(3):
    raptors.cx[:, y_min + i*y_step:y_min + (i+1)*y_step].plot()

# %%
y_min=raptors["lat_y_dd"].min()
y_max=raptors["lat_y_dd"].max()
y_step = (y_max-y_min)/3
x_min=raptors["long_x_dd"].min()
x_max=raptors["long_x_dd"].max()
x_step = (x_max-x_min)/3
for y in range(3):
    for x in range(3):
        raptors.cx[x_min + x*x_step:x_min + (x+1)*x_step, y_min + y*y_step:y_min + (y+1)*y_step].plot()

# %% [markdown]
# ## Referencing cell values with loc, iloc, and at
#
# ### loc - referencing by column and row index values

# %%
raptors.columns
# Out:
# Index(['postgis_fi', 'lat_y_dd', 'long_x_dd', 'lastsurvey', 'recentspec',
#        'recentstat', 'Nest_ID', 'geometry'],
#       dtype='object')

# %%
raptors.index
# Out:
# Index([  0,   1,   3,   4,   5,   6,   7,   8,   9,  10,
#        ...
#        869, 870, 871, 872, 873, 874, 875, 876, 877, 878],
#       dtype='int64', length=862)

# %%
raptors
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16    Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16    Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06    Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03    Swainsons Hawk
# 5           4.0  40.217638 -104.779386  2011-01-06     Red-tail Hawk
# ..          ...        ...         ...         ...               ...
# 874       911.0  40.006950 -104.894370  2015-08-18     Red-tail Hawk
# 875       912.0  39.998876 -104.900128  2015-09-01     Red-tail Hawk
# 876         NaN        NaN         NaN  2020-05-08  Northern Harrier
# 877         NaN        NaN         NaN  2020-05-05              SWHA
# 878         NaN  40.243865 -104.937170        None              RTHA
#
#         recentstat  Nest_ID                     geometry
# 0    INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1    INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 3    INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4      ACTIVE NEST        3  POINT (-104.74466 40.18571)
# 5     FLEDGED NEST        4  POINT (-104.79963 40.15712)
# ..             ...      ...                          ...
# 874  INACTIVE NEST      911  POINT (-104.98394 40.00297)
# 875  INACTIVE NEST      912  POINT (-104.84766 39.96975)
# 876  INACTIVE NEST     9991  POINT (-104.95039 40.24432)
# 877  INACTIVE NEST     1001  POINT (-104.94502 40.24443)
# 878   FLEDGED NEST     1002  POINT (-104.93717 40.24387)
#
# [862 rows x 8 columns]

# %%
raptors.loc[877, 'lastsurvey']
# Out:
# '2020-05-05'

# %%
raptors.loc[3:10, 'lastsurvey':'Nest_ID']
# Out:
#     lastsurvey      recentspec     recentstat  Nest_ID
# 3   2011-01-06  Swainsons Hawk  INACTIVE NEST        2
# 4   2014-07-03  Swainsons Hawk    ACTIVE NEST        3
# 5   2011-01-06   Red-tail Hawk   FLEDGED NEST        4
# 6   2011-01-06  Swainsons Hawk  INACTIVE NEST        5
# 7   2011-01-06  Swainsons Hawk    ACTIVE NEST        6
# 8   2011-01-06  Swainsons Hawk   FLEDGED NEST        7
# 9   2011-01-06   Red-tail Hawk  INACTIVE NEST        8
# 10  2011-01-06  Swainsons Hawk   FLEDGED NEST        9

# %%
raptors.loc[[10, 3, 5], ['Nest_ID', 'lat_y_dd', 'recentspec']]
# Out:
#     Nest_ID   lat_y_dd      recentspec
# 10        9  40.000189  Swainsons Hawk
# 3         2  40.309574  Swainsons Hawk
# 5         4  40.217638   Red-tail Hawk

# %%
for row in raptors.index:
    for col in raptors.columns:
        print(row, col, raptors.loc[row, col])
# Out:
# 0 postgis_fi 361.0
# 0 lat_y_dd 40.267502
# 0 long_x_dd -104.870872
# 0 lastsurvey 2012-03-16
# 0 recentspec Swainsons Hawk
# 0 recentstat INACTIVE NEST
# 0 Nest_ID 361
# 0 geometry POINT (-104.79595 40.29891)
# 1 postgis_fi 362.0
# 1 lat_y_dd 40.264321
# 1 long_x_dd -104.860255
# 1 lastsurvey 2012-03-16
# 1 recentspec Swainsons Hawk
# 1 recentstat INACTIVE NEST
# 1 Nest_ID 362
# 1 geometry POINT (-104.78897 40.22089)
# 3 postgis_fi 2.0
# 3 lat_y_dd 40.309574
# 3 long_x_dd -104.932604
# 3 lastsurvey 2011-01-06
# 3 recentspec Swainsons Hawk
# 3 recentstat INACTIVE NEST
# 3 Nest_ID 2
# 3 geometry POINT (-104.84889 40.35215)
# 4 postgis_fi 3.0
# 4 lat_y_dd 40.219343
# 4 long_x_dd -104.729246
# 4 lastsurvey 2014-07-03
# 4 recentspec Swainsons Hawk
# 4 recentstat ACTIVE NEST
# 4 Nest_ID 3
# 4 geometry POINT (-104.74466 40.18571)
# 5 postgis_fi 4.0
# 5 lat_y_dd 40.217638
# 5 long_x_dd -104.779386
# 5 lastsurvey 2011-01-06
# 5 recentspec Red-tail Hawk
# 5 recentstat FLEDGED NEST
# 5 Nest_ID 4
# 5 geometry POINT (-104.79963 40.15712)
# 6 postgis_fi 5.0
# 6 lat_y_dd 40.271203
# 6 long_x_dd -104.740819
# 6 lastsurvey 2011-01-06
# 6 recentspec Swainsons Hawk
# 6 recentstat INACTIVE NEST
# 6 Nest_ID 5
# 6 geometry POINT (-104.6679 40.26382)
# 7 postgis_fi 6.0
# 7 lat_y_dd 40.357587
# 7 long_x_dd -104.737632
# 7 lastsurvey 2011-01-06
# 7 recentspec Swainsons Hawk
# 7 recentstat ACTIVE NEST
# 7 Nest_ID 6
# 7 geometry POINT (-104.67679 40.30686)
# 8 postgis_fi 7.0
# 8 lat_y_dd 40.35966
# 8 long_x_dd -104.730698
# 8 lastsurvey 2011-01-06
# 8 recentspec Swainsons Hawk
# 8 recentstat FLEDGED NEST
# 8 Nest_ID 7
# 8 geometry POINT (-104.69146 40.3136)
# 9 postgis_fi 8.0
# 9 lat_y_dd 40.358919
# 9 long_x_dd -104.725179
# 9 lastsurvey 2011-01-06
# 9 recentspec Red-tail Hawk
# 9 recentstat INACTIVE NEST
# 9 Nest_ID 8
# 9 geometry POINT (-104.67825 40.41094)
# 10 postgis_fi 9.0
# 10 lat_y_dd 40.000189
# 10 long_x_dd -104.860463
# 10 lastsurvey 2011-01-06
# 10 recentspec Swainsons Hawk
# 10 recentstat FLEDGED NEST
# 10 Nest_ID 9
# 10 geometry POINT (-104.78548 39.96439)
# 11 postgis_fi 10.0
# 11 lat_y_dd 40.198163
# 11 long_x_dd -104.918726
# 11 lastsurvey 2011-01-06
# 11 recentspec Swainsons Hawk
# 11 recentstat INACTIVE NEST
# 11 Nest_ID 10
# 11 geometry POINT (-104.99879 40.20531)
# 12 postgis_fi 11.0
# 12 lat_y_dd 40.033635
# 12 long_x_dd -104.833716
# 12 lastsurvey 2011-01-06
# 12 recentspec Red-tail Hawk
# 12 recentstat INACTIVE NEST
# 12 Nest_ID 11
# 12 geometry POINT (-104.80748 40.03194)
# 13 postgis_fi 12.0
# 13 lat_y_dd 40.327655
# 13 long_x_dd -104.574845
# 13 lastsurvey 2011-01-06
# 13 recentspec Red-tail Hawk
# 13 recentstat INACTIVE NEST
# 13 Nest_ID 12
# 13 geometry POINT (-104.63061 40.32023)
# 14 postgis_fi 13.0
# 14 lat_y_dd 40.220769
# 14 long_x_dd -104.731024
# 14 lastsurvey 2014-07-24
# 14 recentspec Swainsons Hawk
# 14 recentstat INACTIVE NEST
# 14 Nest_ID 13
# 14 geometry POINT (-104.7683 40.22536)
# 15 postgis_fi 14.0
# 15 lat_y_dd 40.12669
# 15 long_x_dd -105.020896
# 15 lastsurvey 2011-01-06
# 15 recentspec Swainsons Hawk
# 15 recentstat ACTIVE NEST
# 15 Nest_ID 14
# 15 geometry POINT (-105.05943 40.19046)
# 16 postgis_fi 15.0
# 16 lat_y_dd 40.225065
# 16 long_x_dd -104.627044
# 16 lastsurvey 2011-01-06
# 16 recentspec Red-tail Hawk
# 16 recentstat FLEDGED NEST
# 16 Nest_ID 15
# 16 geometry POINT (-104.68345 40.28228)
# 17 postgis_fi 371.0
# 17 lat_y_dd 40.18432
# 17 long_x_dd -104.77275
# 17 lastsurvey 2012-03-23
# 17 recentspec Swainsons Hawk
# 17 recentstat FLEDGED NEST
# 17 Nest_ID 371
# 17 geometry POINT (-104.77275 40.18432)
# 18 postgis_fi 913.0
# 18 lat_y_dd 40.138876
# 18 long_x_dd -104.976541
# 18 lastsurvey 2015-09-10
# 18 recentspec Red-tail Hawk
# 18 recentstat INACTIVE NEST
# 18 Nest_ID 913
# 18 geometry POINT (-104.91296 40.1135)
# 19 postgis_fi 914.0
# 19 lat_y_dd 40.140884
# 19 long_x_dd -104.951201
# 19 lastsurvey 2015-09-10
# 19 recentspec Red-tail Hawk
# 19 recentstat INACTIVE NEST
# 19 Nest_ID 914
# 19 geometry POINT (-104.99814 40.1016)
# 20 postgis_fi 915.0
# 20 lat_y_dd 40.131518
# 20 long_x_dd -104.963308
# 20 lastsurvey 2015-09-10
# 20 recentspec Red-tail Hawk
# 20 recentstat INACTIVE NEST
# 20 Nest_ID 915
# 20 geometry POINT (-104.98495 40.1742)
# 21 postgis_fi 916.0
# 21 lat_y_dd 40.131956
# 21 long_x_dd -104.959158
# 21 lastsurvey 2015-09-10
# 21 recentspec Swainsons Hawk
# 21 recentstat INACTIVE NEST
# 21 Nest_ID 916
# 21 geometry POINT (-105.03582 40.19353)
# 22 postgis_fi 917.0
# 22 lat_y_dd 40.368366
# 22 long_x_dd -104.963993
# 22 lastsurvey 2015-10-14
# 22 recentspec Red-tail Hawk
# 22 recentstat INACTIVE NEST
# 22 Nest_ID 917
# 22 geometry POINT (-104.99776 40.42473)
# 23 postgis_fi 918.0
# 23 lat_y_dd 40.357932
# 23 long_x_dd -104.965152
# 23 lastsurvey 2015-10-14
# 23 recentspec Red-tail Hawk
# 23 recentstat INACTIVE NEST
# 23 Nest_ID 918
# 23 geometry POINT (-104.98967 40.42586)
# 24 postgis_fi 919.0
# 24 lat_y_dd 40.35701
# 24 long_x_dd -104.963257
# 24 lastsurvey 2015-10-14
# 24 recentspec Swainsons Hawk
# 24 recentstat INACTIVE NEST
# 24 Nest_ID 919
# 24 geometry POINT (-104.97197 40.4067)
# 25 postgis_fi 16.0
# 25 lat_y_dd 40.243589
# 25 long_x_dd -104.730385
# 25 lastsurvey 2011-01-06
# 25 recentspec Swainsons Hawk
# 25 recentstat ACTIVE NEST
# 25 Nest_ID 16
# 25 geometry POINT (-104.72963 40.2348)
# 26 postgis_fi 17.0
# 26 lat_y_dd 40.185072
# 26 long_x_dd -104.844298
# 26 lastsurvey 2011-01-06
# 26 recentspec Red-tail Hawk
# 26 recentstat ACTIVE NEST
# 26 Nest_ID 17
# 26 geometry POINT (-104.87677 40.23926)
# 27 postgis_fi 18.0
# 27 lat_y_dd 40.240403
# 27 long_x_dd -104.860404
# 27 lastsurvey 2011-01-06
# 27 recentspec Red-tail Hawk
# 27 recentstat INACTIVE NEST
# 27 Nest_ID 18
# 27 geometry POINT (-104.91238 40.29383)
# 28 postgis_fi 19.0
# 28 lat_y_dd 40.226344
# 28 long_x_dd -104.850214
# 28 lastsurvey 2011-01-06
# 28 recentspec Red-tail Hawk
# 28 recentstat ACTIVE NEST
# 28 Nest_ID 19
# 28 geometry POINT (-104.87695 40.21758)
# 29 postgis_fi 20.0
# 29 lat_y_dd 40.229449
# 29 long_x_dd -104.8522
# 29 lastsurvey 2011-01-06
# 29 recentspec Red-tail Hawk
# 29 recentstat ACTIVE NEST
# 29 Nest_ID 20
# 29 geometry POINT (-104.8872 40.16783)
# 30 postgis_fi 21.0
# 30 lat_y_dd 40.301935
# 30 long_x_dd -104.947598
# 30 lastsurvey 2011-01-06
# 30 recentspec Swainsons Hawk
# 30 recentstat INACTIVE NEST
# 30 Nest_ID 21
# 30 geometry POINT (-104.98418 40.30175)
# 31 postgis_fi 22.0
# 31 lat_y_dd 40.196557
# 31 long_x_dd -104.851282
# 31 lastsurvey 2011-01-06
# 31 recentspec Swainsons Hawk
# 31 recentstat INACTIVE NEST
# 31 Nest_ID 22
# 31 geometry POINT (-104.77577 40.16702)
# 32 postgis_fi 23.0
# 32 lat_y_dd 40.138615
# 32 long_x_dd -104.989487
# 32 lastsurvey 2014-06-25
# 32 recentspec Swainsons Hawk
# 32 recentstat INACTIVE NEST
# 32 Nest_ID 23
# 32 geometry POINT (-104.95636 40.20921)
# 33 postgis_fi 24.0
# 33 lat_y_dd 40.140795
# 33 long_x_dd -104.714801
# 33 lastsurvey 2011-01-06
# 33 recentspec Red-tail Hawk
# 33 recentstat INACTIVE NEST
# 33 Nest_ID 24
# 33 geometry POINT (-104.78436 40.16182)
# 34 postgis_fi 25.0
# 34 lat_y_dd 40.231893
# 34 long_x_dd -104.860162
# 34 lastsurvey 2011-01-06
# 34 recentspec Red-tail Hawk
# 34 recentstat INACTIVE NEST
# 34 Nest_ID 25
# 34 geometry POINT (-104.94972 40.25426)
# 35 postgis_fi 26.0
# 35 lat_y_dd 40.141795
# 35 long_x_dd -104.714559
# 35 lastsurvey 2011-01-06
# 35 recentspec Swainsons Hawk
# 35 recentstat INACTIVE NEST
# 35 Nest_ID 26
# 35 geometry POINT (-104.65786 40.1207)
# 36 postgis_fi 27.0
# 36 lat_y_dd 40.196828
# 36 long_x_dd -104.830056
# 36 lastsurvey 2011-01-06
# 36 recentspec Red-tail Hawk
# 36 recentstat ACTIVE NEST
# 36 Nest_ID 27
# 36 geometry POINT (-104.76699 40.20147)
# 37 postgis_fi 28.0
# 37 lat_y_dd 40.181554
# 37 long_x_dd -104.603392
# 37 lastsurvey 2011-01-06
# 37 recentspec Red-tail Hawk
# 37 recentstat INACTIVE NEST
# 37 Nest_ID 28
# 37 geometry POINT (-104.52641 40.17562)
# 38 postgis_fi 29.0
# 38 lat_y_dd 40.182014
# 38 long_x_dd -104.660659
# 38 lastsurvey 2011-01-06
# 38 recentspec Red-tail Hawk
# 38 recentstat INACTIVE NEST
# 38 Nest_ID 29
# 38 geometry POINT (-104.69561 40.16848)
# 39 postgis_fi 30.0
# 39 lat_y_dd 40.195063
# 39 long_x_dd -104.849572
# 39 lastsurvey 2011-01-06
# 39 recentspec Swainsons Hawk
# 39 recentstat INACTIVE NEST
# 39 Nest_ID 30
# 39 geometry POINT (-104.85299 40.23548)
# 40 postgis_fi 31.0
# 40 lat_y_dd 40.175037
# 40 long_x_dd -104.946548
# 40 lastsurvey 2011-01-06
# 40 recentspec Swainsons Hawk
# 40 recentstat ACTIVE NEST
# 40 Nest_ID 31
# 40 geometry POINT (-105.00639 40.24032)
# 41 postgis_fi 32.0
# 41 lat_y_dd 40.22518
# 41 long_x_dd -104.838378
# 41 lastsurvey 2011-01-06
# 41 recentspec Red-tail Hawk
# 41 recentstat INACTIVE NEST
# 41 Nest_ID 32
# 41 geometry POINT (-104.83528 40.19825)
# 42 postgis_fi 33.0
# 42 lat_y_dd 40.174755
# 42 long_x_dd -104.799249
# 42 lastsurvey 2011-01-06
# 42 recentspec Red-tail Hawk
# 42 recentstat INACTIVE NEST
# 42 Nest_ID 33
# 42 geometry POINT (-104.79673 40.20553)
# 43 postgis_fi 34.0
# 43 lat_y_dd 40.019042
# 43 long_x_dd -104.942779
# 43 lastsurvey 2011-01-06
# 43 recentspec Red-tail Hawk
# 43 recentstat ACTIVE NEST
# 43 Nest_ID 34
# 43 geometry POINT (-104.91002 39.96346)
# 44 postgis_fi 35.0
# 44 lat_y_dd 40.181961
# 44 long_x_dd -104.847581
# 44 lastsurvey 2011-01-06
# 44 recentspec Red-tail Hawk
# 44 recentstat ACTIVE NEST
# 44 Nest_ID 35
# 44 geometry POINT (-104.83385 40.12341)
# 45 postgis_fi 36.0
# 45 lat_y_dd 40.18421
# 45 long_x_dd -104.876609
# 45 lastsurvey 2011-01-06
# 45 recentspec Swainsons Hawk
# 45 recentstat ACTIVE NEST
# 45 Nest_ID 36
# 45 geometry POINT (-104.82664 40.15769)
# 46 postgis_fi 37.0
# 46 lat_y_dd 40.185009
# 46 long_x_dd -104.876566
# 46 lastsurvey 2011-01-06
# 46 recentspec Red-tail Hawk
# 46 recentstat FLEDGED NEST
# 46 Nest_ID 37
# 46 geometry POINT (-104.96623 40.13452)
# 47 postgis_fi 38.0
# 47 lat_y_dd 40.074776
# 47 long_x_dd -105.047018
# 47 lastsurvey 2008-04-25
# 47 recentspec Red-tail Hawk
# 47 recentstat INACTIVE NEST
# 47 Nest_ID 38
# 47 geometry POINT (-104.98086 40.08121)
# 48 postgis_fi 39.0
# 48 lat_y_dd 40.143726
# 48 long_x_dd -104.984522
# 48 lastsurvey 2008-04-25
# 48 recentspec Red-tail Hawk
# 48 recentstat INACTIVE NEST
# 48 Nest_ID 39
# 48 geometry POINT (-105.05218 40.1003)
# 49 postgis_fi 40.0
# 49 lat_y_dd 40.231198
# 49 long_x_dd -104.626507
# 49 lastsurvey 2008-04-25
# 49 recentspec Red-tail Hawk
# 49 recentstat INACTIVE NEST
# 49 Nest_ID 40
# 49 geometry POINT (-104.60876 40.28215)
# 50 postgis_fi 41.0
# 50 lat_y_dd 40.14024
# 50 long_x_dd -104.984017
# 50 lastsurvey 2008-04-25
# 50 recentspec Red-tail Hawk
# 50 recentstat INACTIVE NEST
# 50 Nest_ID 41
# 50 geometry POINT (-105.0307 40.10774)
# 51 postgis_fi 42.0
# 51 lat_y_dd 40.280158
# 51 long_x_dd -105.023386
# 51 lastsurvey 2008-04-25
# 51 recentspec Swainsons Hawk
# 51 recentstat ACTIVE NEST
# 51 Nest_ID 42
# 51 geometry POINT (-105.01748 40.34794)
# 52 postgis_fi 43.0
# 52 lat_y_dd 40.441386
# 52 long_x_dd -104.852749
# 52 lastsurvey 2008-04-25
# 52 recentspec Swainsons Hawk
# 52 recentstat FLEDGED NEST
# 52 Nest_ID 43
# 52 geometry POINT (-104.79653 40.47682)
# 53 postgis_fi 44.0
# 53 lat_y_dd 40.2483
# 53 long_x_dd -104.598365
# 53 lastsurvey 2008-04-25
# 53 recentspec Red-tail Hawk
# 53 recentstat ACTIVE NEST
# 53 Nest_ID 44
# 53 geometry POINT (-104.52823 40.27316)
# 54 postgis_fi 45.0
# 54 lat_y_dd 40.25945
# 54 long_x_dd -104.594912
# 54 lastsurvey 2008-04-25
# 54 recentspec Red-tail Hawk
# 54 recentstat FLEDGED NEST
# 54 Nest_ID 45
# 54 geometry POINT (-104.64234 40.30311)
# 55 postgis_fi 46.0
# 55 lat_y_dd 40.322534
# 55 long_x_dd -104.630024
# 55 lastsurvey 2008-04-25
# 55 recentspec Swainsons Hawk
# 55 recentstat INACTIVE NEST
# 55 Nest_ID 46
# 55 geometry POINT (-104.59918 40.34821)
# 56 postgis_fi 47.0
# 56 lat_y_dd 40.271404
# 56 long_x_dd -104.629232
# 56 lastsurvey 2008-04-25
# 56 recentspec Swainsons Hawk
# 56 recentstat INACTIVE NEST
# 56 Nest_ID 47
# 56 geometry POINT (-104.60601 40.24514)
# 57 postgis_fi 48.0
# 57 lat_y_dd 40.27624
# 57 long_x_dd -104.578685
# 57 lastsurvey 2008-04-25
# 57 recentspec Red-tail Hawk
# 57 recentstat INACTIVE NEST
# 57 Nest_ID 48
# 57 geometry POINT (-104.58589 40.3014)
# 58 postgis_fi 49.0
# 58 lat_y_dd 40.283779
# 58 long_x_dd -105.026692
# 58 lastsurvey 2008-04-25
# 58 recentspec Red-tail Hawk
# 58 recentstat INACTIVE NEST
# 58 Nest_ID 49
# 58 geometry POINT (-104.98787 40.29486)
# 59 postgis_fi 50.0
# 59 lat_y_dd 40.275573
# 59 long_x_dd -105.019373
# 59 lastsurvey 2008-04-25
# 59 recentspec Red-tail Hawk
# 59 recentstat ACTIVE NEST
# 59 Nest_ID 50
# 59 geometry POINT (-104.99136 40.24572)
# 60 postgis_fi 51.0
# 60 lat_y_dd 40.485335
# 60 long_x_dd -104.452276
# 60 lastsurvey 2008-04-25
# 60 recentspec Swainsons Hawk
# 60 recentstat INACTIVE NEST
# 60 Nest_ID 51
# 60 geometry POINT (-104.53763 40.45225)
# 61 postgis_fi 52.0
# 61 lat_y_dd 40.341314
# 61 long_x_dd -104.617747
# 61 lastsurvey 2008-04-25
# 61 recentspec Red-tail Hawk
# 61 recentstat INACTIVE NEST
# 61 Nest_ID 52
# 61 geometry POINT (-104.57254 40.34041)
# 62 postgis_fi 53.0
# 62 lat_y_dd 40.275542
# 62 long_x_dd -104.67526
# 62 lastsurvey 2008-04-25
# 62 recentspec Swainsons Hawk
# 62 recentstat INACTIVE NEST
# 62 Nest_ID 53
# 62 geometry POINT (-104.63141 40.33613)
# 63 postgis_fi 54.0
# 63 lat_y_dd 40.270743
# 63 long_x_dd -104.679423
# 63 lastsurvey 2008-04-25
# 63 recentspec Swainsons Hawk
# 63 recentstat INACTIVE NEST
# 63 Nest_ID 54
# 63 geometry POINT (-104.7117 40.30232)
# 64 postgis_fi 55.0
# 64 lat_y_dd 39.84752
# 64 long_x_dd -104.61775
# 64 lastsurvey 2008-04-25
# 64 recentspec Swainsons Hawk
# 64 recentstat INACTIVE NEST
# 64 Nest_ID 55
# 64 geometry POINT (-104.54095 39.86113)
# 65 postgis_fi 56.0
# 65 lat_y_dd 40.25559
# 65 long_x_dd -104.58366
# 65 lastsurvey 2008-04-25
# 65 recentspec Swainsons Hawk
# 65 recentstat FLEDGED NEST
# 65 Nest_ID 56
# 65 geometry POINT (-104.621 40.27386)
# 66 postgis_fi 57.0
# 66 lat_y_dd 40.58071
# 66 long_x_dd -104.50874
# 66 lastsurvey 2008-04-25
# 66 recentspec Swainsons Hawk
# 66 recentstat INACTIVE NEST
# 66 Nest_ID 57
# 66 geometry POINT (-104.46596 40.57309)
# 67 postgis_fi 58.0
# 67 lat_y_dd 40.53128
# 67 long_x_dd -104.83036
# 67 lastsurvey 2008-04-25
# 67 recentspec Red-tail Hawk
# 67 recentstat INACTIVE NEST
# 67 Nest_ID 58
# 67 geometry POINT (-104.8295 40.48061)
# 68 postgis_fi 59.0
# 68 lat_y_dd 40.53205
# 68 long_x_dd -104.65707
# 68 lastsurvey 2008-04-25
# 68 recentspec Red-tail Hawk
# 68 recentstat INACTIVE NEST
# 68 Nest_ID 59
# 68 geometry POINT (-104.61477 40.48916)
# 70 postgis_fi 61.0
# 70 lat_y_dd 40.283752
# 70 long_x_dd -105.026892
# 70 lastsurvey 2008-04-25
# 70 recentspec Red-tail Hawk
# 70 recentstat INACTIVE NEST
# 70 Nest_ID 61
# 70 geometry POINT (-105.07959 40.35293)
# 71 postgis_fi 62.0
# 71 lat_y_dd 40.116947
# 71 long_x_dd -105.036532
# 71 lastsurvey 2008-04-25
# 71 recentspec Swainsons Hawk
# 71 recentstat INACTIVE NEST
# 71 Nest_ID 62
# 71 geometry POINT (-105.09585 40.1276)
# 72 postgis_fi 63.0
# 72 lat_y_dd 40.362427
# 72 long_x_dd -104.764271
# 72 lastsurvey 2008-04-25
# 72 recentspec Swainsons Hawk
# 72 recentstat FLEDGED NEST
# 72 Nest_ID 63
# 72 geometry POINT (-104.84195 40.36651)
# 73 postgis_fi 64.0
# 73 lat_y_dd 40.121593
# 73 long_x_dd -105.005058
# 73 lastsurvey 2008-04-25
# 73 recentspec Red-tail Hawk
# 73 recentstat INACTIVE NEST
# 73 Nest_ID 64
# 73 geometry POINT (-105.01954 40.1775)
# 74 postgis_fi 65.0
# 74 lat_y_dd 40.486637
# 74 long_x_dd -104.451427
# 74 lastsurvey 2008-04-25
# 74 recentspec Swainsons Hawk
# 74 recentstat INACTIVE NEST
# 74 Nest_ID 65
# 74 geometry POINT (-104.41929 40.52833)
# 75 postgis_fi 66.0
# 75 lat_y_dd 40.201173
# 75 long_x_dd -104.907319
# 75 lastsurvey 2008-04-25
# 75 recentspec Red-tail Hawk
# 75 recentstat FLEDGED NEST
# 75 Nest_ID 66
# 75 geometry POINT (-104.94201 40.16989)
# 76 postgis_fi 67.0
# 76 lat_y_dd 40.200841
# 76 long_x_dd -104.909011
# 76 lastsurvey 2008-04-25
# 76 recentspec Red-tail Hawk
# 76 recentstat INACTIVE NEST
# 76 Nest_ID 67
# 76 geometry POINT (-104.91275 40.22515)
# 77 postgis_fi 68.0
# 77 lat_y_dd 40.179032
# 77 long_x_dd -104.831177
# 77 lastsurvey 2008-04-25
# 77 recentspec Red-tail Hawk
# 77 recentstat ACTIVE NEST
# 77 Nest_ID 68
# 77 geometry POINT (-104.83712 40.12286)
# 78 postgis_fi 69.0
# 78 lat_y_dd 40.048844
# 78 long_x_dd -104.831487
# 78 lastsurvey 2008-04-25
# 78 recentspec Red-tail Hawk
# 78 recentstat FLEDGED NEST
# 78 Nest_ID 69
# 78 geometry POINT (-104.83891 40.05415)
# 79 postgis_fi 70.0
# 79 lat_y_dd 40.168236
# 79 long_x_dd -104.623535
# 79 lastsurvey 2008-04-25
# 79 recentspec Swainsons Hawk
# 79 recentstat INACTIVE NEST
# 79 Nest_ID 70
# 79 geometry POINT (-104.57744 40.11825)
# 80 postgis_fi 71.0
# 80 lat_y_dd 40.161225
# 80 long_x_dd -104.631465
# 80 lastsurvey 2014-09-04
# 80 recentspec Red-tail Hawk
# 80 recentstat ACTIVE NEST
# 80 Nest_ID 71
# 80 geometry POINT (-104.61912 40.17869)
# 81 postgis_fi 72.0
# 81 lat_y_dd 40.157045
# 81 long_x_dd -104.620332
# 81 lastsurvey 2008-04-25
# 81 recentspec Swainsons Hawk
# 81 recentstat INACTIVE NEST
# 81 Nest_ID 72
# 81 geometry POINT (-104.64093 40.08932)
# 82 postgis_fi 73.0
# 82 lat_y_dd 40.155659
# 82 long_x_dd -104.620748
# 82 lastsurvey 2008-04-25
# 82 recentspec Red-tail Hawk
# 82 recentstat INACTIVE NEST
# 82 Nest_ID 73
# 82 geometry POINT (-104.56071 40.20625)
# 83 postgis_fi 75.0
# 83 lat_y_dd 40.135336
# 83 long_x_dd -104.61632
# 83 lastsurvey 2008-04-25
# 83 recentspec Swainsons Hawk
# 83 recentstat INACTIVE NEST
# 83 Nest_ID 75
# 83 geometry POINT (-104.60701 40.0922)
# 84 postgis_fi 76.0
# 84 lat_y_dd 40.313602
# 84 long_x_dd -104.933598
# 84 lastsurvey 2008-04-25
# 84 recentspec Red-tail Hawk
# 84 recentstat ACTIVE NEST
# 84 Nest_ID 76
# 84 geometry POINT (-104.99521 40.36347)
# 85 postgis_fi 77.0
# 85 lat_y_dd 40.256101
# 85 long_x_dd -104.971308
# 85 lastsurvey 2008-04-25
# 85 recentspec Swainsons Hawk
# 85 recentstat INACTIVE NEST
# 85 Nest_ID 77
# 85 geometry POINT (-105.05676 40.32494)
# 86 postgis_fi 78.0
# 86 lat_y_dd 40.225608
# 86 long_x_dd -104.848821
# 86 lastsurvey 2008-04-25
# 86 recentspec Red-tail Hawk
# 86 recentstat FLEDGED NEST
# 86 Nest_ID 78
# 86 geometry POINT (-104.89094 40.29457)
# 87 postgis_fi 79.0
# 87 lat_y_dd 40.064704
# 87 long_x_dd -104.847137
# 87 lastsurvey 2008-04-25
# 87 recentspec Red-tail Hawk
# 87 recentstat FLEDGED NEST
# 87 Nest_ID 79
# 87 geometry POINT (-104.90728 40.12695)
# 88 postgis_fi 80.0
# 88 lat_y_dd 40.0586
# 88 long_x_dd -104.836715
# 88 lastsurvey 2008-04-25
# 88 recentspec Swainsons Hawk
# 88 recentstat ACTIVE NEST
# 88 Nest_ID 80
# 88 geometry POINT (-104.88378 40.11421)
# 89 postgis_fi 81.0
# 89 lat_y_dd 40.06284
# 89 long_x_dd -104.834489
# 89 lastsurvey 2008-04-25
# 89 recentspec Swainsons Hawk
# 89 recentstat INACTIVE NEST
# 89 Nest_ID 81
# 89 geometry POINT (-104.83552 40.10434)
# 90 postgis_fi 82.0
# 90 lat_y_dd 40.038086
# 90 long_x_dd -104.831619
# 90 lastsurvey 2008-04-25
# 90 recentspec Red-tail Hawk
# 90 recentstat ACTIVE NEST
# 90 Nest_ID 82
# 90 geometry POINT (-104.84902 40.06503)
# 91 postgis_fi 83.0
# 91 lat_y_dd 40.048069
# 91 long_x_dd -104.831336
# 91 lastsurvey 2008-04-25
# 91 recentspec Red-tail Hawk
# 91 recentstat INACTIVE NEST
# 91 Nest_ID 83
# 91 geometry POINT (-104.91765 40.01353)
# 92 postgis_fi 84.0
# 92 lat_y_dd 40.062771
# 92 long_x_dd -104.830749
# 92 lastsurvey 2008-04-25
# 92 recentspec Swainsons Hawk
# 92 recentstat INACTIVE NEST
# 92 Nest_ID 84
# 92 geometry POINT (-104.91904 40.09191)
# 93 postgis_fi 85.0
# 93 lat_y_dd 40.06178
# 93 long_x_dd -104.830306
# 93 lastsurvey 2008-04-25
# 93 recentspec Red-tail Hawk
# 93 recentstat ACTIVE NEST
# 93 Nest_ID 85
# 93 geometry POINT (-104.92033 40.00823)
# 94 postgis_fi 86.0
# 94 lat_y_dd 40.050671
# 94 long_x_dd -104.830275
# 94 lastsurvey 2008-04-25
# 94 recentspec Swainsons Hawk
# 94 recentstat ACTIVE NEST
# 94 Nest_ID 86
# 94 geometry POINT (-104.75313 39.99989)
# 95 postgis_fi 87.0
# 95 lat_y_dd 40.046409
# 95 long_x_dd -104.830121
# 95 lastsurvey 2008-04-25
# 95 recentspec Red-tail Hawk
# 95 recentstat INACTIVE NEST
# 95 Nest_ID 87
# 95 geometry POINT (-104.78684 40.06302)
# 96 postgis_fi 88.0
# 96 lat_y_dd 40.063599
# 96 long_x_dd -104.829832
# 96 lastsurvey 2008-04-25
# 96 recentspec Swainsons Hawk
# 96 recentstat INACTIVE NEST
# 96 Nest_ID 88
# 96 geometry POINT (-104.89227 40.04444)
# 97 postgis_fi 89.0
# 97 lat_y_dd 40.037714
# 97 long_x_dd -104.829709
# 97 lastsurvey 2008-04-25
# 97 recentspec Red-tail Hawk
# 97 recentstat INACTIVE NEST
# 97 Nest_ID 89
# 97 geometry POINT (-104.8124 39.99289)
# 98 postgis_fi 90.0
# 98 lat_y_dd 40.038471
# 98 long_x_dd -104.829695
# 98 lastsurvey 2008-04-25
# 98 recentspec Red-tail Hawk
# 98 recentstat INACTIVE NEST
# 98 Nest_ID 90
# 98 geometry POINT (-104.8625 39.99064)
# 99 postgis_fi 91.0
# 99 lat_y_dd 40.036795
# 99 long_x_dd -104.829582
# 99 lastsurvey 2008-04-25
# 99 recentspec Swainsons Hawk
# 99 recentstat INACTIVE NEST
# 99 Nest_ID 91
# 99 geometry POINT (-104.81005 40.09573)
# 100 postgis_fi 92.0
# 100 lat_y_dd 40.031947
# 100 long_x_dd -104.829477
# 100 lastsurvey 2008-04-25
# 100 recentspec Swainsons Hawk
# 100 recentstat FLEDGED NEST
# 100 Nest_ID 92
# 100 geometry POINT (-104.83104 40.0983)
# 101 postgis_fi 93.0
# 101 lat_y_dd 40.049804
# 101 long_x_dd -104.829175
# 101 lastsurvey 2008-04-25
# 101 recentspec Red-tail Hawk
# 101 recentstat INACTIVE NEST
# 101 Nest_ID 93
# 101 geometry POINT (-104.77532 40.05807)
# 102 postgis_fi 94.0
# 102 lat_y_dd 40.048244
# 102 long_x_dd -104.828065
# 102 lastsurvey 2014-06-09
# 102 recentspec Red-tail Hawk
# 102 recentstat ACTIVE NEST
# 102 Nest_ID 94
# 102 geometry POINT (-104.77525 40.11579)
# 103 postgis_fi 95.0
# 103 lat_y_dd 40.049477
# 103 long_x_dd -104.8271
# 103 lastsurvey 2008-04-25
# 103 recentspec Red-tail Hawk
# 103 recentstat INACTIVE NEST
# 103 Nest_ID 95
# 103 geometry POINT (-104.87745 40.06964)
# 104 postgis_fi 96.0
# 104 lat_y_dd 40.035529
# 104 long_x_dd -104.826561
# 104 lastsurvey 2008-04-25
# 104 recentspec Red-tail Hawk
# 104 recentstat INACTIVE NEST
# 104 Nest_ID 96
# 104 geometry POINT (-104.73479 40.03041)
# 105 postgis_fi 97.0
# 105 lat_y_dd 40.058384
# 105 long_x_dd -104.824545
# 105 lastsurvey 2008-04-25
# 105 recentspec Swainsons Hawk
# 105 recentstat ACTIVE NEST
# 105 Nest_ID 97
# 105 geometry POINT (-104.86578 39.99927)
# 106 postgis_fi 98.0
# 106 lat_y_dd 40.061459
# 106 long_x_dd -104.820562
# 106 lastsurvey 2008-04-25
# 106 recentspec Red-tail Hawk
# 106 recentstat INACTIVE NEST
# 106 Nest_ID 98
# 106 geometry POINT (-104.82824 40.0463)
# 107 postgis_fi 99.0
# 107 lat_y_dd 40.530799
# 107 long_x_dd -104.831797
# 107 lastsurvey 2008-06-03
# 107 recentspec Swainsons Hawk
# 107 recentstat FLEDGED NEST
# 107 Nest_ID 99
# 107 geometry POINT (-104.91752 40.49435)
# 108 postgis_fi 100.0
# 108 lat_y_dd 40.338229
# 108 long_x_dd -104.587601
# 108 lastsurvey 2008-06-03
# 108 recentspec Red-tail Hawk
# 108 recentstat INACTIVE NEST
# 108 Nest_ID 100
# 108 geometry POINT (-104.53155 40.2802)
# 109 postgis_fi 101.0
# 109 lat_y_dd 40.487824
# 109 long_x_dd -104.768116
# 109 lastsurvey 2008-06-03
# 109 recentspec Swainsons Hawk
# 109 recentstat FLEDGED NEST
# 109 Nest_ID 101
# 109 geometry POINT (-104.76049 40.41908)
# 110 postgis_fi 102.0
# 110 lat_y_dd 40.08835
# 110 long_x_dd -104.508468
# 110 lastsurvey 2008-06-03
# 110 recentspec Swainsons Hawk
# 110 recentstat FLEDGED NEST
# 110 Nest_ID 102
# 110 geometry POINT (-104.49186 40.03111)
# 111 postgis_fi 103.0
# 111 lat_y_dd 40.517867
# 111 long_x_dd -104.827522
# 111 lastsurvey 2008-06-03
# 111 recentspec Red-tail Hawk
# 111 recentstat INACTIVE NEST
# 111 Nest_ID 103
# 111 geometry POINT (-104.75051 40.52852)
# 112 postgis_fi 104.0
# 112 lat_y_dd 40.508454
# 112 long_x_dd -104.830224
# 112 lastsurvey 2008-06-03
# 112 recentspec Red-tail Hawk
# 112 recentstat FLEDGED NEST
# 112 Nest_ID 104
# 112 geometry POINT (-104.765 40.48259)
# 113 postgis_fi 105.0
# 113 lat_y_dd 40.518207
# 113 long_x_dd -104.82783
# 113 lastsurvey 2008-06-03
# 113 recentspec Red-tail Hawk
# 113 recentstat FLEDGED NEST
# 113 Nest_ID 105
# 113 geometry POINT (-104.77397 40.45362)
# 114 postgis_fi 106.0
# 114 lat_y_dd 40.326908
# 114 long_x_dd -104.581231
# 114 lastsurvey 2008-06-03
# 114 recentspec Swainsons Hawk
# 114 recentstat INACTIVE NEST
# 114 Nest_ID 106
# 114 geometry POINT (-104.53068 40.33154)
# 115 postgis_fi 107.0
# 115 lat_y_dd 40.057375
# 115 long_x_dd -104.576964
# 115 lastsurvey 2008-06-03
# 115 recentspec Red-tail Hawk
# 115 recentstat INACTIVE NEST
# 115 Nest_ID 107
# 115 geometry POINT (-104.57046 40.02929)
# 116 postgis_fi 108.0
# 116 lat_y_dd 40.290293
# 116 long_x_dd -104.876666
# 116 lastsurvey 2008-06-03
# 116 recentspec Swainsons Hawk
# 116 recentstat INACTIVE NEST
# 116 Nest_ID 108
# 116 geometry POINT (-104.8441 40.34197)
# 117 postgis_fi 109.0
# 117 lat_y_dd 40.310841
# 117 long_x_dd -104.866732
# 117 lastsurvey 2008-06-03
# 117 recentspec Red-tail Hawk
# 117 recentstat ACTIVE NEST
# 117 Nest_ID 109
# 117 geometry POINT (-104.86989 40.29139)
# 118 postgis_fi 110.0
# 118 lat_y_dd 40.501811
# 118 long_x_dd -104.471308
# 118 lastsurvey 2008-06-03
# 118 recentspec Red-tail Hawk
# 118 recentstat INACTIVE NEST
# 118 Nest_ID 110
# 118 geometry POINT (-104.48078 40.56803)
# 119 postgis_fi 111.0
# 119 lat_y_dd 40.266192
# 119 long_x_dd -104.666249
# 119 lastsurvey 2008-06-03
# 119 recentspec Red-tail Hawk
# 119 recentstat INACTIVE NEST
# 119 Nest_ID 111
# 119 geometry POINT (-104.68259 40.27171)
# 120 postgis_fi 112.0
# 120 lat_y_dd 40.185024
# 120 long_x_dd -105.155517
# 120 lastsurvey 2008-06-03
# 120 recentspec Red-tail Hawk
# 120 recentstat INACTIVE NEST
# 120 Nest_ID 112
# 120 geometry POINT (-105.17062 40.23782)
# 121 postgis_fi 114.0
# 121 lat_y_dd 40.38259
# 121 long_x_dd -104.94166
# 121 lastsurvey 2008-06-03
# 121 recentspec Swainsons Hawk
# 121 recentstat FLEDGED NEST
# 121 Nest_ID 114
# 121 geometry POINT (-104.96513 40.43837)
# 122 postgis_fi 115.0
# 122 lat_y_dd 40.57187
# 122 long_x_dd -104.819655
# 122 lastsurvey 2008-06-03
# 122 recentspec Red-tail Hawk
# 122 recentstat ACTIVE NEST
# 122 Nest_ID 115
# 122 geometry POINT (-104.82919 40.54868)
# 123 postgis_fi 116.0
# 123 lat_y_dd 40.357831
# 123 long_x_dd -104.719123
# 123 lastsurvey 2008-06-03
# 123 recentspec Red-tail Hawk
# 123 recentstat INACTIVE NEST
# 123 Nest_ID 116
# 123 geometry POINT (-104.68079 40.31262)
# 124 postgis_fi 117.0
# 124 lat_y_dd 40.130134
# 124 long_x_dd -104.993051
# 124 lastsurvey 2008-06-03
# 124 recentspec Red-tail Hawk
# 124 recentstat FLEDGED NEST
# 124 Nest_ID 117
# 124 geometry POINT (-104.96794 40.20047)
# 125 postgis_fi 118.0
# 125 lat_y_dd 40.48504
# 125 long_x_dd -104.61311
# 125 lastsurvey 2008-06-03
# 125 recentspec Red-tail Hawk
# 125 recentstat ACTIVE NEST
# 125 Nest_ID 118
# 125 geometry POINT (-104.52014 40.44087)
# 126 postgis_fi 119.0
# 126 lat_y_dd 40.232609
# 126 long_x_dd -104.730173
# 126 lastsurvey 2014-07-16
# 126 recentspec Swainsons Hawk
# 126 recentstat INACTIVE NEST
# 126 Nest_ID 119
# 126 geometry POINT (-104.67131 40.25596)
# 127 postgis_fi 121.0
# 127 lat_y_dd 40.235751
# 127 long_x_dd -104.744902
# 127 lastsurvey 2014-07-18
# 127 recentspec Red-tail Hawk
# 127 recentstat INACTIVE NEST
# 127 Nest_ID 121
# 127 geometry POINT (-104.81498 40.23871)
# 128 postgis_fi 122.0
# 128 lat_y_dd 40.272105
# 128 long_x_dd -104.934651
# 128 lastsurvey 2014-04-30
# 128 recentspec Swainsons Hawk
# 128 recentstat ACTIVE NEST
# 128 Nest_ID 122
# 128 geometry POINT (-104.95209 40.23106)
# 129 postgis_fi 123.0
# 129 lat_y_dd 40.275357
# 129 long_x_dd -104.93313
# 129 lastsurvey 2014-07-23
# 129 recentspec Red-tail Hawk
# 129 recentstat FLEDGED NEST
# 129 Nest_ID 123
# 129 geometry POINT (-104.85054 40.26056)
# 130 postgis_fi 124.0
# 130 lat_y_dd 40.476414
# 130 long_x_dd -104.794357
# 130 lastsurvey 2008-06-03
# 130 recentspec Swainsons Hawk
# 130 recentstat FLEDGED NEST
# 130 Nest_ID 124
# 130 geometry POINT (-104.88624 40.45142)
# 131 postgis_fi 125.0
# 131 lat_y_dd 40.338705
# 131 long_x_dd -104.587316
# 131 lastsurvey 2008-06-03
# 131 recentspec Red-tail Hawk
# 131 recentstat FLEDGED NEST
# 131 Nest_ID 125
# 131 geometry POINT (-104.6084 40.33203)
# 132 postgis_fi 126.0
# 132 lat_y_dd 40.347629
# 132 long_x_dd -104.591041
# 132 lastsurvey 2008-06-03
# 132 recentspec Swainsons Hawk
# 132 recentstat INACTIVE NEST
# 132 Nest_ID 126
# 132 geometry POINT (-104.52545 40.28275)
# 133 postgis_fi 127.0
# 133 lat_y_dd 40.193263
# 133 long_x_dd -104.918913
# 133 lastsurvey 2014-07-11
# 133 recentspec Swainsons Hawk
# 133 recentstat ACTIVE NEST
# 133 Nest_ID 127
# 133 geometry POINT (-104.87129 40.12185)
# 134 postgis_fi 128.0
# 134 lat_y_dd 40.419094
# 134 long_x_dd -104.864786
# 134 lastsurvey 2009-02-16
# 134 recentspec Red-tail Hawk
# 134 recentstat FLEDGED NEST
# 134 Nest_ID 128
# 134 geometry POINT (-104.84771 40.39903)
# 135 postgis_fi 129.0
# 135 lat_y_dd 40.420177
# 135 long_x_dd -104.86661
# 135 lastsurvey 2009-02-16
# 135 recentspec Swainsons Hawk
# 135 recentstat ACTIVE NEST
# 135 Nest_ID 129
# 135 geometry POINT (-104.93307 40.40455)
# 136 postgis_fi 130.0
# 136 lat_y_dd 40.182479
# 136 long_x_dd -105.021958
# 136 lastsurvey 2009-02-16
# 136 recentspec Swainsons Hawk
# 136 recentstat ACTIVE NEST
# 136 Nest_ID 130
# 136 geometry POINT (-105.10449 40.15217)
# 137 postgis_fi 131.0
# 137 lat_y_dd 40.177304
# 137 long_x_dd -104.832708
# 137 lastsurvey 2009-02-16
# 137 recentspec Red-tail Hawk
# 137 recentstat INACTIVE NEST
# 137 Nest_ID 131
# 137 geometry POINT (-104.80508 40.12561)
# 138 postgis_fi 132.0
# 138 lat_y_dd 40.293525
# 138 long_x_dd -104.826139
# 138 lastsurvey 2009-02-16
# 138 recentspec Red-tail Hawk
# 138 recentstat FLEDGED NEST
# 138 Nest_ID 132
# 138 geometry POINT (-104.84461 40.36478)
# 139 postgis_fi 133.0
# 139 lat_y_dd 40.293302
# 139 long_x_dd -104.827081
# 139 lastsurvey 2009-02-16
# 139 recentspec Swainsons Hawk
# 139 recentstat INACTIVE NEST
# 139 Nest_ID 133
# 139 geometry POINT (-104.89419 40.35369)
# 140 postgis_fi 134.0
# 140 lat_y_dd 40.295341
# 140 long_x_dd -104.829523
# 140 lastsurvey 2009-02-16
# 140 recentspec Red-tail Hawk
# 140 recentstat INACTIVE NEST
# 140 Nest_ID 134
# 140 geometry POINT (-104.88737 40.3673)
# 141 postgis_fi 135.0
# 141 lat_y_dd 40.239064
# 141 long_x_dd -104.560988
# 141 lastsurvey 2009-02-16
# 141 recentspec Red-tail Hawk
# 141 recentstat ACTIVE NEST
# 141 Nest_ID 135
# 141 geometry POINT (-104.50898 40.29313)
# 142 postgis_fi 136.0
# 142 lat_y_dd 40.236308
# 142 long_x_dd -104.561158
# 142 lastsurvey 2009-02-16
# 142 recentspec Swainsons Hawk
# 142 recentstat INACTIVE NEST
# 142 Nest_ID 136
# 142 geometry POINT (-104.57135 40.19549)
# 143 postgis_fi 137.0
# 143 lat_y_dd 40.161485
# 143 long_x_dd -104.736432
# 143 lastsurvey 2009-02-16
# 143 recentspec Red-tail Hawk
# 143 recentstat INACTIVE NEST
# 143 Nest_ID 137
# 143 geometry POINT (-104.75732 40.22608)
# 144 postgis_fi 138.0
# 144 lat_y_dd 40.167251
# 144 long_x_dd -104.895186
# 144 lastsurvey 2009-09-21
# 144 recentspec Red-tail Hawk
# 144 recentstat ACTIVE NEST
# 144 Nest_ID 138
# 144 geometry POINT (-104.81781 40.12482)
# 145 postgis_fi 139.0
# 145 lat_y_dd 40.174632
# 145 long_x_dd -104.908529
# 145 lastsurvey 2009-09-21
# 145 recentspec Red-tail Hawk
# 145 recentstat FLEDGED NEST
# 145 Nest_ID 139
# 145 geometry POINT (-104.82487 40.1579)
# 146 postgis_fi 140.0
# 146 lat_y_dd 40.168164
# 146 long_x_dd -104.889043
# 146 lastsurvey 2009-09-21
# 146 recentspec Red-tail Hawk
# 146 recentstat ACTIVE NEST
# 146 Nest_ID 140
# 146 geometry POINT (-104.83257 40.18646)
# 147 postgis_fi 141.0
# 147 lat_y_dd 40.168317
# 147 long_x_dd -104.888796
# 147 lastsurvey 2009-09-21
# 147 recentspec Red-tail Hawk
# 147 recentstat INACTIVE NEST
# 147 Nest_ID 141
# 147 geometry POINT (-104.90306 40.13331)
# 148 postgis_fi 142.0
# 148 lat_y_dd 39.850724
# 148 long_x_dd -104.362036
# 148 lastsurvey 2009-09-21
# 148 recentspec Red-tail Hawk
# 148 recentstat ACTIVE NEST
# 148 Nest_ID 142
# 148 geometry POINT (-104.34477 39.86965)
# 149 postgis_fi 143.0
# 149 lat_y_dd 40.222794
# 149 long_x_dd -104.728426
# 149 lastsurvey 2014-08-14
# 149 recentspec Red-tail Hawk
# 149 recentstat ACTIVE NEST
# 149 Nest_ID 143
# 149 geometry POINT (-104.72085 40.1949)
# 150 postgis_fi 144.0
# 150 lat_y_dd 40.153272
# 150 long_x_dd -104.849557
# 150 lastsurvey 2009-09-21
# 150 recentspec Swainsons Hawk
# 150 recentstat FLEDGED NEST
# 150 Nest_ID 144
# 150 geometry POINT (-104.92554 40.13202)
# 151 postgis_fi 145.0
# 151 lat_y_dd 40.193823
# 151 long_x_dd -104.909103
# 151 lastsurvey 2009-09-21
# 151 recentspec Red-tail Hawk
# 151 recentstat FLEDGED NEST
# 151 Nest_ID 145
# 151 geometry POINT (-104.92416 40.23481)
# 152 postgis_fi 146.0
# 152 lat_y_dd 40.034008
# 152 long_x_dd -104.869171
# 152 lastsurvey 2009-09-21
# 152 recentspec Red-tail Hawk
# 152 recentstat INACTIVE NEST
# 152 Nest_ID 146
# 152 geometry POINT (-104.81893 39.9708)
# 153 postgis_fi 147.0
# 153 lat_y_dd 40.072767
# 153 long_x_dd -104.7324
# 153 lastsurvey 2009-09-21
# 153 recentspec Red-tail Hawk
# 153 recentstat INACTIVE NEST
# 153 Nest_ID 147
# 153 geometry POINT (-104.74471 40.06464)
# 154 postgis_fi 148.0
# 154 lat_y_dd 40.167169
# 154 long_x_dd -104.624985
# 154 lastsurvey 2009-09-21
# 154 recentspec Red-tail Hawk
# 154 recentstat FLEDGED NEST
# 154 Nest_ID 148
# 154 geometry POINT (-104.63358 40.19635)
# 155 postgis_fi 149.0
# 155 lat_y_dd 40.169002
# 155 long_x_dd -104.623601
# 155 lastsurvey 2009-09-21
# 155 recentspec Red-tail Hawk
# 155 recentstat INACTIVE NEST
# 155 Nest_ID 149
# 155 geometry POINT (-104.63727 40.12933)
# 156 postgis_fi 151.0
# 156 lat_y_dd 40.103025
# 156 long_x_dd -105.044244
# 156 lastsurvey 2009-09-21
# 156 recentspec Red-tail Hawk
# 156 recentstat INACTIVE NEST
# 156 Nest_ID 151
# 156 geometry POINT (-105.03273 40.05664)
# 157 postgis_fi 152.0
# 157 lat_y_dd 40.132348
# 157 long_x_dd -104.617414
# 157 lastsurvey 2014-08-13
# 157 recentspec Red-tail Hawk
# 157 recentstat ACTIVE NEST
# 157 Nest_ID 152
# 157 geometry POINT (-104.52344 40.19385)
# 158 postgis_fi 153.0
# 158 lat_y_dd 40.135256
# 158 long_x_dd -104.616223
# 158 lastsurvey 2009-09-21
# 158 recentspec Red-tail Hawk
# 158 recentstat INACTIVE NEST
# 158 Nest_ID 153
# 158 geometry POINT (-104.63036 40.17159)
# 159 postgis_fi 154.0
# 159 lat_y_dd 40.1125
# 159 long_x_dd -105.051913
# 159 lastsurvey 2009-09-21
# 159 recentspec Red-tail Hawk
# 159 recentstat FLEDGED NEST
# 159 Nest_ID 154
# 159 geometry POINT (-105.11649 40.14566)
# 160 postgis_fi 155.0
# 160 lat_y_dd 40.076103
# 160 long_x_dd -105.006404
# 160 lastsurvey 2009-09-21
# 160 recentspec Red-tail Hawk
# 160 recentstat INACTIVE NEST
# 160 Nest_ID 155
# 160 geometry POINT (-104.97112 40.13564)
# 161 postgis_fi 156.0
# 161 lat_y_dd 40.170812
# 161 long_x_dd -104.997346
# 161 lastsurvey 2014-03-28
# 161 recentspec Swainsons Hawk
# 161 recentstat FLEDGED NEST
# 161 Nest_ID 156
# 161 geometry POINT (-105.03309 40.17915)
# 162 postgis_fi 157.0
# 162 lat_y_dd 40.145261
# 162 long_x_dd -104.80076
# 162 lastsurvey 2009-09-21
# 162 recentspec Red-tail Hawk
# 162 recentstat INACTIVE NEST
# 162 Nest_ID 157
# 162 geometry POINT (-104.73093 40.15405)
# 163 postgis_fi 158.0
# 163 lat_y_dd 40.006736
# 163 long_x_dd -104.950838
# 163 lastsurvey 2009-12-01
# 163 recentspec Swainsons Hawk
# 163 recentstat INACTIVE NEST
# 163 Nest_ID 158
# 163 geometry POINT (-104.93439 40.02142)
# 164 postgis_fi 159.0
# 164 lat_y_dd 40.29972
# 164 long_x_dd -104.661765
# 164 lastsurvey 2009-12-01
# 164 recentspec Swainsons Hawk
# 164 recentstat INACTIVE NEST
# 164 Nest_ID 159
# 164 geometry POINT (-104.71062 40.23542)
# 165 postgis_fi 160.0
# 165 lat_y_dd 40.289884
# 165 long_x_dd -104.668438
# 165 lastsurvey 2009-12-01
# 165 recentspec Swainsons Hawk
# 165 recentstat INACTIVE NEST
# 165 Nest_ID 160
# 165 geometry POINT (-104.75082 40.29079)
# 166 postgis_fi 161.0
# 166 lat_y_dd 40.292939
# 166 long_x_dd -104.671882
# 166 lastsurvey 2009-12-01
# 166 recentspec Swainsons Hawk
# 166 recentstat ACTIVE NEST
# 166 Nest_ID 161
# 166 geometry POINT (-104.64941 40.29793)
# 167 postgis_fi 162.0
# 167 lat_y_dd 40.293358
# 167 long_x_dd -104.673633
# 167 lastsurvey 2009-12-01
# 167 recentspec Red-tail Hawk
# 167 recentstat ACTIVE NEST
# 167 Nest_ID 162
# 167 geometry POINT (-104.6791 40.33783)
# 168 postgis_fi 163.0
# 168 lat_y_dd 40.226344
# 168 long_x_dd -104.789309
# 168 lastsurvey 2009-12-01
# 168 recentspec Red-tail Hawk
# 168 recentstat ACTIVE NEST
# 168 Nest_ID 163
# 168 geometry POINT (-104.81088 40.25406)
# 169 postgis_fi 164.0
# 169 lat_y_dd 40.159268
# 169 long_x_dd -104.832881
# 169 lastsurvey 2009-12-01
# 169 recentspec Swainsons Hawk
# 169 recentstat INACTIVE NEST
# 169 Nest_ID 164
# 169 geometry POINT (-104.9125 40.21974)
# 170 postgis_fi 165.0
# 170 lat_y_dd 40.160131
# 170 long_x_dd -104.831494
# 170 lastsurvey 2009-12-01
# 170 recentspec Red-tail Hawk
# 170 recentstat INACTIVE NEST
# 170 Nest_ID 165
# 170 geometry POINT (-104.77161 40.2095)
# 171 postgis_fi 166.0
# 171 lat_y_dd 40.21755
# 171 long_x_dd -104.778994
# 171 lastsurvey 2009-12-01
# 171 recentspec Red-tail Hawk
# 171 recentstat ACTIVE NEST
# 171 Nest_ID 166
# 171 geometry POINT (-104.74842 40.16597)
# 172 postgis_fi 167.0
# 172 lat_y_dd 40.136026
# 172 long_x_dd -104.987064
# 172 lastsurvey 2014-06-25
# 172 recentspec Swainsons Hawk
# 172 recentstat FLEDGED NEST
# 172 Nest_ID 167
# 172 geometry POINT (-105.03474 40.06689)
# 173 postgis_fi 168.0
# 173 lat_y_dd 40.145528
# 173 long_x_dd -104.969699
# 173 lastsurvey 2014-06-25
# 173 recentspec Red-tail Hawk
# 173 recentstat INACTIVE NEST
# 173 Nest_ID 168
# 173 geometry POINT (-104.99082 40.15241)
# 174 postgis_fi 169.0
# 174 lat_y_dd 39.91276
# 174 long_x_dd -104.778561
# 174 lastsurvey 2010-03-23
# 174 recentspec Red-tail Hawk
# 174 recentstat FLEDGED NEST
# 174 Nest_ID 169
# 174 geometry POINT (-104.86037 39.9666)
# 175 postgis_fi 170.0
# 175 lat_y_dd 39.919324
# 175 long_x_dd -104.785643
# 175 lastsurvey 2010-03-23
# 175 recentspec Swainsons Hawk
# 175 recentstat INACTIVE NEST
# 175 Nest_ID 170
# 175 geometry POINT (-104.87099 39.89833)
# 176 postgis_fi 171.0
# 176 lat_y_dd 39.91862
# 176 long_x_dd -104.789916
# 176 lastsurvey 2010-03-23
# 176 recentspec Swainsons Hawk
# 176 recentstat ACTIVE NEST
# 176 Nest_ID 171
# 176 geometry POINT (-104.73176 39.86449)
# 177 postgis_fi 173.0
# 177 lat_y_dd 40.072903
# 177 long_x_dd -104.895859
# 177 lastsurvey 2010-03-23
# 177 recentspec Red-tail Hawk
# 177 recentstat INACTIVE NEST
# 177 Nest_ID 173
# 177 geometry POINT (-104.84726 40.02745)
# 178 postgis_fi 174.0
# 178 lat_y_dd 40.166473
# 178 long_x_dd -104.851078
# 178 lastsurvey 2014-06-26
# 178 recentspec Red-tail Hawk
# 178 recentstat ACTIVE NEST
# 178 Nest_ID 174
# 178 geometry POINT (-104.75938 40.12098)
# 179 postgis_fi 175.0
# 179 lat_y_dd 40.160287
# 179 long_x_dd -104.861343
# 179 lastsurvey 2010-03-23
# 179 recentspec Swainsons Hawk
# 179 recentstat INACTIVE NEST
# 179 Nest_ID 175
# 179 geometry POINT (-104.82586 40.13976)
# 180 postgis_fi 176.0
# 180 lat_y_dd 40.162092
# 180 long_x_dd -104.848625
# 180 lastsurvey 2014-06-26
# 180 recentspec Swainsons Hawk
# 180 recentstat ACTIVE NEST
# 180 Nest_ID 176
# 180 geometry POINT (-104.76202 40.10325)
# 181 postgis_fi 177.0
# 181 lat_y_dd 40.356638
# 181 long_x_dd -104.853652
# 181 lastsurvey 2010-03-23
# 181 recentspec Red-tail Hawk
# 181 recentstat INACTIVE NEST
# 181 Nest_ID 177
# 181 geometry POINT (-104.94406 40.30175)
# 182 postgis_fi 178.0
# 182 lat_y_dd 40.174502
# 182 long_x_dd -104.928179
# 182 lastsurvey 2010-03-23
# 182 recentspec Red-tail Hawk
# 182 recentstat ACTIVE NEST
# 182 Nest_ID 178
# 182 geometry POINT (-104.89967 40.20431)
# 183 postgis_fi 179.0
# 183 lat_y_dd 40.341031
# 183 long_x_dd -104.838486
# 183 lastsurvey 2010-03-23
# 183 recentspec Red-tail Hawk
# 183 recentstat INACTIVE NEST
# 183 Nest_ID 179
# 183 geometry POINT (-104.77919 40.28223)
# 184 postgis_fi 180.0
# 184 lat_y_dd 40.338924
# 184 long_x_dd -104.838773
# 184 lastsurvey 2010-03-23
# 184 recentspec Red-tail Hawk
# 184 recentstat INACTIVE NEST
# 184 Nest_ID 180
# 184 geometry POINT (-104.93145 40.31238)
# 185 postgis_fi 181.0
# 185 lat_y_dd 40.235283
# 185 long_x_dd -104.933358
# 185 lastsurvey 2010-03-23
# 185 recentspec Red-tail Hawk
# 185 recentstat ACTIVE NEST
# 185 Nest_ID 181
# 185 geometry POINT (-104.97757 40.18457)
# 186 postgis_fi 182.0
# 186 lat_y_dd 40.201741
# 186 long_x_dd -104.983809
# 186 lastsurvey 2010-03-23
# 186 recentspec Red-tail Hawk
# 186 recentstat ACTIVE NEST
# 186 Nest_ID 182
# 186 geometry POINT (-105.05784 40.20291)
# 187 postgis_fi 184.0
# 187 lat_y_dd 39.977388
# 187 long_x_dd -104.893334
# 187 lastsurvey 2010-03-23
# 187 recentspec Red-tail Hawk
# 187 recentstat INACTIVE NEST
# 187 Nest_ID 184
# 187 geometry POINT (-104.8283 40.02308)
# 188 postgis_fi 185.0
# 188 lat_y_dd 39.98485
# 188 long_x_dd -104.905527
# 188 lastsurvey 2010-03-23
# 188 recentspec Swainsons Hawk
# 188 recentstat INACTIVE NEST
# 188 Nest_ID 185
# 188 geometry POINT (-104.86663 39.91547)
# 189 postgis_fi 186.0
# 189 lat_y_dd 40.174497
# 189 long_x_dd -104.758157
# 189 lastsurvey 2010-03-23
# 189 recentspec Red-tail Hawk
# 189 recentstat INACTIVE NEST
# 189 Nest_ID 186
# 189 geometry POINT (-104.66622 40.20521)
# 190 postgis_fi 187.0
# 190 lat_y_dd 40.169435
# 190 long_x_dd -104.640757
# 190 lastsurvey 2010-03-23
# 190 recentspec Red-tail Hawk
# 190 recentstat INACTIVE NEST
# 190 Nest_ID 187
# 190 geometry POINT (-104.68392 40.15443)
# 191 postgis_fi 188.0
# 191 lat_y_dd 40.140847
# 191 long_x_dd -104.714829
# 191 lastsurvey 2010-03-23
# 191 recentspec Red-tail Hawk
# 191 recentstat ACTIVE NEST
# 191 Nest_ID 188
# 191 geometry POINT (-104.69689 40.18767)
# 192 postgis_fi 189.0
# 192 lat_y_dd 40.099861
# 192 long_x_dd -105.014888
# 192 lastsurvey 2010-10-26
# 192 recentspec Swainsons Hawk
# 192 recentstat ACTIVE NEST
# 192 Nest_ID 189
# 192 geometry POINT (-104.92674 40.16508)
# 193 postgis_fi 190.0
# 193 lat_y_dd 40.177878
# 193 long_x_dd -104.960722
# 193 lastsurvey 2014-08-15
# 193 recentspec Red-tail Hawk
# 193 recentstat INACTIVE NEST
# 193 Nest_ID 190
# 193 geometry POINT (-105.02043 40.11285)
# 194 postgis_fi 191.0
# 194 lat_y_dd 40.07458
# 194 long_x_dd -104.985551
# 194 lastsurvey 2010-10-26
# 194 recentspec Red-tail Hawk
# 194 recentstat INACTIVE NEST
# 194 Nest_ID 191
# 194 geometry POINT (-105.01651 40.0752)
# 195 postgis_fi 192.0
# 195 lat_y_dd 40.061201
# 195 long_x_dd -105.005382
# 195 lastsurvey 2010-10-26
# 195 recentspec Red-tail Hawk
# 195 recentstat ACTIVE NEST
# 195 Nest_ID 192
# 195 geometry POINT (-105.06703 40.11313)
# 196 postgis_fi 193.0
# 196 lat_y_dd 40.372327
# 196 long_x_dd -104.443097
# 196 lastsurvey 2010-10-26
# 196 recentspec Red-tail Hawk
# 196 recentstat ACTIVE NEST
# 196 Nest_ID 193
# 196 geometry POINT (-104.45843 40.41029)
# 197 postgis_fi 194.0
# 197 lat_y_dd 40.371026
# 197 long_x_dd -104.449951
# 197 lastsurvey 2010-10-26
# 197 recentspec Swainsons Hawk
# 197 recentstat FLEDGED NEST
# 197 Nest_ID 194
# 197 geometry POINT (-104.43838 40.33633)
# 198 postgis_fi 195.0
# 198 lat_y_dd 40.131129
# 198 long_x_dd -104.668929
# 198 lastsurvey 2010-10-26
# 198 recentspec Red-tail Hawk
# 198 recentstat FLEDGED NEST
# 198 Nest_ID 195
# 198 geometry POINT (-104.7198 40.15161)
# 199 postgis_fi 196.0
# 199 lat_y_dd 40.112731
# 199 long_x_dd -104.948514
# 199 lastsurvey 2011-04-06
# 199 recentspec Red-tail Hawk
# 199 recentstat ACTIVE NEST
# 199 Nest_ID 196
# 199 geometry POINT (-104.91655 40.09337)
# 200 postgis_fi 197.0
# 200 lat_y_dd 40.061725
# 200 long_x_dd -104.848436
# 200 lastsurvey 2011-04-06
# 200 recentspec Swainsons Hawk
# 200 recentstat ACTIVE NEST
# 200 Nest_ID 197
# 200 geometry POINT (-104.90909 40.09074)
# 201 postgis_fi 198.0
# 201 lat_y_dd 40.113723
# 201 long_x_dd -104.949271
# 201 lastsurvey 2011-04-06
# 201 recentspec Red-tail Hawk
# 201 recentstat ACTIVE NEST
# 201 Nest_ID 198
# 201 geometry POINT (-104.89801 40.11342)
# 202 postgis_fi 199.0
# 202 lat_y_dd 40.172293
# 202 long_x_dd -104.784592
# 202 lastsurvey 2011-04-06
# 202 recentspec Red-tail Hawk
# 202 recentstat INACTIVE NEST
# 202 Nest_ID 199
# 202 geometry POINT (-104.8704 40.13612)
# 203 postgis_fi 200.0
# 203 lat_y_dd 40.126929
# 203 long_x_dd -104.814651
# 203 lastsurvey 2011-04-06
# 203 recentspec Red-tail Hawk
# 203 recentstat INACTIVE NEST
# 203 Nest_ID 200
# 203 geometry POINT (-104.76846 40.11321)
# 204 postgis_fi 201.0
# 204 lat_y_dd 40.145757
# 204 long_x_dd -104.779728
# 204 lastsurvey 2011-04-06
# 204 recentspec Swainsons Hawk
# 204 recentstat INACTIVE NEST
# 204 Nest_ID 201
# 204 geometry POINT (-104.75637 40.14731)
# 205 postgis_fi 202.0
# 205 lat_y_dd 40.268263
# 205 long_x_dd -104.743564
# 205 lastsurvey 2011-04-06
# 205 recentspec Swainsons Hawk
# 205 recentstat INACTIVE NEST
# 205 Nest_ID 202
# 205 geometry POINT (-104.66766 40.2258)
# 206 postgis_fi 203.0
# 206 lat_y_dd 40.150653
# 206 long_x_dd -104.980521
# 206 lastsurvey 2011-04-06
# 206 recentspec Red-tail Hawk
# 206 recentstat ACTIVE NEST
# 206 Nest_ID 203
# 206 geometry POINT (-105.04248 40.22027)
# 207 postgis_fi 204.0
# 207 lat_y_dd 40.152757
# 207 long_x_dd -104.815532
# 207 lastsurvey 2011-04-06
# 207 recentspec Red-tail Hawk
# 207 recentstat INACTIVE NEST
# 207 Nest_ID 204
# 207 geometry POINT (-104.86334 40.21205)
# 208 postgis_fi 205.0
# 208 lat_y_dd 40.148665
# 208 long_x_dd -104.826989
# 208 lastsurvey 2011-04-06
# 208 recentspec Red-tail Hawk
# 208 recentstat INACTIVE NEST
# 208 Nest_ID 205
# 208 geometry POINT (-104.8047 40.08208)
# 209 postgis_fi 206.0
# 209 lat_y_dd 40.147341
# 209 long_x_dd -104.825788
# 209 lastsurvey 2011-04-06
# 209 recentspec Red-tail Hawk
# 209 recentstat INACTIVE NEST
# 209 Nest_ID 206
# 209 geometry POINT (-104.81832 40.1991)
# 210 postgis_fi 207.0
# 210 lat_y_dd 40.134698
# 210 long_x_dd -104.828673
# 210 lastsurvey 2011-04-06
# 210 recentspec Swainsons Hawk
# 210 recentstat ACTIVE NEST
# 210 Nest_ID 207
# 210 geometry POINT (-104.82777 40.12576)
# 211 postgis_fi 208.0
# 211 lat_y_dd 40.14708
# 211 long_x_dd -104.834212
# 211 lastsurvey 2011-04-06
# 211 recentspec Red-tail Hawk
# 211 recentstat INACTIVE NEST
# 211 Nest_ID 208
# 211 geometry POINT (-104.77567 40.21635)
# 212 postgis_fi 209.0
# 212 lat_y_dd 40.13957
# 212 long_x_dd -104.825099
# 212 lastsurvey 2011-04-06
# 212 recentspec Red-tail Hawk
# 212 recentstat INACTIVE NEST
# 212 Nest_ID 209
# 212 geometry POINT (-104.86175 40.12318)
# 213 postgis_fi 210.0
# 213 lat_y_dd 40.128951
# 213 long_x_dd -104.774438
# 213 lastsurvey 2014-08-13
# 213 recentspec Red-tail Hawk
# 213 recentstat INACTIVE NEST
# 213 Nest_ID 210
# 213 geometry POINT (-104.73089 40.08466)
# 214 postgis_fi 211.0
# 214 lat_y_dd 40.122824
# 214 long_x_dd -104.709241
# 214 lastsurvey 2011-04-06
# 214 recentspec Red-tail Hawk
# 214 recentstat INACTIVE NEST
# 214 Nest_ID 211
# 214 geometry POINT (-104.78983 40.12918)
# 215 postgis_fi 212.0
# 215 lat_y_dd 40.121872
# 215 long_x_dd -104.709205
# 215 lastsurvey 2011-04-06
# 215 recentspec Red-tail Hawk
# 215 recentstat FLEDGED NEST
# 215 Nest_ID 212
# 215 geometry POINT (-104.69793 40.19232)
# 216 postgis_fi 213.0
# 216 lat_y_dd 40.123081
# 216 long_x_dd -104.709844
# 216 lastsurvey 2011-04-06
# 216 recentspec Swainsons Hawk
# 216 recentstat INACTIVE NEST
# 216 Nest_ID 213
# 216 geometry POINT (-104.65041 40.1693)
# 217 postgis_fi 214.0
# 217 lat_y_dd 40.125323
# 217 long_x_dd -104.715126
# 217 lastsurvey 2011-04-06
# 217 recentspec Red-tail Hawk
# 217 recentstat ACTIVE NEST
# 217 Nest_ID 214
# 217 geometry POINT (-104.6936 40.11083)
# 218 postgis_fi 215.0
# 218 lat_y_dd 40.150356
# 218 long_x_dd -104.727755
# 218 lastsurvey 2015-07-17
# 218 recentspec Swainsons Hawk
# 218 recentstat INACTIVE NEST
# 218 Nest_ID 215
# 218 geometry POINT (-104.78471 40.11843)
# 219 postgis_fi 216.0
# 219 lat_y_dd 40.153737
# 219 long_x_dd -104.734575
# 219 lastsurvey 2011-04-06
# 219 recentspec Swainsons Hawk
# 219 recentstat ACTIVE NEST
# 219 Nest_ID 216
# 219 geometry POINT (-104.75618 40.15758)
# 220 postgis_fi 217.0
# 220 lat_y_dd 40.187351
# 220 long_x_dd -104.696651
# 220 lastsurvey 2011-04-06
# 220 recentspec Red-tail Hawk
# 220 recentstat INACTIVE NEST
# 220 Nest_ID 217
# 220 geometry POINT (-104.7882 40.13419)
# 221 postgis_fi 218.0
# 221 lat_y_dd 40.131003
# 221 long_x_dd -104.819187
# 221 lastsurvey 2011-04-06
# 221 recentspec Red-tail Hawk
# 221 recentstat FLEDGED NEST
# 221 Nest_ID 218
# 221 geometry POINT (-104.90224 40.09308)
# 222 postgis_fi 219.0
# 222 lat_y_dd 40.247995
# 222 long_x_dd -104.709889
# 222 lastsurvey 2011-04-06
# 222 recentspec Red-tail Hawk
# 222 recentstat INACTIVE NEST
# 222 Nest_ID 219
# 222 geometry POINT (-104.80145 40.30365)
# 223 postgis_fi 220.0
# 223 lat_y_dd 40.20476
# 223 long_x_dd -104.731688
# 223 lastsurvey 2014-07-09
# 223 recentspec Swainsons Hawk
# 223 recentstat INACTIVE NEST
# 223 Nest_ID 220
# 223 geometry POINT (-104.65619 40.26741)
# 224 postgis_fi 221.0
# 224 lat_y_dd 40.203464
# 224 long_x_dd -104.764686
# 224 lastsurvey 2011-04-06
# 224 recentspec Swainsons Hawk
# 224 recentstat INACTIVE NEST
# 224 Nest_ID 221
# 224 geometry POINT (-104.76316 40.22673)
# 225 postgis_fi 222.0
# 225 lat_y_dd 40.209897
# 225 long_x_dd -104.772162
# 225 lastsurvey 2014-06-10
# 225 recentspec Swainsons Hawk
# 225 recentstat FLEDGED NEST
# 225 Nest_ID 222
# 225 geometry POINT (-104.83038 40.27413)
# 226 postgis_fi 223.0
# 226 lat_y_dd 40.196331
# 226 long_x_dd -104.777856
# 226 lastsurvey 2011-04-06
# 226 recentspec Red-tail Hawk
# 226 recentstat INACTIVE NEST
# 226 Nest_ID 223
# 226 geometry POINT (-104.70182 40.12719)
# 227 postgis_fi 224.0
# 227 lat_y_dd 40.287577
# 227 long_x_dd -104.658659
# 227 lastsurvey 2011-04-06
# 227 recentspec Red-tail Hawk
# 227 recentstat INACTIVE NEST
# 227 Nest_ID 224
# 227 geometry POINT (-104.61904 40.29743)
# 228 postgis_fi 225.0
# 228 lat_y_dd 40.321585
# 228 long_x_dd -104.902831
# 228 lastsurvey 2011-04-06
# 228 recentspec Swainsons Hawk
# 228 recentstat INACTIVE NEST
# 228 Nest_ID 225
# 228 geometry POINT (-104.81706 40.3174)
# 229 postgis_fi 226.0
# 229 lat_y_dd 40.26126
# 229 long_x_dd -104.83005
# 229 lastsurvey 2011-04-06
# 229 recentspec Swainsons Hawk
# 229 recentstat INACTIVE NEST
# 229 Nest_ID 226
# 229 geometry POINT (-104.89886 40.30126)
# 230 postgis_fi 227.0
# 230 lat_y_dd 40.134202
# 230 long_x_dd -104.846785
# 230 lastsurvey 2011-04-06
# 230 recentspec Swainsons Hawk
# 230 recentstat FLEDGED NEST
# 230 Nest_ID 227
# 230 geometry POINT (-104.8052 40.15268)
# 231 postgis_fi 228.0
# 231 lat_y_dd 40.303645
# 231 long_x_dd -104.639123
# 231 lastsurvey 2011-04-06
# 231 recentspec Red-tail Hawk
# 231 recentstat INACTIVE NEST
# 231 Nest_ID 228
# 231 geometry POINT (-104.64396 40.30093)
# 232 postgis_fi 229.0
# 232 lat_y_dd 40.287961
# 232 long_x_dd -104.657788
# 232 lastsurvey 2011-04-06
# 232 recentspec Swainsons Hawk
# 232 recentstat INACTIVE NEST
# 232 Nest_ID 229
# 232 geometry POINT (-104.71123 40.27445)
# 233 postgis_fi 230.0
# 233 lat_y_dd 40.139559
# 233 long_x_dd -104.674827
# 233 lastsurvey 2015-03-19
# 233 recentspec Red-tail Hawk
# 233 recentstat ACTIVE NEST
# 233 Nest_ID 230
# 233 geometry POINT (-104.71889 40.13759)
# 234 postgis_fi 231.0
# 234 lat_y_dd 40.182995
# 234 long_x_dd -104.976268
# 234 lastsurvey 2011-04-06
# 234 recentspec Red-tail Hawk
# 234 recentstat FLEDGED NEST
# 234 Nest_ID 231
# 234 geometry POINT (-104.90873 40.1582)
# 235 postgis_fi 232.0
# 235 lat_y_dd 40.311822
# 235 long_x_dd -104.598844
# ...
# 803 lat_y_dd 40.057304
# 803 long_x_dd -104.821032
# 803 lastsurvey 2015-02-12
# 803 recentspec Swainsons Hawk
# 803 recentstat INACTIVE NEST
# 803 Nest_ID 839
# 803 geometry POINT (-104.84752 40.11711)
# 804 postgis_fi 840.0
# 804 lat_y_dd 40.139296
# 804 long_x_dd -104.993893
# 804 lastsurvey 2015-02-18
# 804 recentspec Red-tail Hawk
# 804 recentstat INACTIVE NEST
# 804 Nest_ID 840
# 804 geometry POINT (-104.93848 40.16313)
# 805 postgis_fi 841.0
# 805 lat_y_dd 40.151933
# 805 long_x_dd -104.980898
# 805 lastsurvey 2015-02-20
# 805 recentspec Swainsons Hawk
# 805 recentstat INACTIVE NEST
# 805 Nest_ID 841
# 805 geometry POINT (-104.99521 40.11863)
# 806 postgis_fi 842.0
# 806 lat_y_dd 40.014175
# 806 long_x_dd -105.126386
# 806 lastsurvey 2015-02-20
# 806 recentspec Swainsons Hawk
# 806 recentstat FLEDGED NEST
# 806 Nest_ID 842
# 806 geometry POINT (-105.17925 40.0679)
# 807 postgis_fi 843.0
# 807 lat_y_dd 40.007517
# 807 long_x_dd -105.119596
# 807 lastsurvey 2015-02-20
# 807 recentspec Red-tail Hawk
# 807 recentstat INACTIVE NEST
# 807 Nest_ID 843
# 807 geometry POINT (-105.13401 39.93887)
# 808 postgis_fi 844.0
# 808 lat_y_dd 40.014859
# 808 long_x_dd -105.11541
# 808 lastsurvey 2015-02-20
# 808 recentspec Red-tail Hawk
# 808 recentstat INACTIVE NEST
# 808 Nest_ID 844
# 808 geometry POINT (-105.20091 40.03907)
# 809 postgis_fi 845.0
# 809 lat_y_dd 40.010111
# 809 long_x_dd -105.121219
# 809 lastsurvey 2015-02-20
# 809 recentspec Red-tail Hawk
# 809 recentstat FLEDGED NEST
# 809 Nest_ID 845
# 809 geometry POINT (-105.08961 39.98107)
# 810 postgis_fi 846.0
# 810 lat_y_dd 40.009698
# 810 long_x_dd -105.113618
# 810 lastsurvey 2015-02-20
# 810 recentspec Swainsons Hawk
# 810 recentstat INACTIVE NEST
# 810 Nest_ID 846
# 810 geometry POINT (-105.09268 39.94469)
# 811 postgis_fi 847.0
# 811 lat_y_dd 40.055237
# 811 long_x_dd -104.986777
# 811 lastsurvey 2015-02-24
# 811 recentspec Swainsons Hawk
# 811 recentstat FLEDGED NEST
# 811 Nest_ID 847
# 811 geometry POINT (-105.01906 40.00125)
# 812 postgis_fi 848.0
# 812 lat_y_dd 40.140663
# 812 long_x_dd -104.676056
# 812 lastsurvey 2015-03-19
# 812 recentspec Red-tail Hawk
# 812 recentstat INACTIVE NEST
# 812 Nest_ID 848
# 812 geometry POINT (-104.7536 40.20598)
# 813 postgis_fi 849.0
# 813 lat_y_dd 40.125167
# 813 long_x_dd -104.669795
# 813 lastsurvey 2015-07-09
# 813 recentspec Swainsons Hawk
# 813 recentstat FLEDGED NEST
# 813 Nest_ID 849
# 813 geometry POINT (-104.6928 40.13614)
# 814 postgis_fi 851.0
# 814 lat_y_dd 40.145773
# 814 long_x_dd -104.841214
# 814 lastsurvey 2015-06-12
# 814 recentspec Red-tail Hawk
# 814 recentstat FLEDGED NEST
# 814 Nest_ID 851
# 814 geometry POINT (-104.90825 40.17937)
# 815 postgis_fi 852.0
# 815 lat_y_dd 40.144499
# 815 long_x_dd -104.839908
# 815 lastsurvey 2015-06-12
# 815 recentspec Red-tail Hawk
# 815 recentstat INACTIVE NEST
# 815 Nest_ID 852
# 815 geometry POINT (-104.76546 40.15663)
# 816 postgis_fi 853.0
# 816 lat_y_dd 40.145211
# 816 long_x_dd -104.83618
# 816 lastsurvey 2015-03-13
# 816 recentspec Red-tail Hawk
# 816 recentstat INACTIVE NEST
# 816 Nest_ID 853
# 816 geometry POINT (-104.89834 40.11963)
# 817 postgis_fi 854.0
# 817 lat_y_dd 40.139674
# 817 long_x_dd -104.836056
# 817 lastsurvey 2015-03-13
# 817 recentspec Swainsons Hawk
# 817 recentstat ACTIVE NEST
# 817 Nest_ID 854
# 817 geometry POINT (-104.88898 40.12566)
# 818 postgis_fi 855.0
# 818 lat_y_dd 40.131117
# 818 long_x_dd -104.745545
# 818 lastsurvey 2015-03-16
# 818 recentspec Swainsons Hawk
# 818 recentstat ACTIVE NEST
# 818 Nest_ID 855
# 818 geometry POINT (-104.68922 40.09929)
# 819 postgis_fi 856.0
# 819 lat_y_dd 40.211016
# 819 long_x_dd -104.599269
# 819 lastsurvey 2015-05-22
# 819 recentspec Swainsons Hawk
# 819 recentstat COULD NOT SEE NEST
# 819 Nest_ID 856
# 819 geometry POINT (-104.55478 40.14262)
# 820 postgis_fi 857.0
# 820 lat_y_dd 40.498638
# 820 long_x_dd -105.10217
# 820 lastsurvey 2015-03-18
# 820 recentspec Red-tail Hawk
# 820 recentstat ACTIVE NEST
# 820 Nest_ID 857
# 820 geometry POINT (-105.07142 40.54964)
# 821 postgis_fi 858.0
# 821 lat_y_dd 40.416655
# 821 long_x_dd -105.129483
# 821 lastsurvey 2015-03-18
# 821 recentspec Swainsons Hawk
# 821 recentstat FLEDGED NEST
# 821 Nest_ID 858
# 821 geometry POINT (-105.14924 40.46454)
# 822 postgis_fi 859.0
# 822 lat_y_dd 40.058621
# 822 long_x_dd -104.62285
# 822 lastsurvey 2015-04-16
# 822 recentspec Red-tail Hawk
# 822 recentstat FLEDGED NEST
# 822 Nest_ID 859
# 822 geometry POINT (-104.68596 40.07383)
# 823 postgis_fi 860.0
# 823 lat_y_dd 40.058602
# 823 long_x_dd -104.612157
# 823 lastsurvey 2015-03-19
# 823 recentspec Red-tail Hawk
# 823 recentstat ACTIVE NEST
# 823 Nest_ID 860
# 823 geometry POINT (-104.60278 40.08161)
# 824 postgis_fi 861.0
# 824 lat_y_dd 40.163707
# 824 long_x_dd -104.703622
# 824 lastsurvey 2015-03-23
# 824 recentspec Red-tail Hawk
# 824 recentstat INACTIVE NEST
# 824 Nest_ID 861
# 824 geometry POINT (-104.63891 40.12857)
# 825 postgis_fi 862.0
# 825 lat_y_dd 40.167149
# 825 long_x_dd -104.701369
# 825 lastsurvey 2015-03-23
# 825 recentspec Red-tail Hawk
# 825 recentstat ACTIVE NEST
# 825 Nest_ID 862
# 825 geometry POINT (-104.73128 40.19092)
# 826 postgis_fi 863.0
# 826 lat_y_dd 40.167166
# 826 long_x_dd -104.700325
# 826 lastsurvey 2015-03-23
# 826 recentspec Red-tail Hawk
# 826 recentstat INACTIVE NEST
# 826 Nest_ID 863
# 826 geometry POINT (-104.74839 40.18424)
# 827 postgis_fi 864.0
# 827 lat_y_dd 40.218405
# 827 long_x_dd -104.980569
# 827 lastsurvey 2015-07-27
# 827 recentspec Red-tail Hawk
# 827 recentstat FLEDGED NEST
# 827 Nest_ID 864
# 827 geometry POINT (-105.06553 40.17014)
# 828 postgis_fi 865.0
# 828 lat_y_dd 40.192682
# 828 long_x_dd -104.880386
# 828 lastsurvey 2015-06-03
# 828 recentspec Red-tail Hawk
# 828 recentstat ACTIVE NEST
# 828 Nest_ID 865
# 828 geometry POINT (-104.95442 40.14821)
# 829 postgis_fi 866.0
# 829 lat_y_dd 40.153187
# 829 long_x_dd -104.8346
# 829 lastsurvey 2015-05-13
# 829 recentspec Swainsons Hawk
# 829 recentstat ACTIVE NEST
# 829 Nest_ID 866
# 829 geometry POINT (-104.83995 40.13489)
# 830 postgis_fi 867.0
# 830 lat_y_dd 40.154771
# 830 long_x_dd -104.832801
# 830 lastsurvey 2015-05-13
# 830 recentspec Red-tail Hawk
# 830 recentstat ACTIVE NEST
# 830 Nest_ID 867
# 830 geometry POINT (-104.80713 40.19204)
# 831 postgis_fi 868.0
# 831 lat_y_dd 40.159337
# 831 long_x_dd -104.730777
# 831 lastsurvey 2015-06-02
# 831 recentspec Red-tail Hawk
# 831 recentstat INACTIVE NEST
# 831 Nest_ID 868
# 831 geometry POINT (-104.79555 40.08931)
# 832 postgis_fi 869.0
# 832 lat_y_dd 40.128012
# 832 long_x_dd -104.675725
# 832 lastsurvey 2015-04-29
# 832 recentspec Swainsons Hawk
# 832 recentstat INACTIVE NEST
# 832 Nest_ID 869
# 832 geometry POINT (-104.67358 40.16967)
# 833 postgis_fi 870.0
# 833 lat_y_dd 40.12105
# 833 long_x_dd -104.678276
# 833 lastsurvey 2015-04-29
# 833 recentspec Red-tail Hawk
# 833 recentstat ACTIVE NEST
# 833 Nest_ID 870
# 833 geometry POINT (-104.65542 40.12024)
# 834 postgis_fi 871.0
# 834 lat_y_dd 40.132081
# 834 long_x_dd -104.676521
# 834 lastsurvey 2015-04-29
# 834 recentspec Swainsons Hawk
# 834 recentstat ACTIVE NEST
# 834 Nest_ID 871
# 834 geometry POINT (-104.68749 40.1987)
# 835 postgis_fi 872.0
# 835 lat_y_dd 40.135098
# 835 long_x_dd -104.970502
# 835 lastsurvey 2015-07-29
# 835 recentspec Swainsons Hawk
# 835 recentstat FLEDGED NEST
# 835 Nest_ID 872
# 835 geometry POINT (-105.04937 40.13417)
# 836 postgis_fi 873.0
# 836 lat_y_dd 40.142579
# 836 long_x_dd -104.975146
# 836 lastsurvey 2015-07-29
# 836 recentspec Swainsons Hawk
# 836 recentstat ACTIVE NEST
# 836 Nest_ID 873
# 836 geometry POINT (-105.06517 40.1029)
# 837 postgis_fi 874.0
# 837 lat_y_dd 40.118346
# 837 long_x_dd -104.993852
# 837 lastsurvey 2015-07-29
# 837 recentspec Swainsons Hawk
# 837 recentstat ACTIVE NEST
# 837 Nest_ID 874
# 837 geometry POINT (-104.99311 40.14737)
# 838 postgis_fi 875.0
# 838 lat_y_dd 40.10994
# 838 long_x_dd -104.983845
# 838 lastsurvey 2015-07-29
# 838 recentspec Swainsons Hawk
# 838 recentstat INACTIVE NEST
# 838 Nest_ID 875
# 838 geometry POINT (-104.93318 40.10669)
# 839 postgis_fi 876.0
# 839 lat_y_dd 40.110156
# 839 long_x_dd -104.983312
# 839 lastsurvey 2015-07-29
# 839 recentspec Red-tail Hawk
# 839 recentstat FLEDGED NEST
# 839 Nest_ID 876
# 839 geometry POINT (-104.90706 40.04251)
# 840 postgis_fi 877.0
# 840 lat_y_dd 40.064131
# 840 long_x_dd -104.670375
# 840 lastsurvey 2015-07-29
# 840 recentspec Swainsons Hawk
# 840 recentstat INACTIVE NEST
# 840 Nest_ID 877
# 840 geometry POINT (-104.72305 40.06901)
# 841 postgis_fi 878.0
# 841 lat_y_dd 40.073284
# 841 long_x_dd -104.682972
# 841 lastsurvey 2015-07-29
# 841 recentspec Red-tail Hawk
# 841 recentstat INACTIVE NEST
# 841 Nest_ID 878
# 841 geometry POINT (-104.59907 40.07846)
# 842 postgis_fi 879.0
# 842 lat_y_dd 40.08895
# 842 long_x_dd -104.896209
# 842 lastsurvey 2015-08-11
# 842 recentspec Red-tail Hawk
# 842 recentstat FLEDGED NEST
# 842 Nest_ID 879
# 842 geometry POINT (-104.86851 40.11922)
# 843 postgis_fi 880.0
# 843 lat_y_dd 40.074107
# 843 long_x_dd -104.688067
# 843 lastsurvey 2015-07-09
# 843 recentspec Red-tail Hawk
# 843 recentstat INACTIVE NEST
# 843 Nest_ID 880
# 843 geometry POINT (-104.75285 40.00713)
# 844 postgis_fi 881.0
# 844 lat_y_dd 40.162751
# 844 long_x_dd -104.73058
# 844 lastsurvey 2015-05-28
# 844 recentspec Swainsons Hawk
# 844 recentstat ACTIVE NEST
# 844 Nest_ID 881
# 844 geometry POINT (-104.69085 40.09987)
# 845 postgis_fi 882.0
# 845 lat_y_dd 40.04562
# 845 long_x_dd -104.908517
# 845 lastsurvey 2015-05-22
# 845 recentspec Red-tail Hawk
# 845 recentstat ACTIVE NEST
# 845 Nest_ID 882
# 845 geometry POINT (-104.9876 40.0091)
# 846 postgis_fi 883.0
# 846 lat_y_dd 40.1099
# 846 long_x_dd -104.879429
# 846 lastsurvey 2015-08-14
# 846 recentspec Red-tail Hawk
# 846 recentstat FLEDGED NEST
# 846 Nest_ID 883
# 846 geometry POINT (-104.88351 40.06975)
# 847 postgis_fi 884.0
# 847 lat_y_dd 40.068421
# 847 long_x_dd -104.862728
# 847 lastsurvey 2015-06-03
# 847 recentspec Red-tail Hawk
# 847 recentstat ACTIVE NEST
# 847 Nest_ID 884
# 847 geometry POINT (-104.91311 40.00704)
# 848 postgis_fi 885.0
# 848 lat_y_dd 40.189083
# 848 long_x_dd -104.865355
# 848 lastsurvey 2015-06-05
# 848 recentspec Red-tail Hawk
# 848 recentstat ACTIVE NEST
# 848 Nest_ID 885
# 848 geometry POINT (-104.92905 40.24316)
# 849 postgis_fi 886.0
# 849 lat_y_dd 39.988339
# 849 long_x_dd -105.067373
# 849 lastsurvey 2015-06-11
# 849 recentspec Swainsons Hawk
# 849 recentstat ACTIVE NEST
# 849 Nest_ID 886
# 849 geometry POINT (-105.15664 39.92748)
# 850 postgis_fi 887.0
# 850 lat_y_dd 39.986753
# 850 long_x_dd -105.067144
# 850 lastsurvey 2015-06-11
# 850 recentspec Swainsons Hawk
# 850 recentstat INACTIVE NEST
# 850 Nest_ID 887
# 850 geometry POINT (-105.0972 39.99392)
# 851 postgis_fi 888.0
# 851 lat_y_dd 39.986721
# 851 long_x_dd -105.066816
# 851 lastsurvey 2015-06-11
# 851 recentspec Red-tail Hawk
# 851 recentstat INACTIVE NEST
# 851 Nest_ID 888
# 851 geometry POINT (-105.02362 39.99817)
# 852 postgis_fi 889.0
# 852 lat_y_dd 39.986176
# 852 long_x_dd -105.065648
# 852 lastsurvey 2015-06-11
# 852 recentspec Red-tail Hawk
# 852 recentstat INACTIVE NEST
# 852 Nest_ID 889
# 852 geometry POINT (-105.08037 40.03062)
# 853 postgis_fi 890.0
# 853 lat_y_dd 40.130182
# 853 long_x_dd -104.654085
# 853 lastsurvey 2015-07-28
# 853 recentspec Swainsons Hawk
# 853 recentstat INACTIVE NEST
# 853 Nest_ID 890
# 853 geometry POINT (-104.71035 40.13155)
# 854 postgis_fi 891.0
# 854 lat_y_dd 39.953605
# 854 long_x_dd -104.845677
# 854 lastsurvey 2015-08-24
# 854 recentspec Red-tail Hawk
# 854 recentstat FLEDGED NEST
# 854 Nest_ID 891
# 854 geometry POINT (-104.89861 39.99438)
# 855 postgis_fi 892.0
# 855 lat_y_dd 39.947835
# 855 long_x_dd -104.847082
# 855 lastsurvey 2015-08-04
# 855 recentspec Swainsons Hawk
# 855 recentstat INACTIVE NEST
# 855 Nest_ID 892
# 855 geometry POINT (-104.78362 39.93726)
# 856 postgis_fi 893.0
# 856 lat_y_dd 40.15454
# 856 long_x_dd -104.841188
# 856 lastsurvey 2015-07-30
# 856 recentspec Red-tail Hawk
# 856 recentstat INACTIVE NEST
# 856 Nest_ID 893
# 856 geometry POINT (-104.84911 40.09943)
# 857 postgis_fi 894.0
# 857 lat_y_dd 40.154797
# 857 long_x_dd -104.841198
# 857 lastsurvey 2015-07-30
# 857 recentspec Red-tail Hawk
# 857 recentstat INACTIVE NEST
# 857 Nest_ID 894
# 857 geometry POINT (-104.77056 40.22599)
# 858 postgis_fi 895.0
# 858 lat_y_dd 40.204491
# 858 long_x_dd -104.662237
# 858 lastsurvey 2015-08-05
# 858 recentspec Swainsons Hawk
# 858 recentstat INACTIVE NEST
# 858 Nest_ID 895
# 858 geometry POINT (-104.64539 40.14265)
# 859 postgis_fi 896.0
# 859 lat_y_dd 39.975339
# 859 long_x_dd -104.94509
# 859 lastsurvey 2015-07-27
# 859 recentspec Swainsons Hawk
# 859 recentstat FLEDGED NEST
# 859 Nest_ID 896
# 859 geometry POINT (-104.92662 39.96089)
# 860 postgis_fi 897.0
# 860 lat_y_dd 40.417061
# 860 long_x_dd -104.800156
# 860 lastsurvey 2015-07-07
# 860 recentspec Red-tail Hawk
# 860 recentstat ACTIVE NEST
# 860 Nest_ID 897
# 860 geometry POINT (-104.72328 40.47858)
# 861 postgis_fi 898.0
# 861 lat_y_dd 40.188867
# 861 long_x_dd -105.005624
# 861 lastsurvey 2015-07-10
# 861 recentspec Red-tail Hawk
# 861 recentstat INACTIVE NEST
# 861 Nest_ID 898
# 861 geometry POINT (-104.94558 40.23595)
# 862 postgis_fi 899.0
# 862 lat_y_dd 40.187254
# 862 long_x_dd -105.005608
# 862 lastsurvey 2015-07-10
# 862 recentspec Swainsons Hawk
# 862 recentstat INACTIVE NEST
# 862 Nest_ID 899
# 862 geometry POINT (-104.97637 40.14121)
# 863 postgis_fi 900.0
# 863 lat_y_dd 40.169258
# 863 long_x_dd -104.889567
# 863 lastsurvey 2015-07-13
# 863 recentspec Swainsons Hawk
# 863 recentstat INACTIVE NEST
# 863 Nest_ID 900
# 863 geometry POINT (-104.90353 40.2323)
# 864 postgis_fi 901.0
# 864 lat_y_dd 40.04328
# 864 long_x_dd -105.017857
# 864 lastsurvey 2015-08-04
# 864 recentspec Red-tail Hawk
# 864 recentstat INACTIVE NEST
# 864 Nest_ID 901
# 864 geometry POINT (-104.94253 40.03679)
# 865 postgis_fi 902.0
# 865 lat_y_dd 40.04519
# 865 long_x_dd -104.727397
# 865 lastsurvey 2015-08-14
# 865 recentspec Swainsons Hawk
# 865 recentstat INACTIVE NEST
# 865 Nest_ID 902
# 865 geometry POINT (-104.63442 40.00987)
# 866 postgis_fi 903.0
# 866 lat_y_dd 40.04469
# 866 long_x_dd -104.726963
# 866 lastsurvey 2015-08-14
# 866 recentspec Red-tail Hawk
# 866 recentstat INACTIVE NEST
# 866 Nest_ID 903
# 866 geometry POINT (-104.72082 40.03216)
# 867 postgis_fi 904.0
# 867 lat_y_dd 40.044586
# 867 long_x_dd -104.727664
# 867 lastsurvey 2015-08-14
# 867 recentspec Red-tail Hawk
# 867 recentstat INACTIVE NEST
# 867 Nest_ID 904
# 867 geometry POINT (-104.78274 40.08121)
# 868 postgis_fi 905.0
# 868 lat_y_dd 40.056013
# 868 long_x_dd -104.761654
# 868 lastsurvey 2015-08-17
# 868 recentspec Red-tail Hawk
# 868 recentstat INACTIVE NEST
# 868 Nest_ID 905
# 868 geometry POINT (-104.83105 40.06771)
# 869 postgis_fi 906.0
# 869 lat_y_dd 40.051193
# 869 long_x_dd -104.794308
# 869 lastsurvey 2015-08-17
# 869 recentspec Red-tail Hawk
# 869 recentstat INACTIVE NEST
# 869 Nest_ID 906
# 869 geometry POINT (-104.76127 40.07742)
# 870 postgis_fi 907.0
# 870 lat_y_dd 39.995541
# 870 long_x_dd -104.891149
# 870 lastsurvey 2015-08-18
# 870 recentspec Red-tail Hawk
# 870 recentstat INACTIVE NEST
# 870 Nest_ID 907
# 870 geometry POINT (-104.81692 40.02965)
# 871 postgis_fi 908.0
# 871 lat_y_dd 39.996516
# 871 long_x_dd -104.891649
# 871 lastsurvey 2015-08-18
# 871 recentspec Red-tail Hawk
# 871 recentstat INACTIVE NEST
# 871 Nest_ID 908
# 871 geometry POINT (-104.93254 40.03877)
# 872 postgis_fi 909.0
# 872 lat_y_dd 39.999138
# 872 long_x_dd -104.899116
# 872 lastsurvey 2015-08-18
# 872 recentspec Swainsons Hawk
# 872 recentstat INACTIVE NEST
# 872 Nest_ID 909
# 872 geometry POINT (-104.91958 40.00116)
# 873 postgis_fi 910.0
# 873 lat_y_dd 40.002516
# 873 long_x_dd -104.893713
# 873 lastsurvey 2015-08-18
# 873 recentspec Red-tail Hawk
# 873 recentstat INACTIVE NEST
# 873 Nest_ID 910
# 873 geometry POINT (-104.83619 39.98674)
# 874 postgis_fi 911.0
# 874 lat_y_dd 40.00695
# 874 long_x_dd -104.89437
# 874 lastsurvey 2015-08-18
# 874 recentspec Red-tail Hawk
# 874 recentstat INACTIVE NEST
# 874 Nest_ID 911
# 874 geometry POINT (-104.98394 40.00297)
# 875 postgis_fi 912.0
# 875 lat_y_dd 39.998876
# 875 long_x_dd -104.900128
# 875 lastsurvey 2015-09-01
# 875 recentspec Red-tail Hawk
# 875 recentstat INACTIVE NEST
# 875 Nest_ID 912
# 875 geometry POINT (-104.84766 39.96975)
# 876 postgis_fi nan
# 876 lat_y_dd nan
# 876 long_x_dd nan
# 876 lastsurvey 2020-05-08
# 876 recentspec Northern Harrier
# 876 recentstat INACTIVE NEST
# 876 Nest_ID 9991
# 876 geometry POINT (-104.95039158280412 40.24431700148285)
# 877 postgis_fi nan
# 877 lat_y_dd nan
# 877 long_x_dd nan
# 877 lastsurvey 2020-05-05
# 877 recentspec SWHA
# 877 recentstat INACTIVE NEST
# 877 Nest_ID 1001
# 877 geometry POINT (-104.94501532785657 40.24442591598638)
# 878 postgis_fi nan
# 878 lat_y_dd 40.24386520326873
# 878 long_x_dd -104.9371695362882
# 878 lastsurvey None
# 878 recentspec RTHA
# 878 recentstat FLEDGED NEST
# 878 Nest_ID 1002
# 878 geometry POINT (-104.9371695362882 40.24386520326873)

# %% [markdown]
# ### iloc - referencing by integers
#
# shape property returns a tuple with the number of rows and columns

# %%
raptors.shape
# Out:
# (862, 8)

# %%
raptors.iloc[861, 4]
# Out:
# 'RTHA'

# %%
raptors.iloc[100:200, 2:4]
# Out:
#       long_x_dd  lastsurvey
# 102 -104.828065  2014-06-09
# 103 -104.827100  2008-04-25
# 104 -104.826561  2008-04-25
# 105 -104.824545  2008-04-25
# 106 -104.820562  2008-04-25
# ..          ...         ...
# 197 -104.449951  2010-10-26
# 198 -104.668929  2010-10-26
# 199 -104.948514  2011-04-06
# 200 -104.848436  2011-04-06
# 201 -104.949271  2011-04-06
#
# [100 rows x 2 columns]

# %%
raptors.iloc[[103, 197, 200], [1, 2, 5]]
# Out:
#       lat_y_dd   long_x_dd     recentstat
# 105  40.058384 -104.824545    ACTIVE NEST
# 199  40.112731 -104.948514    ACTIVE NEST
# 202  40.172293 -104.784592  INACTIVE NEST

# %%
for x in range(raptors.shape[0]):
    for y in range(raptors.shape[1]):
        print(x, y, raptors.iloc[x,y])
# Out:
# 0 0 361.0
# 0 1 40.267502
# 0 2 -104.870872
# 0 3 2012-03-16
# 0 4 Swainsons Hawk
# 0 5 INACTIVE NEST
# 0 6 361
# 0 7 POINT (-104.79595 40.29891)
# 1 0 362.0
# 1 1 40.264321
# 1 2 -104.860255
# 1 3 2012-03-16
# 1 4 Swainsons Hawk
# 1 5 INACTIVE NEST
# 1 6 362
# 1 7 POINT (-104.78897 40.22089)
# 2 0 2.0
# 2 1 40.309574
# 2 2 -104.932604
# 2 3 2011-01-06
# 2 4 Swainsons Hawk
# 2 5 INACTIVE NEST
# 2 6 2
# 2 7 POINT (-104.84889 40.35215)
# 3 0 3.0
# 3 1 40.219343
# 3 2 -104.729246
# 3 3 2014-07-03
# 3 4 Swainsons Hawk
# 3 5 ACTIVE NEST
# 3 6 3
# 3 7 POINT (-104.74466 40.18571)
# 4 0 4.0
# 4 1 40.217638
# 4 2 -104.779386
# 4 3 2011-01-06
# 4 4 Red-tail Hawk
# 4 5 FLEDGED NEST
# 4 6 4
# 4 7 POINT (-104.79963 40.15712)
# 5 0 5.0
# 5 1 40.271203
# 5 2 -104.740819
# 5 3 2011-01-06
# 5 4 Swainsons Hawk
# 5 5 INACTIVE NEST
# 5 6 5
# 5 7 POINT (-104.6679 40.26382)
# 6 0 6.0
# 6 1 40.357587
# 6 2 -104.737632
# 6 3 2011-01-06
# 6 4 Swainsons Hawk
# 6 5 ACTIVE NEST
# 6 6 6
# 6 7 POINT (-104.67679 40.30686)
# 7 0 7.0
# 7 1 40.35966
# 7 2 -104.730698
# 7 3 2011-01-06
# 7 4 Swainsons Hawk
# 7 5 FLEDGED NEST
# 7 6 7
# 7 7 POINT (-104.69146 40.3136)
# 8 0 8.0
# 8 1 40.358919
# 8 2 -104.725179
# 8 3 2011-01-06
# 8 4 Red-tail Hawk
# 8 5 INACTIVE NEST
# 8 6 8
# 8 7 POINT (-104.67825 40.41094)
# 9 0 9.0
# 9 1 40.000189
# 9 2 -104.860463
# 9 3 2011-01-06
# 9 4 Swainsons Hawk
# 9 5 FLEDGED NEST
# 9 6 9
# 9 7 POINT (-104.78548 39.96439)
# 10 0 10.0
# 10 1 40.198163
# 10 2 -104.918726
# 10 3 2011-01-06
# 10 4 Swainsons Hawk
# 10 5 INACTIVE NEST
# 10 6 10
# 10 7 POINT (-104.99879 40.20531)
# 11 0 11.0
# 11 1 40.033635
# 11 2 -104.833716
# 11 3 2011-01-06
# 11 4 Red-tail Hawk
# 11 5 INACTIVE NEST
# 11 6 11
# 11 7 POINT (-104.80748 40.03194)
# 12 0 12.0
# 12 1 40.327655
# 12 2 -104.574845
# 12 3 2011-01-06
# 12 4 Red-tail Hawk
# 12 5 INACTIVE NEST
# 12 6 12
# 12 7 POINT (-104.63061 40.32023)
# 13 0 13.0
# 13 1 40.220769
# 13 2 -104.731024
# 13 3 2014-07-24
# 13 4 Swainsons Hawk
# 13 5 INACTIVE NEST
# 13 6 13
# 13 7 POINT (-104.7683 40.22536)
# 14 0 14.0
# 14 1 40.12669
# 14 2 -105.020896
# 14 3 2011-01-06
# 14 4 Swainsons Hawk
# 14 5 ACTIVE NEST
# 14 6 14
# 14 7 POINT (-105.05943 40.19046)
# 15 0 15.0
# 15 1 40.225065
# 15 2 -104.627044
# 15 3 2011-01-06
# 15 4 Red-tail Hawk
# 15 5 FLEDGED NEST
# 15 6 15
# 15 7 POINT (-104.68345 40.28228)
# 16 0 371.0
# 16 1 40.18432
# 16 2 -104.77275
# 16 3 2012-03-23
# 16 4 Swainsons Hawk
# 16 5 FLEDGED NEST
# 16 6 371
# 16 7 POINT (-104.77275 40.18432)
# 17 0 913.0
# 17 1 40.138876
# 17 2 -104.976541
# 17 3 2015-09-10
# 17 4 Red-tail Hawk
# 17 5 INACTIVE NEST
# 17 6 913
# 17 7 POINT (-104.91296 40.1135)
# 18 0 914.0
# 18 1 40.140884
# 18 2 -104.951201
# 18 3 2015-09-10
# 18 4 Red-tail Hawk
# 18 5 INACTIVE NEST
# 18 6 914
# 18 7 POINT (-104.99814 40.1016)
# 19 0 915.0
# 19 1 40.131518
# 19 2 -104.963308
# 19 3 2015-09-10
# 19 4 Red-tail Hawk
# 19 5 INACTIVE NEST
# 19 6 915
# 19 7 POINT (-104.98495 40.1742)
# 20 0 916.0
# 20 1 40.131956
# 20 2 -104.959158
# 20 3 2015-09-10
# 20 4 Swainsons Hawk
# 20 5 INACTIVE NEST
# 20 6 916
# 20 7 POINT (-105.03582 40.19353)
# 21 0 917.0
# 21 1 40.368366
# 21 2 -104.963993
# 21 3 2015-10-14
# 21 4 Red-tail Hawk
# 21 5 INACTIVE NEST
# 21 6 917
# 21 7 POINT (-104.99776 40.42473)
# 22 0 918.0
# 22 1 40.357932
# 22 2 -104.965152
# 22 3 2015-10-14
# 22 4 Red-tail Hawk
# 22 5 INACTIVE NEST
# 22 6 918
# 22 7 POINT (-104.98967 40.42586)
# 23 0 919.0
# 23 1 40.35701
# 23 2 -104.963257
# 23 3 2015-10-14
# 23 4 Swainsons Hawk
# 23 5 INACTIVE NEST
# 23 6 919
# 23 7 POINT (-104.97197 40.4067)
# 24 0 16.0
# 24 1 40.243589
# 24 2 -104.730385
# 24 3 2011-01-06
# 24 4 Swainsons Hawk
# 24 5 ACTIVE NEST
# 24 6 16
# 24 7 POINT (-104.72963 40.2348)
# 25 0 17.0
# 25 1 40.185072
# 25 2 -104.844298
# 25 3 2011-01-06
# 25 4 Red-tail Hawk
# 25 5 ACTIVE NEST
# 25 6 17
# 25 7 POINT (-104.87677 40.23926)
# 26 0 18.0
# 26 1 40.240403
# 26 2 -104.860404
# 26 3 2011-01-06
# 26 4 Red-tail Hawk
# 26 5 INACTIVE NEST
# 26 6 18
# 26 7 POINT (-104.91238 40.29383)
# 27 0 19.0
# 27 1 40.226344
# 27 2 -104.850214
# 27 3 2011-01-06
# 27 4 Red-tail Hawk
# 27 5 ACTIVE NEST
# 27 6 19
# 27 7 POINT (-104.87695 40.21758)
# 28 0 20.0
# 28 1 40.229449
# 28 2 -104.8522
# 28 3 2011-01-06
# 28 4 Red-tail Hawk
# 28 5 ACTIVE NEST
# 28 6 20
# 28 7 POINT (-104.8872 40.16783)
# 29 0 21.0
# 29 1 40.301935
# 29 2 -104.947598
# 29 3 2011-01-06
# 29 4 Swainsons Hawk
# 29 5 INACTIVE NEST
# 29 6 21
# 29 7 POINT (-104.98418 40.30175)
# 30 0 22.0
# 30 1 40.196557
# 30 2 -104.851282
# 30 3 2011-01-06
# 30 4 Swainsons Hawk
# 30 5 INACTIVE NEST
# 30 6 22
# 30 7 POINT (-104.77577 40.16702)
# 31 0 23.0
# 31 1 40.138615
# 31 2 -104.989487
# 31 3 2014-06-25
# 31 4 Swainsons Hawk
# 31 5 INACTIVE NEST
# 31 6 23
# 31 7 POINT (-104.95636 40.20921)
# 32 0 24.0
# 32 1 40.140795
# 32 2 -104.714801
# 32 3 2011-01-06
# 32 4 Red-tail Hawk
# 32 5 INACTIVE NEST
# 32 6 24
# 32 7 POINT (-104.78436 40.16182)
# 33 0 25.0
# 33 1 40.231893
# 33 2 -104.860162
# 33 3 2011-01-06
# 33 4 Red-tail Hawk
# 33 5 INACTIVE NEST
# 33 6 25
# 33 7 POINT (-104.94972 40.25426)
# 34 0 26.0
# 34 1 40.141795
# 34 2 -104.714559
# 34 3 2011-01-06
# 34 4 Swainsons Hawk
# 34 5 INACTIVE NEST
# 34 6 26
# 34 7 POINT (-104.65786 40.1207)
# 35 0 27.0
# 35 1 40.196828
# 35 2 -104.830056
# 35 3 2011-01-06
# 35 4 Red-tail Hawk
# 35 5 ACTIVE NEST
# 35 6 27
# 35 7 POINT (-104.76699 40.20147)
# 36 0 28.0
# 36 1 40.181554
# 36 2 -104.603392
# 36 3 2011-01-06
# 36 4 Red-tail Hawk
# 36 5 INACTIVE NEST
# 36 6 28
# 36 7 POINT (-104.52641 40.17562)
# 37 0 29.0
# 37 1 40.182014
# 37 2 -104.660659
# 37 3 2011-01-06
# 37 4 Red-tail Hawk
# 37 5 INACTIVE NEST
# 37 6 29
# 37 7 POINT (-104.69561 40.16848)
# 38 0 30.0
# 38 1 40.195063
# 38 2 -104.849572
# 38 3 2011-01-06
# 38 4 Swainsons Hawk
# 38 5 INACTIVE NEST
# 38 6 30
# 38 7 POINT (-104.85299 40.23548)
# 39 0 31.0
# 39 1 40.175037
# 39 2 -104.946548
# 39 3 2011-01-06
# 39 4 Swainsons Hawk
# 39 5 ACTIVE NEST
# 39 6 31
# 39 7 POINT (-105.00639 40.24032)
# 40 0 32.0
# 40 1 40.22518
# 40 2 -104.838378
# 40 3 2011-01-06
# 40 4 Red-tail Hawk
# 40 5 INACTIVE NEST
# 40 6 32
# 40 7 POINT (-104.83528 40.19825)
# 41 0 33.0
# 41 1 40.174755
# 41 2 -104.799249
# 41 3 2011-01-06
# 41 4 Red-tail Hawk
# 41 5 INACTIVE NEST
# 41 6 33
# 41 7 POINT (-104.79673 40.20553)
# 42 0 34.0
# 42 1 40.019042
# 42 2 -104.942779
# 42 3 2011-01-06
# 42 4 Red-tail Hawk
# 42 5 ACTIVE NEST
# 42 6 34
# 42 7 POINT (-104.91002 39.96346)
# 43 0 35.0
# 43 1 40.181961
# 43 2 -104.847581
# 43 3 2011-01-06
# 43 4 Red-tail Hawk
# 43 5 ACTIVE NEST
# 43 6 35
# 43 7 POINT (-104.83385 40.12341)
# 44 0 36.0
# 44 1 40.18421
# 44 2 -104.876609
# 44 3 2011-01-06
# 44 4 Swainsons Hawk
# 44 5 ACTIVE NEST
# 44 6 36
# 44 7 POINT (-104.82664 40.15769)
# 45 0 37.0
# 45 1 40.185009
# 45 2 -104.876566
# 45 3 2011-01-06
# 45 4 Red-tail Hawk
# 45 5 FLEDGED NEST
# 45 6 37
# 45 7 POINT (-104.96623 40.13452)
# 46 0 38.0
# 46 1 40.074776
# 46 2 -105.047018
# 46 3 2008-04-25
# 46 4 Red-tail Hawk
# 46 5 INACTIVE NEST
# 46 6 38
# 46 7 POINT (-104.98086 40.08121)
# 47 0 39.0
# 47 1 40.143726
# 47 2 -104.984522
# 47 3 2008-04-25
# 47 4 Red-tail Hawk
# 47 5 INACTIVE NEST
# 47 6 39
# 47 7 POINT (-105.05218 40.1003)
# 48 0 40.0
# 48 1 40.231198
# 48 2 -104.626507
# 48 3 2008-04-25
# 48 4 Red-tail Hawk
# 48 5 INACTIVE NEST
# 48 6 40
# 48 7 POINT (-104.60876 40.28215)
# 49 0 41.0
# 49 1 40.14024
# 49 2 -104.984017
# 49 3 2008-04-25
# 49 4 Red-tail Hawk
# 49 5 INACTIVE NEST
# 49 6 41
# 49 7 POINT (-105.0307 40.10774)
# 50 0 42.0
# 50 1 40.280158
# 50 2 -105.023386
# 50 3 2008-04-25
# 50 4 Swainsons Hawk
# 50 5 ACTIVE NEST
# 50 6 42
# 50 7 POINT (-105.01748 40.34794)
# 51 0 43.0
# 51 1 40.441386
# 51 2 -104.852749
# 51 3 2008-04-25
# 51 4 Swainsons Hawk
# 51 5 FLEDGED NEST
# 51 6 43
# 51 7 POINT (-104.79653 40.47682)
# 52 0 44.0
# 52 1 40.2483
# 52 2 -104.598365
# 52 3 2008-04-25
# 52 4 Red-tail Hawk
# 52 5 ACTIVE NEST
# 52 6 44
# 52 7 POINT (-104.52823 40.27316)
# 53 0 45.0
# 53 1 40.25945
# 53 2 -104.594912
# 53 3 2008-04-25
# 53 4 Red-tail Hawk
# 53 5 FLEDGED NEST
# 53 6 45
# 53 7 POINT (-104.64234 40.30311)
# 54 0 46.0
# 54 1 40.322534
# 54 2 -104.630024
# 54 3 2008-04-25
# 54 4 Swainsons Hawk
# 54 5 INACTIVE NEST
# 54 6 46
# 54 7 POINT (-104.59918 40.34821)
# 55 0 47.0
# 55 1 40.271404
# 55 2 -104.629232
# 55 3 2008-04-25
# 55 4 Swainsons Hawk
# 55 5 INACTIVE NEST
# 55 6 47
# 55 7 POINT (-104.60601 40.24514)
# 56 0 48.0
# 56 1 40.27624
# 56 2 -104.578685
# 56 3 2008-04-25
# 56 4 Red-tail Hawk
# 56 5 INACTIVE NEST
# 56 6 48
# 56 7 POINT (-104.58589 40.3014)
# 57 0 49.0
# 57 1 40.283779
# 57 2 -105.026692
# 57 3 2008-04-25
# 57 4 Red-tail Hawk
# 57 5 INACTIVE NEST
# 57 6 49
# 57 7 POINT (-104.98787 40.29486)
# 58 0 50.0
# 58 1 40.275573
# 58 2 -105.019373
# 58 3 2008-04-25
# 58 4 Red-tail Hawk
# 58 5 ACTIVE NEST
# 58 6 50
# 58 7 POINT (-104.99136 40.24572)
# 59 0 51.0
# 59 1 40.485335
# 59 2 -104.452276
# 59 3 2008-04-25
# 59 4 Swainsons Hawk
# 59 5 INACTIVE NEST
# 59 6 51
# 59 7 POINT (-104.53763 40.45225)
# 60 0 52.0
# 60 1 40.341314
# 60 2 -104.617747
# 60 3 2008-04-25
# 60 4 Red-tail Hawk
# 60 5 INACTIVE NEST
# 60 6 52
# 60 7 POINT (-104.57254 40.34041)
# 61 0 53.0
# 61 1 40.275542
# 61 2 -104.67526
# 61 3 2008-04-25
# 61 4 Swainsons Hawk
# 61 5 INACTIVE NEST
# 61 6 53
# 61 7 POINT (-104.63141 40.33613)
# 62 0 54.0
# 62 1 40.270743
# 62 2 -104.679423
# 62 3 2008-04-25
# 62 4 Swainsons Hawk
# 62 5 INACTIVE NEST
# 62 6 54
# 62 7 POINT (-104.7117 40.30232)
# 63 0 55.0
# 63 1 39.84752
# 63 2 -104.61775
# 63 3 2008-04-25
# 63 4 Swainsons Hawk
# 63 5 INACTIVE NEST
# 63 6 55
# 63 7 POINT (-104.54095 39.86113)
# 64 0 56.0
# 64 1 40.25559
# 64 2 -104.58366
# 64 3 2008-04-25
# 64 4 Swainsons Hawk
# 64 5 FLEDGED NEST
# 64 6 56
# 64 7 POINT (-104.621 40.27386)
# 65 0 57.0
# 65 1 40.58071
# 65 2 -104.50874
# 65 3 2008-04-25
# 65 4 Swainsons Hawk
# 65 5 INACTIVE NEST
# 65 6 57
# 65 7 POINT (-104.46596 40.57309)
# 66 0 58.0
# 66 1 40.53128
# 66 2 -104.83036
# 66 3 2008-04-25
# 66 4 Red-tail Hawk
# 66 5 INACTIVE NEST
# 66 6 58
# 66 7 POINT (-104.8295 40.48061)
# 67 0 59.0
# 67 1 40.53205
# 67 2 -104.65707
# 67 3 2008-04-25
# 67 4 Red-tail Hawk
# 67 5 INACTIVE NEST
# 67 6 59
# 67 7 POINT (-104.61477 40.48916)
# 68 0 61.0
# 68 1 40.283752
# 68 2 -105.026892
# 68 3 2008-04-25
# 68 4 Red-tail Hawk
# 68 5 INACTIVE NEST
# 68 6 61
# 68 7 POINT (-105.07959 40.35293)
# 69 0 62.0
# 69 1 40.116947
# 69 2 -105.036532
# 69 3 2008-04-25
# 69 4 Swainsons Hawk
# 69 5 INACTIVE NEST
# 69 6 62
# 69 7 POINT (-105.09585 40.1276)
# 70 0 63.0
# 70 1 40.362427
# 70 2 -104.764271
# 70 3 2008-04-25
# 70 4 Swainsons Hawk
# 70 5 FLEDGED NEST
# 70 6 63
# 70 7 POINT (-104.84195 40.36651)
# 71 0 64.0
# 71 1 40.121593
# 71 2 -105.005058
# 71 3 2008-04-25
# 71 4 Red-tail Hawk
# 71 5 INACTIVE NEST
# 71 6 64
# 71 7 POINT (-105.01954 40.1775)
# 72 0 65.0
# 72 1 40.486637
# 72 2 -104.451427
# 72 3 2008-04-25
# 72 4 Swainsons Hawk
# 72 5 INACTIVE NEST
# 72 6 65
# 72 7 POINT (-104.41929 40.52833)
# 73 0 66.0
# 73 1 40.201173
# 73 2 -104.907319
# 73 3 2008-04-25
# 73 4 Red-tail Hawk
# 73 5 FLEDGED NEST
# 73 6 66
# 73 7 POINT (-104.94201 40.16989)
# 74 0 67.0
# 74 1 40.200841
# 74 2 -104.909011
# 74 3 2008-04-25
# 74 4 Red-tail Hawk
# 74 5 INACTIVE NEST
# 74 6 67
# 74 7 POINT (-104.91275 40.22515)
# 75 0 68.0
# 75 1 40.179032
# 75 2 -104.831177
# 75 3 2008-04-25
# 75 4 Red-tail Hawk
# 75 5 ACTIVE NEST
# 75 6 68
# 75 7 POINT (-104.83712 40.12286)
# 76 0 69.0
# 76 1 40.048844
# 76 2 -104.831487
# 76 3 2008-04-25
# 76 4 Red-tail Hawk
# 76 5 FLEDGED NEST
# 76 6 69
# 76 7 POINT (-104.83891 40.05415)
# 77 0 70.0
# 77 1 40.168236
# 77 2 -104.623535
# 77 3 2008-04-25
# 77 4 Swainsons Hawk
# 77 5 INACTIVE NEST
# 77 6 70
# 77 7 POINT (-104.57744 40.11825)
# 78 0 71.0
# 78 1 40.161225
# 78 2 -104.631465
# 78 3 2014-09-04
# 78 4 Red-tail Hawk
# 78 5 ACTIVE NEST
# 78 6 71
# 78 7 POINT (-104.61912 40.17869)
# 79 0 72.0
# 79 1 40.157045
# 79 2 -104.620332
# 79 3 2008-04-25
# 79 4 Swainsons Hawk
# 79 5 INACTIVE NEST
# 79 6 72
# 79 7 POINT (-104.64093 40.08932)
# 80 0 73.0
# 80 1 40.155659
# 80 2 -104.620748
# 80 3 2008-04-25
# 80 4 Red-tail Hawk
# 80 5 INACTIVE NEST
# 80 6 73
# 80 7 POINT (-104.56071 40.20625)
# 81 0 75.0
# 81 1 40.135336
# 81 2 -104.61632
# 81 3 2008-04-25
# 81 4 Swainsons Hawk
# 81 5 INACTIVE NEST
# 81 6 75
# 81 7 POINT (-104.60701 40.0922)
# 82 0 76.0
# 82 1 40.313602
# 82 2 -104.933598
# 82 3 2008-04-25
# 82 4 Red-tail Hawk
# 82 5 ACTIVE NEST
# 82 6 76
# 82 7 POINT (-104.99521 40.36347)
# 83 0 77.0
# 83 1 40.256101
# 83 2 -104.971308
# 83 3 2008-04-25
# 83 4 Swainsons Hawk
# 83 5 INACTIVE NEST
# 83 6 77
# 83 7 POINT (-105.05676 40.32494)
# 84 0 78.0
# 84 1 40.225608
# 84 2 -104.848821
# 84 3 2008-04-25
# 84 4 Red-tail Hawk
# 84 5 FLEDGED NEST
# 84 6 78
# 84 7 POINT (-104.89094 40.29457)
# 85 0 79.0
# 85 1 40.064704
# 85 2 -104.847137
# 85 3 2008-04-25
# 85 4 Red-tail Hawk
# 85 5 FLEDGED NEST
# 85 6 79
# 85 7 POINT (-104.90728 40.12695)
# 86 0 80.0
# 86 1 40.0586
# 86 2 -104.836715
# 86 3 2008-04-25
# 86 4 Swainsons Hawk
# 86 5 ACTIVE NEST
# 86 6 80
# 86 7 POINT (-104.88378 40.11421)
# 87 0 81.0
# 87 1 40.06284
# 87 2 -104.834489
# 87 3 2008-04-25
# 87 4 Swainsons Hawk
# 87 5 INACTIVE NEST
# 87 6 81
# 87 7 POINT (-104.83552 40.10434)
# 88 0 82.0
# 88 1 40.038086
# 88 2 -104.831619
# 88 3 2008-04-25
# 88 4 Red-tail Hawk
# 88 5 ACTIVE NEST
# 88 6 82
# 88 7 POINT (-104.84902 40.06503)
# 89 0 83.0
# 89 1 40.048069
# 89 2 -104.831336
# 89 3 2008-04-25
# 89 4 Red-tail Hawk
# 89 5 INACTIVE NEST
# 89 6 83
# 89 7 POINT (-104.91765 40.01353)
# 90 0 84.0
# 90 1 40.062771
# 90 2 -104.830749
# 90 3 2008-04-25
# 90 4 Swainsons Hawk
# 90 5 INACTIVE NEST
# 90 6 84
# 90 7 POINT (-104.91904 40.09191)
# 91 0 85.0
# 91 1 40.06178
# 91 2 -104.830306
# 91 3 2008-04-25
# 91 4 Red-tail Hawk
# 91 5 ACTIVE NEST
# 91 6 85
# 91 7 POINT (-104.92033 40.00823)
# 92 0 86.0
# 92 1 40.050671
# 92 2 -104.830275
# 92 3 2008-04-25
# 92 4 Swainsons Hawk
# 92 5 ACTIVE NEST
# 92 6 86
# 92 7 POINT (-104.75313 39.99989)
# 93 0 87.0
# 93 1 40.046409
# 93 2 -104.830121
# 93 3 2008-04-25
# 93 4 Red-tail Hawk
# 93 5 INACTIVE NEST
# 93 6 87
# 93 7 POINT (-104.78684 40.06302)
# 94 0 88.0
# 94 1 40.063599
# 94 2 -104.829832
# 94 3 2008-04-25
# 94 4 Swainsons Hawk
# 94 5 INACTIVE NEST
# 94 6 88
# 94 7 POINT (-104.89227 40.04444)
# 95 0 89.0
# 95 1 40.037714
# 95 2 -104.829709
# 95 3 2008-04-25
# 95 4 Red-tail Hawk
# 95 5 INACTIVE NEST
# 95 6 89
# 95 7 POINT (-104.8124 39.99289)
# 96 0 90.0
# 96 1 40.038471
# 96 2 -104.829695
# 96 3 2008-04-25
# 96 4 Red-tail Hawk
# 96 5 INACTIVE NEST
# 96 6 90
# 96 7 POINT (-104.8625 39.99064)
# 97 0 91.0
# 97 1 40.036795
# 97 2 -104.829582
# 97 3 2008-04-25
# 97 4 Swainsons Hawk
# 97 5 INACTIVE NEST
# 97 6 91
# 97 7 POINT (-104.81005 40.09573)
# 98 0 92.0
# 98 1 40.031947
# 98 2 -104.829477
# 98 3 2008-04-25
# 98 4 Swainsons Hawk
# 98 5 FLEDGED NEST
# 98 6 92
# 98 7 POINT (-104.83104 40.0983)
# 99 0 93.0
# 99 1 40.049804
# 99 2 -104.829175
# 99 3 2008-04-25
# 99 4 Red-tail Hawk
# 99 5 INACTIVE NEST
# 99 6 93
# 99 7 POINT (-104.77532 40.05807)
# 100 0 94.0
# 100 1 40.048244
# 100 2 -104.828065
# 100 3 2014-06-09
# 100 4 Red-tail Hawk
# 100 5 ACTIVE NEST
# 100 6 94
# 100 7 POINT (-104.77525 40.11579)
# 101 0 95.0
# 101 1 40.049477
# 101 2 -104.8271
# 101 3 2008-04-25
# 101 4 Red-tail Hawk
# 101 5 INACTIVE NEST
# 101 6 95
# 101 7 POINT (-104.87745 40.06964)
# 102 0 96.0
# 102 1 40.035529
# 102 2 -104.826561
# 102 3 2008-04-25
# 102 4 Red-tail Hawk
# 102 5 INACTIVE NEST
# 102 6 96
# 102 7 POINT (-104.73479 40.03041)
# 103 0 97.0
# 103 1 40.058384
# 103 2 -104.824545
# 103 3 2008-04-25
# 103 4 Swainsons Hawk
# 103 5 ACTIVE NEST
# 103 6 97
# 103 7 POINT (-104.86578 39.99927)
# 104 0 98.0
# 104 1 40.061459
# 104 2 -104.820562
# 104 3 2008-04-25
# 104 4 Red-tail Hawk
# 104 5 INACTIVE NEST
# 104 6 98
# 104 7 POINT (-104.82824 40.0463)
# 105 0 99.0
# 105 1 40.530799
# 105 2 -104.831797
# 105 3 2008-06-03
# 105 4 Swainsons Hawk
# 105 5 FLEDGED NEST
# 105 6 99
# 105 7 POINT (-104.91752 40.49435)
# 106 0 100.0
# 106 1 40.338229
# 106 2 -104.587601
# 106 3 2008-06-03
# 106 4 Red-tail Hawk
# 106 5 INACTIVE NEST
# 106 6 100
# 106 7 POINT (-104.53155 40.2802)
# 107 0 101.0
# 107 1 40.487824
# 107 2 -104.768116
# 107 3 2008-06-03
# 107 4 Swainsons Hawk
# 107 5 FLEDGED NEST
# 107 6 101
# 107 7 POINT (-104.76049 40.41908)
# 108 0 102.0
# 108 1 40.08835
# 108 2 -104.508468
# 108 3 2008-06-03
# 108 4 Swainsons Hawk
# 108 5 FLEDGED NEST
# 108 6 102
# 108 7 POINT (-104.49186 40.03111)
# 109 0 103.0
# 109 1 40.517867
# 109 2 -104.827522
# 109 3 2008-06-03
# 109 4 Red-tail Hawk
# 109 5 INACTIVE NEST
# 109 6 103
# 109 7 POINT (-104.75051 40.52852)
# 110 0 104.0
# 110 1 40.508454
# 110 2 -104.830224
# 110 3 2008-06-03
# 110 4 Red-tail Hawk
# 110 5 FLEDGED NEST
# 110 6 104
# 110 7 POINT (-104.765 40.48259)
# 111 0 105.0
# 111 1 40.518207
# 111 2 -104.82783
# 111 3 2008-06-03
# 111 4 Red-tail Hawk
# 111 5 FLEDGED NEST
# 111 6 105
# 111 7 POINT (-104.77397 40.45362)
# 112 0 106.0
# 112 1 40.326908
# 112 2 -104.581231
# 112 3 2008-06-03
# 112 4 Swainsons Hawk
# 112 5 INACTIVE NEST
# 112 6 106
# 112 7 POINT (-104.53068 40.33154)
# 113 0 107.0
# 113 1 40.057375
# 113 2 -104.576964
# 113 3 2008-06-03
# 113 4 Red-tail Hawk
# 113 5 INACTIVE NEST
# 113 6 107
# 113 7 POINT (-104.57046 40.02929)
# 114 0 108.0
# 114 1 40.290293
# 114 2 -104.876666
# 114 3 2008-06-03
# 114 4 Swainsons Hawk
# 114 5 INACTIVE NEST
# 114 6 108
# 114 7 POINT (-104.8441 40.34197)
# 115 0 109.0
# 115 1 40.310841
# 115 2 -104.866732
# 115 3 2008-06-03
# 115 4 Red-tail Hawk
# 115 5 ACTIVE NEST
# 115 6 109
# 115 7 POINT (-104.86989 40.29139)
# 116 0 110.0
# 116 1 40.501811
# 116 2 -104.471308
# 116 3 2008-06-03
# 116 4 Red-tail Hawk
# 116 5 INACTIVE NEST
# 116 6 110
# 116 7 POINT (-104.48078 40.56803)
# 117 0 111.0
# 117 1 40.266192
# 117 2 -104.666249
# 117 3 2008-06-03
# 117 4 Red-tail Hawk
# 117 5 INACTIVE NEST
# 117 6 111
# 117 7 POINT (-104.68259 40.27171)
# 118 0 112.0
# 118 1 40.185024
# 118 2 -105.155517
# 118 3 2008-06-03
# 118 4 Red-tail Hawk
# 118 5 INACTIVE NEST
# 118 6 112
# 118 7 POINT (-105.17062 40.23782)
# 119 0 114.0
# 119 1 40.38259
# 119 2 -104.94166
# 119 3 2008-06-03
# 119 4 Swainsons Hawk
# 119 5 FLEDGED NEST
# 119 6 114
# 119 7 POINT (-104.96513 40.43837)
# 120 0 115.0
# 120 1 40.57187
# 120 2 -104.819655
# 120 3 2008-06-03
# 120 4 Red-tail Hawk
# 120 5 ACTIVE NEST
# 120 6 115
# 120 7 POINT (-104.82919 40.54868)
# 121 0 116.0
# 121 1 40.357831
# 121 2 -104.719123
# 121 3 2008-06-03
# 121 4 Red-tail Hawk
# 121 5 INACTIVE NEST
# 121 6 116
# 121 7 POINT (-104.68079 40.31262)
# 122 0 117.0
# 122 1 40.130134
# 122 2 -104.993051
# 122 3 2008-06-03
# 122 4 Red-tail Hawk
# 122 5 FLEDGED NEST
# 122 6 117
# 122 7 POINT (-104.96794 40.20047)
# 123 0 118.0
# 123 1 40.48504
# 123 2 -104.61311
# 123 3 2008-06-03
# 123 4 Red-tail Hawk
# 123 5 ACTIVE NEST
# 123 6 118
# 123 7 POINT (-104.52014 40.44087)
# 124 0 119.0
# 124 1 40.232609
# 124 2 -104.730173
# 124 3 2014-07-16
# 124 4 Swainsons Hawk
# 124 5 INACTIVE NEST
# 124 6 119
# 124 7 POINT (-104.67131 40.25596)
# 125 0 121.0
# 125 1 40.235751
# 125 2 -104.744902
# 125 3 2014-07-18
# 125 4 Red-tail Hawk
# 125 5 INACTIVE NEST
# 125 6 121
# 125 7 POINT (-104.81498 40.23871)
# 126 0 122.0
# 126 1 40.272105
# 126 2 -104.934651
# 126 3 2014-04-30
# 126 4 Swainsons Hawk
# 126 5 ACTIVE NEST
# 126 6 122
# 126 7 POINT (-104.95209 40.23106)
# 127 0 123.0
# 127 1 40.275357
# 127 2 -104.93313
# 127 3 2014-07-23
# 127 4 Red-tail Hawk
# 127 5 FLEDGED NEST
# 127 6 123
# 127 7 POINT (-104.85054 40.26056)
# 128 0 124.0
# 128 1 40.476414
# 128 2 -104.794357
# 128 3 2008-06-03
# 128 4 Swainsons Hawk
# 128 5 FLEDGED NEST
# 128 6 124
# 128 7 POINT (-104.88624 40.45142)
# 129 0 125.0
# 129 1 40.338705
# 129 2 -104.587316
# 129 3 2008-06-03
# 129 4 Red-tail Hawk
# 129 5 FLEDGED NEST
# 129 6 125
# 129 7 POINT (-104.6084 40.33203)
# 130 0 126.0
# 130 1 40.347629
# 130 2 -104.591041
# 130 3 2008-06-03
# 130 4 Swainsons Hawk
# 130 5 INACTIVE NEST
# 130 6 126
# 130 7 POINT (-104.52545 40.28275)
# 131 0 127.0
# 131 1 40.193263
# 131 2 -104.918913
# 131 3 2014-07-11
# 131 4 Swainsons Hawk
# 131 5 ACTIVE NEST
# 131 6 127
# 131 7 POINT (-104.87129 40.12185)
# 132 0 128.0
# 132 1 40.419094
# 132 2 -104.864786
# 132 3 2009-02-16
# 132 4 Red-tail Hawk
# 132 5 FLEDGED NEST
# 132 6 128
# 132 7 POINT (-104.84771 40.39903)
# 133 0 129.0
# 133 1 40.420177
# 133 2 -104.86661
# 133 3 2009-02-16
# 133 4 Swainsons Hawk
# 133 5 ACTIVE NEST
# 133 6 129
# 133 7 POINT (-104.93307 40.40455)
# 134 0 130.0
# 134 1 40.182479
# 134 2 -105.021958
# 134 3 2009-02-16
# 134 4 Swainsons Hawk
# 134 5 ACTIVE NEST
# 134 6 130
# 134 7 POINT (-105.10449 40.15217)
# 135 0 131.0
# 135 1 40.177304
# 135 2 -104.832708
# 135 3 2009-02-16
# 135 4 Red-tail Hawk
# 135 5 INACTIVE NEST
# 135 6 131
# 135 7 POINT (-104.80508 40.12561)
# 136 0 132.0
# 136 1 40.293525
# 136 2 -104.826139
# 136 3 2009-02-16
# 136 4 Red-tail Hawk
# 136 5 FLEDGED NEST
# 136 6 132
# 136 7 POINT (-104.84461 40.36478)
# 137 0 133.0
# 137 1 40.293302
# 137 2 -104.827081
# 137 3 2009-02-16
# 137 4 Swainsons Hawk
# 137 5 INACTIVE NEST
# 137 6 133
# 137 7 POINT (-104.89419 40.35369)
# 138 0 134.0
# 138 1 40.295341
# 138 2 -104.829523
# 138 3 2009-02-16
# 138 4 Red-tail Hawk
# 138 5 INACTIVE NEST
# 138 6 134
# 138 7 POINT (-104.88737 40.3673)
# 139 0 135.0
# 139 1 40.239064
# 139 2 -104.560988
# 139 3 2009-02-16
# 139 4 Red-tail Hawk
# 139 5 ACTIVE NEST
# 139 6 135
# 139 7 POINT (-104.50898 40.29313)
# 140 0 136.0
# 140 1 40.236308
# 140 2 -104.561158
# 140 3 2009-02-16
# 140 4 Swainsons Hawk
# 140 5 INACTIVE NEST
# 140 6 136
# 140 7 POINT (-104.57135 40.19549)
# 141 0 137.0
# 141 1 40.161485
# 141 2 -104.736432
# 141 3 2009-02-16
# 141 4 Red-tail Hawk
# 141 5 INACTIVE NEST
# 141 6 137
# 141 7 POINT (-104.75732 40.22608)
# 142 0 138.0
# 142 1 40.167251
# 142 2 -104.895186
# 142 3 2009-09-21
# 142 4 Red-tail Hawk
# 142 5 ACTIVE NEST
# 142 6 138
# 142 7 POINT (-104.81781 40.12482)
# 143 0 139.0
# 143 1 40.174632
# 143 2 -104.908529
# 143 3 2009-09-21
# 143 4 Red-tail Hawk
# 143 5 FLEDGED NEST
# 143 6 139
# 143 7 POINT (-104.82487 40.1579)
# 144 0 140.0
# 144 1 40.168164
# 144 2 -104.889043
# 144 3 2009-09-21
# 144 4 Red-tail Hawk
# 144 5 ACTIVE NEST
# 144 6 140
# 144 7 POINT (-104.83257 40.18646)
# 145 0 141.0
# 145 1 40.168317
# 145 2 -104.888796
# 145 3 2009-09-21
# 145 4 Red-tail Hawk
# 145 5 INACTIVE NEST
# 145 6 141
# 145 7 POINT (-104.90306 40.13331)
# 146 0 142.0
# 146 1 39.850724
# 146 2 -104.362036
# 146 3 2009-09-21
# 146 4 Red-tail Hawk
# 146 5 ACTIVE NEST
# 146 6 142
# 146 7 POINT (-104.34477 39.86965)
# 147 0 143.0
# 147 1 40.222794
# 147 2 -104.728426
# 147 3 2014-08-14
# 147 4 Red-tail Hawk
# 147 5 ACTIVE NEST
# 147 6 143
# 147 7 POINT (-104.72085 40.1949)
# 148 0 144.0
# 148 1 40.153272
# 148 2 -104.849557
# 148 3 2009-09-21
# 148 4 Swainsons Hawk
# 148 5 FLEDGED NEST
# 148 6 144
# 148 7 POINT (-104.92554 40.13202)
# 149 0 145.0
# 149 1 40.193823
# 149 2 -104.909103
# 149 3 2009-09-21
# 149 4 Red-tail Hawk
# 149 5 FLEDGED NEST
# 149 6 145
# 149 7 POINT (-104.92416 40.23481)
# 150 0 146.0
# 150 1 40.034008
# 150 2 -104.869171
# 150 3 2009-09-21
# 150 4 Red-tail Hawk
# 150 5 INACTIVE NEST
# 150 6 146
# 150 7 POINT (-104.81893 39.9708)
# 151 0 147.0
# 151 1 40.072767
# 151 2 -104.7324
# 151 3 2009-09-21
# 151 4 Red-tail Hawk
# 151 5 INACTIVE NEST
# 151 6 147
# 151 7 POINT (-104.74471 40.06464)
# 152 0 148.0
# 152 1 40.167169
# 152 2 -104.624985
# 152 3 2009-09-21
# 152 4 Red-tail Hawk
# 152 5 FLEDGED NEST
# 152 6 148
# 152 7 POINT (-104.63358 40.19635)
# 153 0 149.0
# 153 1 40.169002
# 153 2 -104.623601
# 153 3 2009-09-21
# 153 4 Red-tail Hawk
# 153 5 INACTIVE NEST
# 153 6 149
# 153 7 POINT (-104.63727 40.12933)
# 154 0 151.0
# 154 1 40.103025
# 154 2 -105.044244
# 154 3 2009-09-21
# 154 4 Red-tail Hawk
# 154 5 INACTIVE NEST
# 154 6 151
# 154 7 POINT (-105.03273 40.05664)
# 155 0 152.0
# 155 1 40.132348
# 155 2 -104.617414
# 155 3 2014-08-13
# 155 4 Red-tail Hawk
# 155 5 ACTIVE NEST
# 155 6 152
# 155 7 POINT (-104.52344 40.19385)
# 156 0 153.0
# 156 1 40.135256
# 156 2 -104.616223
# 156 3 2009-09-21
# 156 4 Red-tail Hawk
# 156 5 INACTIVE NEST
# 156 6 153
# 156 7 POINT (-104.63036 40.17159)
# 157 0 154.0
# 157 1 40.1125
# 157 2 -105.051913
# 157 3 2009-09-21
# 157 4 Red-tail Hawk
# 157 5 FLEDGED NEST
# 157 6 154
# 157 7 POINT (-105.11649 40.14566)
# 158 0 155.0
# 158 1 40.076103
# 158 2 -105.006404
# 158 3 2009-09-21
# 158 4 Red-tail Hawk
# 158 5 INACTIVE NEST
# 158 6 155
# 158 7 POINT (-104.97112 40.13564)
# 159 0 156.0
# 159 1 40.170812
# 159 2 -104.997346
# 159 3 2014-03-28
# 159 4 Swainsons Hawk
# 159 5 FLEDGED NEST
# 159 6 156
# 159 7 POINT (-105.03309 40.17915)
# 160 0 157.0
# 160 1 40.145261
# 160 2 -104.80076
# 160 3 2009-09-21
# 160 4 Red-tail Hawk
# 160 5 INACTIVE NEST
# 160 6 157
# 160 7 POINT (-104.73093 40.15405)
# 161 0 158.0
# 161 1 40.006736
# 161 2 -104.950838
# 161 3 2009-12-01
# 161 4 Swainsons Hawk
# 161 5 INACTIVE NEST
# 161 6 158
# 161 7 POINT (-104.93439 40.02142)
# 162 0 159.0
# 162 1 40.29972
# 162 2 -104.661765
# 162 3 2009-12-01
# 162 4 Swainsons Hawk
# 162 5 INACTIVE NEST
# 162 6 159
# 162 7 POINT (-104.71062 40.23542)
# 163 0 160.0
# 163 1 40.289884
# 163 2 -104.668438
# 163 3 2009-12-01
# 163 4 Swainsons Hawk
# 163 5 INACTIVE NEST
# 163 6 160
# 163 7 POINT (-104.75082 40.29079)
# 164 0 161.0
# 164 1 40.292939
# 164 2 -104.671882
# 164 3 2009-12-01
# 164 4 Swainsons Hawk
# 164 5 ACTIVE NEST
# 164 6 161
# 164 7 POINT (-104.64941 40.29793)
# 165 0 162.0
# 165 1 40.293358
# 165 2 -104.673633
# 165 3 2009-12-01
# 165 4 Red-tail Hawk
# 165 5 ACTIVE NEST
# 165 6 162
# 165 7 POINT (-104.6791 40.33783)
# 166 0 163.0
# 166 1 40.226344
# 166 2 -104.789309
# 166 3 2009-12-01
# 166 4 Red-tail Hawk
# 166 5 ACTIVE NEST
# 166 6 163
# 166 7 POINT (-104.81088 40.25406)
# 167 0 164.0
# 167 1 40.159268
# 167 2 -104.832881
# 167 3 2009-12-01
# 167 4 Swainsons Hawk
# 167 5 INACTIVE NEST
# 167 6 164
# 167 7 POINT (-104.9125 40.21974)
# 168 0 165.0
# 168 1 40.160131
# 168 2 -104.831494
# 168 3 2009-12-01
# 168 4 Red-tail Hawk
# 168 5 INACTIVE NEST
# 168 6 165
# 168 7 POINT (-104.77161 40.2095)
# 169 0 166.0
# 169 1 40.21755
# 169 2 -104.778994
# 169 3 2009-12-01
# 169 4 Red-tail Hawk
# 169 5 ACTIVE NEST
# 169 6 166
# 169 7 POINT (-104.74842 40.16597)
# 170 0 167.0
# 170 1 40.136026
# 170 2 -104.987064
# 170 3 2014-06-25
# 170 4 Swainsons Hawk
# 170 5 FLEDGED NEST
# 170 6 167
# 170 7 POINT (-105.03474 40.06689)
# 171 0 168.0
# 171 1 40.145528
# 171 2 -104.969699
# 171 3 2014-06-25
# 171 4 Red-tail Hawk
# 171 5 INACTIVE NEST
# 171 6 168
# 171 7 POINT (-104.99082 40.15241)
# 172 0 169.0
# 172 1 39.91276
# 172 2 -104.778561
# 172 3 2010-03-23
# 172 4 Red-tail Hawk
# 172 5 FLEDGED NEST
# 172 6 169
# 172 7 POINT (-104.86037 39.9666)
# 173 0 170.0
# 173 1 39.919324
# 173 2 -104.785643
# 173 3 2010-03-23
# 173 4 Swainsons Hawk
# 173 5 INACTIVE NEST
# 173 6 170
# 173 7 POINT (-104.87099 39.89833)
# 174 0 171.0
# 174 1 39.91862
# 174 2 -104.789916
# 174 3 2010-03-23
# 174 4 Swainsons Hawk
# 174 5 ACTIVE NEST
# 174 6 171
# 174 7 POINT (-104.73176 39.86449)
# 175 0 173.0
# 175 1 40.072903
# 175 2 -104.895859
# 175 3 2010-03-23
# 175 4 Red-tail Hawk
# 175 5 INACTIVE NEST
# 175 6 173
# 175 7 POINT (-104.84726 40.02745)
# 176 0 174.0
# 176 1 40.166473
# 176 2 -104.851078
# 176 3 2014-06-26
# 176 4 Red-tail Hawk
# 176 5 ACTIVE NEST
# 176 6 174
# 176 7 POINT (-104.75938 40.12098)
# 177 0 175.0
# 177 1 40.160287
# 177 2 -104.861343
# 177 3 2010-03-23
# 177 4 Swainsons Hawk
# 177 5 INACTIVE NEST
# 177 6 175
# 177 7 POINT (-104.82586 40.13976)
# 178 0 176.0
# 178 1 40.162092
# 178 2 -104.848625
# 178 3 2014-06-26
# 178 4 Swainsons Hawk
# 178 5 ACTIVE NEST
# 178 6 176
# 178 7 POINT (-104.76202 40.10325)
# 179 0 177.0
# 179 1 40.356638
# 179 2 -104.853652
# 179 3 2010-03-23
# 179 4 Red-tail Hawk
# 179 5 INACTIVE NEST
# 179 6 177
# 179 7 POINT (-104.94406 40.30175)
# 180 0 178.0
# 180 1 40.174502
# 180 2 -104.928179
# 180 3 2010-03-23
# 180 4 Red-tail Hawk
# 180 5 ACTIVE NEST
# 180 6 178
# 180 7 POINT (-104.89967 40.20431)
# 181 0 179.0
# 181 1 40.341031
# 181 2 -104.838486
# 181 3 2010-03-23
# 181 4 Red-tail Hawk
# 181 5 INACTIVE NEST
# 181 6 179
# 181 7 POINT (-104.77919 40.28223)
# 182 0 180.0
# 182 1 40.338924
# 182 2 -104.838773
# 182 3 2010-03-23
# 182 4 Red-tail Hawk
# 182 5 INACTIVE NEST
# 182 6 180
# 182 7 POINT (-104.93145 40.31238)
# 183 0 181.0
# 183 1 40.235283
# 183 2 -104.933358
# 183 3 2010-03-23
# 183 4 Red-tail Hawk
# 183 5 ACTIVE NEST
# 183 6 181
# 183 7 POINT (-104.97757 40.18457)
# 184 0 182.0
# 184 1 40.201741
# 184 2 -104.983809
# 184 3 2010-03-23
# 184 4 Red-tail Hawk
# 184 5 ACTIVE NEST
# 184 6 182
# 184 7 POINT (-105.05784 40.20291)
# 185 0 184.0
# 185 1 39.977388
# 185 2 -104.893334
# 185 3 2010-03-23
# 185 4 Red-tail Hawk
# 185 5 INACTIVE NEST
# 185 6 184
# 185 7 POINT (-104.8283 40.02308)
# 186 0 185.0
# 186 1 39.98485
# 186 2 -104.905527
# 186 3 2010-03-23
# 186 4 Swainsons Hawk
# 186 5 INACTIVE NEST
# 186 6 185
# 186 7 POINT (-104.86663 39.91547)
# 187 0 186.0
# 187 1 40.174497
# 187 2 -104.758157
# 187 3 2010-03-23
# 187 4 Red-tail Hawk
# 187 5 INACTIVE NEST
# 187 6 186
# 187 7 POINT (-104.66622 40.20521)
# 188 0 187.0
# 188 1 40.169435
# 188 2 -104.640757
# 188 3 2010-03-23
# 188 4 Red-tail Hawk
# 188 5 INACTIVE NEST
# 188 6 187
# 188 7 POINT (-104.68392 40.15443)
# 189 0 188.0
# 189 1 40.140847
# 189 2 -104.714829
# 189 3 2010-03-23
# 189 4 Red-tail Hawk
# 189 5 ACTIVE NEST
# 189 6 188
# 189 7 POINT (-104.69689 40.18767)
# 190 0 189.0
# 190 1 40.099861
# 190 2 -105.014888
# 190 3 2010-10-26
# 190 4 Swainsons Hawk
# 190 5 ACTIVE NEST
# 190 6 189
# 190 7 POINT (-104.92674 40.16508)
# 191 0 190.0
# 191 1 40.177878
# 191 2 -104.960722
# 191 3 2014-08-15
# 191 4 Red-tail Hawk
# 191 5 INACTIVE NEST
# 191 6 190
# 191 7 POINT (-105.02043 40.11285)
# 192 0 191.0
# 192 1 40.07458
# 192 2 -104.985551
# 192 3 2010-10-26
# 192 4 Red-tail Hawk
# 192 5 INACTIVE NEST
# 192 6 191
# 192 7 POINT (-105.01651 40.0752)
# 193 0 192.0
# 193 1 40.061201
# 193 2 -105.005382
# 193 3 2010-10-26
# 193 4 Red-tail Hawk
# 193 5 ACTIVE NEST
# 193 6 192
# 193 7 POINT (-105.06703 40.11313)
# 194 0 193.0
# 194 1 40.372327
# 194 2 -104.443097
# 194 3 2010-10-26
# 194 4 Red-tail Hawk
# 194 5 ACTIVE NEST
# 194 6 193
# 194 7 POINT (-104.45843 40.41029)
# 195 0 194.0
# 195 1 40.371026
# 195 2 -104.449951
# 195 3 2010-10-26
# 195 4 Swainsons Hawk
# 195 5 FLEDGED NEST
# 195 6 194
# 195 7 POINT (-104.43838 40.33633)
# 196 0 195.0
# 196 1 40.131129
# 196 2 -104.668929
# 196 3 2010-10-26
# 196 4 Red-tail Hawk
# 196 5 FLEDGED NEST
# 196 6 195
# 196 7 POINT (-104.7198 40.15161)
# 197 0 196.0
# 197 1 40.112731
# 197 2 -104.948514
# 197 3 2011-04-06
# 197 4 Red-tail Hawk
# 197 5 ACTIVE NEST
# 197 6 196
# 197 7 POINT (-104.91655 40.09337)
# 198 0 197.0
# 198 1 40.061725
# 198 2 -104.848436
# 198 3 2011-04-06
# 198 4 Swainsons Hawk
# 198 5 ACTIVE NEST
# 198 6 197
# 198 7 POINT (-104.90909 40.09074)
# 199 0 198.0
# 199 1 40.113723
# 199 2 -104.949271
# 199 3 2011-04-06
# 199 4 Red-tail Hawk
# 199 5 ACTIVE NEST
# 199 6 198
# 199 7 POINT (-104.89801 40.11342)
# 200 0 199.0
# 200 1 40.172293
# 200 2 -104.784592
# 200 3 2011-04-06
# 200 4 Red-tail Hawk
# 200 5 INACTIVE NEST
# 200 6 199
# 200 7 POINT (-104.8704 40.13612)
# 201 0 200.0
# 201 1 40.126929
# 201 2 -104.814651
# 201 3 2011-04-06
# 201 4 Red-tail Hawk
# 201 5 INACTIVE NEST
# 201 6 200
# 201 7 POINT (-104.76846 40.11321)
# 202 0 201.0
# 202 1 40.145757
# 202 2 -104.779728
# 202 3 2011-04-06
# 202 4 Swainsons Hawk
# 202 5 INACTIVE NEST
# 202 6 201
# 202 7 POINT (-104.75637 40.14731)
# 203 0 202.0
# 203 1 40.268263
# 203 2 -104.743564
# 203 3 2011-04-06
# 203 4 Swainsons Hawk
# 203 5 INACTIVE NEST
# 203 6 202
# 203 7 POINT (-104.66766 40.2258)
# 204 0 203.0
# 204 1 40.150653
# 204 2 -104.980521
# 204 3 2011-04-06
# 204 4 Red-tail Hawk
# 204 5 ACTIVE NEST
# 204 6 203
# 204 7 POINT (-105.04248 40.22027)
# 205 0 204.0
# 205 1 40.152757
# 205 2 -104.815532
# 205 3 2011-04-06
# 205 4 Red-tail Hawk
# 205 5 INACTIVE NEST
# 205 6 204
# 205 7 POINT (-104.86334 40.21205)
# 206 0 205.0
# 206 1 40.148665
# 206 2 -104.826989
# 206 3 2011-04-06
# 206 4 Red-tail Hawk
# 206 5 INACTIVE NEST
# 206 6 205
# 206 7 POINT (-104.8047 40.08208)
# 207 0 206.0
# 207 1 40.147341
# 207 2 -104.825788
# 207 3 2011-04-06
# 207 4 Red-tail Hawk
# 207 5 INACTIVE NEST
# 207 6 206
# 207 7 POINT (-104.81832 40.1991)
# 208 0 207.0
# 208 1 40.134698
# 208 2 -104.828673
# 208 3 2011-04-06
# 208 4 Swainsons Hawk
# 208 5 ACTIVE NEST
# 208 6 207
# 208 7 POINT (-104.82777 40.12576)
# 209 0 208.0
# 209 1 40.14708
# 209 2 -104.834212
# 209 3 2011-04-06
# 209 4 Red-tail Hawk
# 209 5 INACTIVE NEST
# 209 6 208
# 209 7 POINT (-104.77567 40.21635)
# 210 0 209.0
# 210 1 40.13957
# 210 2 -104.825099
# 210 3 2011-04-06
# 210 4 Red-tail Hawk
# 210 5 INACTIVE NEST
# 210 6 209
# 210 7 POINT (-104.86175 40.12318)
# 211 0 210.0
# 211 1 40.128951
# 211 2 -104.774438
# 211 3 2014-08-13
# 211 4 Red-tail Hawk
# 211 5 INACTIVE NEST
# 211 6 210
# 211 7 POINT (-104.73089 40.08466)
# 212 0 211.0
# 212 1 40.122824
# 212 2 -104.709241
# 212 3 2011-04-06
# 212 4 Red-tail Hawk
# 212 5 INACTIVE NEST
# 212 6 211
# 212 7 POINT (-104.78983 40.12918)
# 213 0 212.0
# 213 1 40.121872
# 213 2 -104.709205
# 213 3 2011-04-06
# 213 4 Red-tail Hawk
# 213 5 FLEDGED NEST
# 213 6 212
# 213 7 POINT (-104.69793 40.19232)
# 214 0 213.0
# 214 1 40.123081
# 214 2 -104.709844
# 214 3 2011-04-06
# 214 4 Swainsons Hawk
# 214 5 INACTIVE NEST
# 214 6 213
# 214 7 POINT (-104.65041 40.1693)
# 215 0 214.0
# 215 1 40.125323
# 215 2 -104.715126
# 215 3 2011-04-06
# 215 4 Red-tail Hawk
# 215 5 ACTIVE NEST
# 215 6 214
# 215 7 POINT (-104.6936 40.11083)
# 216 0 215.0
# 216 1 40.150356
# 216 2 -104.727755
# 216 3 2015-07-17
# 216 4 Swainsons Hawk
# 216 5 INACTIVE NEST
# 216 6 215
# 216 7 POINT (-104.78471 40.11843)
# 217 0 216.0
# 217 1 40.153737
# 217 2 -104.734575
# 217 3 2011-04-06
# 217 4 Swainsons Hawk
# 217 5 ACTIVE NEST
# 217 6 216
# 217 7 POINT (-104.75618 40.15758)
# 218 0 217.0
# 218 1 40.187351
# 218 2 -104.696651
# 218 3 2011-04-06
# 218 4 Red-tail Hawk
# 218 5 INACTIVE NEST
# 218 6 217
# 218 7 POINT (-104.7882 40.13419)
# 219 0 218.0
# 219 1 40.131003
# 219 2 -104.819187
# 219 3 2011-04-06
# 219 4 Red-tail Hawk
# 219 5 FLEDGED NEST
# 219 6 218
# 219 7 POINT (-104.90224 40.09308)
# 220 0 219.0
# 220 1 40.247995
# 220 2 -104.709889
# 220 3 2011-04-06
# 220 4 Red-tail Hawk
# 220 5 INACTIVE NEST
# 220 6 219
# 220 7 POINT (-104.80145 40.30365)
# 221 0 220.0
# 221 1 40.20476
# 221 2 -104.731688
# 221 3 2014-07-09
# 221 4 Swainsons Hawk
# 221 5 INACTIVE NEST
# 221 6 220
# 221 7 POINT (-104.65619 40.26741)
# 222 0 221.0
# 222 1 40.203464
# 222 2 -104.764686
# 222 3 2011-04-06
# 222 4 Swainsons Hawk
# 222 5 INACTIVE NEST
# 222 6 221
# 222 7 POINT (-104.76316 40.22673)
# 223 0 222.0
# 223 1 40.209897
# 223 2 -104.772162
# 223 3 2014-06-10
# 223 4 Swainsons Hawk
# 223 5 FLEDGED NEST
# 223 6 222
# 223 7 POINT (-104.83038 40.27413)
# 224 0 223.0
# 224 1 40.196331
# 224 2 -104.777856
# 224 3 2011-04-06
# 224 4 Red-tail Hawk
# 224 5 INACTIVE NEST
# 224 6 223
# 224 7 POINT (-104.70182 40.12719)
# 225 0 224.0
# 225 1 40.287577
# 225 2 -104.658659
# 225 3 2011-04-06
# 225 4 Red-tail Hawk
# 225 5 INACTIVE NEST
# 225 6 224
# 225 7 POINT (-104.61904 40.29743)
# 226 0 225.0
# 226 1 40.321585
# 226 2 -104.902831
# 226 3 2011-04-06
# 226 4 Swainsons Hawk
# 226 5 INACTIVE NEST
# 226 6 225
# 226 7 POINT (-104.81706 40.3174)
# 227 0 226.0
# 227 1 40.26126
# 227 2 -104.83005
# 227 3 2011-04-06
# 227 4 Swainsons Hawk
# 227 5 INACTIVE NEST
# 227 6 226
# 227 7 POINT (-104.89886 40.30126)
# 228 0 227.0
# 228 1 40.134202
# 228 2 -104.846785
# 228 3 2011-04-06
# 228 4 Swainsons Hawk
# 228 5 FLEDGED NEST
# 228 6 227
# 228 7 POINT (-104.8052 40.15268)
# 229 0 228.0
# 229 1 40.303645
# 229 2 -104.639123
# 229 3 2011-04-06
# 229 4 Red-tail Hawk
# 229 5 INACTIVE NEST
# 229 6 228
# 229 7 POINT (-104.64396 40.30093)
# 230 0 229.0
# 230 1 40.287961
# 230 2 -104.657788
# 230 3 2011-04-06
# 230 4 Swainsons Hawk
# 230 5 INACTIVE NEST
# 230 6 229
# 230 7 POINT (-104.71123 40.27445)
# 231 0 230.0
# 231 1 40.139559
# 231 2 -104.674827
# 231 3 2015-03-19
# 231 4 Red-tail Hawk
# 231 5 ACTIVE NEST
# 231 6 230
# 231 7 POINT (-104.71889 40.13759)
# 232 0 231.0
# 232 1 40.182995
# 232 2 -104.976268
# 232 3 2011-04-06
# 232 4 Red-tail Hawk
# 232 5 FLEDGED NEST
# 232 6 231
# 232 7 POINT (-104.90873 40.1582)
# 233 0 232.0
# 233 1 40.311822
# 233 2 -104.598844
# 233 3 2011-04-06
# 233 4 Red-tail Hawk
# 233 5 ACTIVE NEST
# 233 6 232
# 233 7 POINT (-104.69255 40.36336)
# 234 0 233.0
# 234 1 40.344244
# 234 2 -104.877918
# 234 3 2011-04-06
# 234 4 Swainsons Hawk
# 234 5 FLEDGED NEST
# 234 6 233
# 234 7 POINT (-104.84487 40.29813)
# 235 0 234.0
# 235 1 40.190365
# 235 2 -104.852526
# 235 3 2014-05-12
# 235 4 Red-tail Hawk
# 235 5 FLEDGED NEST
# 235 6 234
# 235 7 POINT (-104.86094 40.24521)
# 236 0 235.0
# 236 1 40.191627
# 236 2 -104.854105
# 236 3 2011-04-06
# 236 4 Red-tail Hawk
# 236 5 ACTIVE NEST
# 236 6 235
# 236 7 POINT (-104.85656 40.12801)
# 237 0 236.0
# 237 1 40.352189
# 237 2 -104.834265
# 237 3 2011-04-06
# 237 4 Swainsons Hawk
# 237 5 ACTIVE NEST
# 237 6 236
# 237 7 POINT (-104.82238 40.42231)
# 238 0 237.0
# 238 1 40.284446
# 238 2 -104.859843
# 238 3 2011-04-06
# 238 4 Swainsons Hawk
# 238 5 INACTIVE NEST
# 238 6 237
# 238 7 POINT (-104.92195 40.31506)
# 239 0 238.0
# 239 1 40.130103
# 239 2 -104.655518
# 239 3 2015-07-28
# 239 4 Red-tail Hawk
# 239 5 ACTIVE NEST
# 239 6 238
# 239 7 POINT (-104.57469 40.13347)
# 240 0 239.0
# 240 1 40.141795
# 240 2 -104.714559
# 240 3 2011-04-06
# 240 4 Swainsons Hawk
# 240 5 INACTIVE NEST
# 240 6 239
# 240 7 POINT (-104.79265 40.21126)
# 241 0 240.0
# 241 1 40.140795
# 241 2 -104.714801
# 241 3 2011-04-06
# 241 4 Swainsons Hawk
# 241 5 FLEDGED NEST
# 241 6 240
# 241 7 POINT (-104.63907 40.13086)
# 242 0 241.0
# 242 1 40.354755
# 242 2 -104.815219
# 242 3 2011-04-06
# 242 4 Swainsons Hawk
# 242 5 FLEDGED NEST
# 242 6 241
# 242 7 POINT (-104.73975 40.40259)
# 243 0 242.0
# 243 1 40.219212
# 243 2 -104.938508
# 243 3 2014-03-24
# 243 4 Swainsons Hawk
# 243 5 FLEDGED NEST
# 243 6 242
# 243 7 POINT (-104.9475 40.27563)
# 244 0 243.0
# 244 1 40.2342
# 244 2 -104.753392
# 244 3 2011-04-06
# 244 4 Swainsons Hawk
# 244 5 ACTIVE NEST
# 244 6 243
# 244 7 POINT (-104.68992 40.30068)
# 245 0 244.0
# 245 1 40.233822
# 245 2 -104.854233
# 245 3 2011-04-06
# 245 4 Swainsons Hawk
# 245 5 INACTIVE NEST
# 245 6 244
# 245 7 POINT (-104.87252 40.29698)
# 246 0 246.0
# 246 1 40.280609
# 246 2 -104.855574
# 246 3 2011-04-06
# 246 4 Red-tail Hawk
# 246 5 ACTIVE NEST
# 246 6 246
# 246 7 POINT (-104.90768 40.3181)
# 247 0 247.0
# 247 1 40.282149
# 247 2 -104.85632
# 247 3 2011-04-06
# 247 4 Red-tail Hawk
# 247 5 FLEDGED NEST
# 247 6 247
# 247 7 POINT (-104.90453 40.21122)
# 248 0 248.0
# 248 1 40.083363
# 248 2 -104.973908
# 248 3 2011-04-06
# 248 4 Red-tail Hawk
# 248 5 INACTIVE NEST
# 248 6 248
# 248 7 POINT (-104.93681 40.10679)
# 249 0 249.0
# 249 1 40.35496
# 249 2 -104.815277
# 249 3 2011-04-06
# 249 4 Red-tail Hawk
# 249 5 INACTIVE NEST
# 249 6 249
# 249 7 POINT (-104.79235 40.35343)
# 250 0 250.0
# 250 1 40.26248
# 250 2 -104.632276
# 250 3 2011-04-06
# 250 4 Swainsons Hawk
# 250 5 ACTIVE NEST
# 250 6 250
# 250 7 POINT (-104.70629 40.32989)
# 251 0 251.0
# 251 1 40.094522
# 251 2 -104.794962
# 251 3 2011-04-06
# 251 4 Red-tail Hawk
# 251 5 INACTIVE NEST
# 251 6 251
# 251 7 POINT (-104.81605 40.11569)
# 252 0 252.0
# 252 1 40.135756
# 252 2 -104.602597
# 252 3 2011-04-06
# 252 4 Swainsons Hawk
# 252 5 INACTIVE NEST
# 252 6 252
# 252 7 POINT (-104.56551 40.07967)
# 253 0 253.0
# 253 1 40.157458
# 253 2 -104.618074
# 253 3 2011-04-06
# 253 4 Swainsons Hawk
# 253 5 INACTIVE NEST
# 253 6 253
# 253 7 POINT (-104.69824 40.12011)
# 254 0 254.0
# 254 1 40.156475
# 254 2 -104.870785
# 254 3 2015-08-10
# 254 4 Swainsons Hawk
# 254 5 FLEDGED NEST
# 254 6 254
# 254 7 POINT (-104.91081 40.1328)
# 255 0 255.0
# 255 1 40.166938
# 255 2 -104.650126
# 255 3 2011-04-06
# 255 4 Red-tail Hawk
# 255 5 INACTIVE NEST
# 255 6 255
# 255 7 POINT (-104.6612 40.20892)
# 256 0 256.0
# 256 1 40.074878
# 256 2 -104.775723
# 256 3 2011-04-06
# 256 4 Red-tail Hawk
# 256 5 INACTIVE NEST
# 256 6 256
# 256 7 POINT (-104.8674 40.10971)
# 257 0 257.0
# 257 1 40.040354
# 257 2 -104.976636
# 257 3 2011-04-06
# 257 4 Red-tail Hawk
# 257 5 INACTIVE NEST
# 257 6 257
# 257 7 POINT (-104.97253 39.97542)
# 258 0 258.0
# 258 1 40.082473
# 258 2 -104.972632
# 258 3 2011-04-06
# 258 4 Swainsons Hawk
# 258 5 FLEDGED NEST
# 258 6 258
# 258 7 POINT (-104.94112 40.08915)
# 259 0 259.0
# 259 1 40.369841
# 259 2 -104.630526
# 259 3 2011-04-06
# 259 4 Red-tail Hawk
# 259 5 INACTIVE NEST
# 259 6 259
# 259 7 POINT (-104.71191 40.37316)
# 260 0 260.0
# 260 1 40.356707
# 260 2 -104.815209
# 260 3 2011-04-06
# 260 4 Swainsons Hawk
# 260 5 ACTIVE NEST
# 260 6 260
# 260 7 POINT (-104.76325 40.3786)
# 261 0 261.0
# 261 1 40.184555
# 261 2 -104.842425
# 261 3 2011-04-06
# 261 4 Red-tail Hawk
# 261 5 INACTIVE NEST
# 261 6 261
# 261 7 POINT (-104.93341 40.19634)
# 262 0 262.0
# 262 1 40.221135
# 262 2 -104.752757
# 262 3 2014-06-26
# 262 4 Swainsons Hawk
# 262 5 ACTIVE NEST
# 262 6 262
# 262 7 POINT (-104.73169 40.20356)
# 263 0 263.0
# 263 1 40.217543
# 263 2 -104.967378
# 263 3 2011-04-06
# 263 4 Swainsons Hawk
# 263 5 INACTIVE NEST
# 263 6 263
# 263 7 POINT (-105.03344 40.22257)
# 264 0 264.0
# 264 1 40.238115
# 264 2 -104.633649
# 264 3 2011-04-06
# 264 4 Red-tail Hawk
# 264 5 ACTIVE NEST
# 264 6 264
# 264 7 POINT (-104.61773 40.20718)
# 265 0 265.0
# 265 1 40.139405
# 265 2 -104.67469
# 265 3 2015-03-03
# 265 4 Red-tail Hawk
# 265 5 ACTIVE NEST
# 265 6 265
# 265 7 POINT (-104.68158 40.12377)
# 266 0 266.0
# 266 1 40.14141
# 266 2 -104.659302
# 266 3 2011-04-06
# 266 4 Red-tail Hawk
# 266 5 INACTIVE NEST
# 266 6 266
# 266 7 POINT (-104.61384 40.08174)
# 267 0 267.0
# 267 1 40.152424
# 267 2 -104.655317
# 267 3 2011-04-06
# 267 4 Red-tail Hawk
# 267 5 INACTIVE NEST
# 267 6 267
# 267 7 POINT (-104.69766 40.11934)
# 268 0 268.0
# 268 1 40.132348
# 268 2 -104.876502
# 268 3 2015-03-17
# 268 4 Swainsons Hawk
# 268 5 FLEDGED NEST
# 268 6 268
# 268 7 POINT (-104.90477 40.08878)
# 269 0 269.0
# 269 1 40.13096
# 269 2 -104.867264
# 269 3 2011-04-06
# 269 4 Red-tail Hawk
# 269 5 INACTIVE NEST
# 269 6 269
# 269 7 POINT (-104.82515 40.10568)
# 270 0 270.0
# 270 1 40.271286
# 270 2 -104.680353
# 270 3 2011-04-06
# 270 4 Swainsons Hawk
# 270 5 INACTIVE NEST
# 270 6 270
# 270 7 POINT (-104.73904 40.33248)
# 271 0 271.0
# 271 1 40.149666
# 271 2 -104.871301
# 271 3 2015-07-27
# 271 4 Red-tail Hawk
# 271 5 INACTIVE NEST
# 271 6 271
# 271 7 POINT (-104.9482 40.20404)
# 272 0 272.0
# 272 1 40.149492
# 272 2 -104.8725
# 272 3 2015-07-27
# 272 4 Red-tail Hawk
# 272 5 FLEDGED NEST
# 272 6 272
# 272 7 POINT (-104.89206 40.13798)
# 273 0 273.0
# 273 1 40.15034
# 273 2 -104.872404
# 273 3 2015-07-27
# 273 4 Red-tail Hawk
# 273 5 ACTIVE NEST
# 273 6 273
# 273 7 POINT (-104.92523 40.2018)
# 274 0 274.0
# 274 1 40.246646
# 274 2 -104.730501
# 274 3 2011-04-06
# 274 4 Red-tail Hawk
# 274 5 INACTIVE NEST
# 274 6 274
# 274 7 POINT (-104.76461 40.26577)
# 275 0 276.0
# 275 1 40.246662
# 275 2 -104.731529
# 275 3 2011-04-06
# 275 4 Swainsons Hawk
# 275 5 INACTIVE NEST
# 275 6 276
# 275 7 POINT (-104.69659 40.20409)
# 276 0 277.0
# 276 1 40.24669
# 276 2 -104.728128
# 276 3 2011-04-06
# 276 4 Swainsons Hawk
# 276 5 ACTIVE NEST
# 276 6 277
# 276 7 POINT (-104.72966 40.28346)
# 277 0 278.0
# 277 1 40.215623
# 277 2 -104.650392
# 277 3 2011-04-06
# 277 4 Red-tail Hawk
# 277 5 INACTIVE NEST
# 277 6 278
# 277 7 POINT (-104.64259 40.26394)
# 278 0 279.0
# 278 1 40.215362
# 278 2 -104.650986
# 278 3 2011-04-06
# 278 4 Red-tail Hawk
# 278 5 ACTIVE NEST
# 278 6 279
# 278 7 POINT (-104.6723 40.16059)
# 279 0 280.0
# 279 1 40.264665
# 279 2 -104.665357
# 279 3 2011-04-06
# 279 4 Red-tail Hawk
# 279 5 ACTIVE NEST
# 279 6 280
# 279 7 POINT (-104.69779 40.31752)
# 280 0 281.0
# 280 1 40.265551
# 280 2 -104.666134
# 280 3 2011-04-06
# 280 4 Red-tail Hawk
# 280 5 ACTIVE NEST
# 280 6 281
# 280 7 POINT (-104.58348 40.2747)
# 281 0 282.0
# 281 1 40.246151
# 281 2 -104.711471
# 281 3 2011-08-02
# 281 4 Red-tail Hawk
# 281 5 INACTIVE NEST
# 281 6 282
# 281 7 POINT (-104.6707 40.21222)
# 282 0 283.0
# 282 1 39.979003
# 282 2 -104.960247
# 282 3 2011-08-02
# 282 4 Swainsons Hawk
# 282 5 INACTIVE NEST
# 282 6 283
# 282 7 POINT (-104.96309 39.91229)
# 283 0 284.0
# 283 1 39.940391
# 283 2 -105.024798
# 283 3 2011-08-02
# 283 4 Red-tail Hawk
# 283 5 ACTIVE NEST
# 283 6 284
# 283 7 POINT (-104.95535 39.88169)
# 284 0 285.0
# 284 1 40.155977
# 284 2 -104.637058
# 284 3 2011-08-02
# 284 4 Swainsons Hawk
# 284 5 ACTIVE NEST
# 284 6 285
# 284 7 POINT (-104.64998 40.09792)
# 285 0 286.0
# 285 1 40.140005
# 285 2 -104.675341
# 285 3 2015-03-19
# 285 4 Swainsons Hawk
# 285 5 ACTIVE NEST
# 285 6 286
# 285 7 POINT (-104.69465 40.16759)
# 286 0 287.0
# 286 1 40.140923
# 286 2 -104.676326
# 286 3 2015-03-19
# 286 4 Swainsons Hawk
# 286 5 ACTIVE NEST
# 286 6 287
# 286 7 POINT (-104.65516 40.18008)
# 287 0 288.0
# 287 1 40.262209
# 287 2 -104.677883
# 287 3 2011-08-02
# 287 4 Red-tail Hawk
# 287 5 FLEDGED NEST
# 287 6 288
# 287 7 POINT (-104.74047 40.30813)
# 288 0 289.0
# 288 1 40.151287
# 288 2 -104.73021
# 288 3 2014-04-08
# 288 4 Red-tail Hawk
# 288 5 INACTIVE NEST
# 288 6 289
# 288 7 POINT (-104.78174 40.20089)
# 289 0 290.0
# 289 1 40.151167
# 289 2 -104.729671
# 289 3 2014-04-08
# 289 4 Swainsons Hawk
# 289 5 ACTIVE NEST
# 289 6 290
# 289 7 POINT (-104.716 40.0965)
# 290 0 291.0
# 290 1 40.152257
# 290 2 -104.668938
# 290 3 2011-08-02
# 290 4 Red-tail Hawk
# 290 5 INACTIVE NEST
# 290 6 291
# 290 7 POINT (-104.72083 40.16656)
# 291 0 292.0
# 291 1 40.478033
# 291 2 -104.594495
# 291 3 2011-11-07
# 291 4 Swainsons Hawk
# 291 5 INACTIVE NEST
# 291 6 292
# 291 7 POINT (-104.64909 40.41189)
# 292 0 293.0
# 292 1 40.106174
# 292 2 -105.041608
# 292 3 2011-11-07
# 292 4 Swainsons Hawk
# 292 5 INACTIVE NEST
# 292 6 293
# 292 7 POINT (-105.08851 40.06113)
# 293 0 294.0
# 293 1 40.104407
# 293 2 -104.981466
# 293 3 2011-11-07
# 293 4 Swainsons Hawk
# 293 5 INACTIVE NEST
# 293 6 294
# 293 7 POINT (-104.92816 40.08412)
# 294 0 295.0
# 294 1 40.137484
# 294 2 -104.859462
# 294 3 2011-11-07
# 294 4 Swainsons Hawk
# 294 5 FLEDGED NEST
# 294 6 295
# 294 7 POINT (-104.88158 40.08582)
# 295 0 296.0
# 295 1 40.131479
# 295 2 -104.930555
# 295 3 2011-11-07
# 295 4 Red-tail Hawk
# 295 5 ACTIVE NEST
# 295 6 296
# 295 7 POINT (-105.02018 40.15646)
# 296 0 297.0
# 296 1 40.149371
# 296 2 -104.713464
# 296 3 2015-06-02
# 296 4 Swainsons Hawk
# 296 5 ACTIVE NEST
# 296 6 297
# 296 7 POINT (-104.77323 40.09031)
# 297 0 298.0
# 297 1 40.21415
# 297 2 -104.902777
# 297 3 2011-11-07
# 297 4 Red-tail Hawk
# 297 5 ACTIVE NEST
# 297 6 298
# 297 7 POINT (-104.81285 40.24195)
# 298 0 299.0
# 298 1 40.106174
# 298 2 -105.041608
# 298 3 2011-11-07
# 298 4 Swainsons Hawk
# 298 5 INACTIVE NEST
# 298 6 299
# 298 7 POINT (-105.05372 40.0753)
# 299 0 300.0
# 299 1 40.199408
# 299 2 -104.989102
# 299 3 2011-11-07
# 299 4 Red-tail Hawk
# 299 5 ACTIVE NEST
# 299 6 300
# 299 7 POINT (-105.0724 40.26148)
# 300 0 301.0
# 300 1 40.174876
# 300 2 -105.002315
# 300 3 2011-11-07
# 300 4 Red-tail Hawk
# 300 5 INACTIVE NEST
# 300 6 301
# 300 7 POINT (-104.96824 40.18357)
# 301 0 302.0
# 301 1 40.261584
# 301 2 -104.692032
# 301 3 2011-11-07
# 301 4 Swainsons Hawk
# 301 5 INACTIVE NEST
# 301 6 302
# 301 7 POINT (-104.72059 40.32503)
# 302 0 303.0
# 302 1 40.030949
# 302 2 -104.693082
# 302 3 2011-12-29
# 302 4 Swainsons Hawk
# 302 5 ACTIVE NEST
# 302 6 303
# 302 7 POINT (-104.77518 39.96141)
# 303 0 304.0
# 303 1 40.163862
# 303 2 -104.584823
# 303 3 2011-12-29
# 303 4 Swainsons Hawk
# 303 5 ACTIVE NEST
# 303 6 304
# 303 7 POINT (-104.51274 40.15899)
# 304 0 305.0
# 304 1 40.199161
# 304 2 -104.916275
# 304 3 2011-12-29
# 304 4 Red-tail Hawk
# 304 5 INACTIVE NEST
# 304 6 305
# 304 7 POINT (-104.93908 40.25292)
# 305 0 306.0
# 305 1 40.36628
# 305 2 -104.6398
# 305 3 2011-12-29
# 305 4 Red-tail Hawk
# 305 5 ACTIVE NEST
# 305 6 306
# 305 7 POINT (-104.67893 40.40555)
# 306 0 307.0
# 306 1 40.178074
# 306 2 -104.858927
# 306 3 2015-04-03
# 306 4 Red-tail Hawk
# 306 5 ACTIVE NEST
# 306 6 307
# 306 7 POINT (-104.7762 40.14175)
# 307 0 308.0
# 307 1 40.318213
# 307 2 -104.818666
# 307 3 2011-12-29
# 307 4 Swainsons Hawk
# 307 5 INACTIVE NEST
# 307 6 308
# 307 7 POINT (-104.79386 40.31468)
# 308 0 309.0
# 308 1 40.152794
# 308 2 -104.80164
# 308 3 2011-12-29
# 308 4 Red-tail Hawk
# 308 5 ACTIVE NEST
# 308 6 309
# 308 7 POINT (-104.77532 40.19692)
# 309 0 310.0
# 309 1 40.100899
# 309 2 -104.783573
# 309 3 2015-06-02
# 309 4 Swainsons Hawk
# 309 5 ACTIVE NEST
# 309 6 310
# 309 7 POINT (-104.79807 40.09809)
# 310 0 311.0
# 310 1 40.102859
# 310 2 -104.77759
# 310 3 2012-01-09
# 310 4 Swainsons Hawk
# 310 5 INACTIVE NEST
# 310 6 311
# 310 7 POINT (-104.82053 40.14107)
# 311 0 312.0
# 311 1 40.091474
# 311 2 -104.762668
# 311 3 2012-01-09
# 311 4 Swainsons Hawk
# 311 5 INACTIVE NEST
# 311 6 312
# 311 7 POINT (-104.73218 40.13379)
# 312 0 313.0
# 312 1 40.099226
# 312 2 -104.760892
# 312 3 2012-01-09
# 312 4 Swainsons Hawk
# 312 5 INACTIVE NEST
# 312 6 313
# 312 7 POINT (-104.70071 40.05732)
# 313 0 314.0
# 313 1 40.134344
# 313 2 -104.631084
# 313 3 2012-01-09
# 313 4 Swainsons Hawk
# 313 5 INACTIVE NEST
# 313 6 314
# 313 7 POINT (-104.56255 40.10769)
# 314 0 315.0
# 314 1 40.210835
# 314 2 -104.588448
# 314 3 2012-01-09
# 314 4 Red-tail Hawk
# 314 5 ACTIVE NEST
# 314 6 315
# 314 7 POINT (-104.66642 40.19258)
# 315 0 316.0
# 315 1 40.076373
# 315 2 -104.774093
# 315 3 2012-01-25
# 315 4 Red-tail Hawk
# 315 5 INACTIVE NEST
# 315 6 316
# 315 7 POINT (-104.68533 40.06504)
# 316 0 317.0
# 316 1 40.075321
# 316 2 -104.775908
# 316 3 2014-08-12
# 316 4 Red-tail Hawk
# 316 5 ACTIVE NEST
# 316 6 317
# 316 7 POINT (-104.76088 40.02459)
# 317 0 318.0
# 317 1 40.147013
# 317 2 -104.652264
# 317 3 2015-08-05
# 317 4 Swainsons Hawk
# 317 5 ACTIVE NEST
# 317 6 318
# 317 7 POINT (-104.55929 40.07828)
# 318 0 319.0
# 318 1 40.358378
# 318 2 -104.632159
# 318 3 2012-01-25
# 318 4 Swainsons Hawk
# 318 5 ACTIVE NEST
# 318 6 319
# 318 7 POINT (-104.5922 40.30088)
# 319 0 320.0
# 319 1 40.353379
# 319 2 -104.639655
# 319 3 2012-01-25
# 319 4 Swainsons Hawk
# 319 5 ACTIVE NEST
# 319 6 320
# 319 7 POINT (-104.54761 40.40162)
# 320 0 321.0
# 320 1 40.255879
# 320 2 -104.629572
# 320 3 2012-01-25
# 320 4 Red-tail Hawk
# 320 5 ACTIVE NEST
# 320 6 321
# 320 7 POINT (-104.66833 40.23653)
# 321 0 322.0
# 321 1 40.211309
# 321 2 -104.64166
# 321 3 2012-01-25
# 321 4 Red-tail Hawk
# 321 5 ACTIVE NEST
# 321 6 322
# 321 7 POINT (-104.55826 40.26254)
# 322 0 323.0
# 322 1 40.203439
# 322 2 -104.616571
# 322 3 2014-08-11
# 322 4 Swainsons Hawk
# 322 5 ACTIVE NEST
# 322 6 323
# 322 7 POINT (-104.70008 40.21558)
# 323 0 324.0
# 323 1 40.344228
# 323 2 -104.878427
# 323 3 2012-02-02
# 323 4 Swainsons Hawk
# 323 5 ACTIVE NEST
# 323 6 324
# 323 7 POINT (-104.86709 40.4066)
# 324 0 325.0
# 324 1 40.155485
# 324 2 -104.62063
# 324 3 2012-02-02
# 324 4 Red-tail Hawk
# 324 5 FLEDGED NEST
# 324 6 325
# 324 7 POINT (-104.61962 40.17535)
# 325 0 326.0
# 325 1 40.313547
# 325 2 -104.93944
# 325 3 2012-02-02
# 325 4 Red-tail Hawk
# 325 5 INACTIVE NEST
# 325 6 326
# 325 7 POINT (-104.92065 40.30481)
# 326 0 327.0
# 326 1 40.3144
# 326 2 -104.943768
# 326 3 2012-02-02
# 326 4 Red-tail Hawk
# 326 5 ACTIVE NEST
# 326 6 327
# 326 7 POINT (-104.86216 40.35976)
# 327 0 328.0
# 327 1 40.315032
# 327 2 -104.944199
# 327 3 2012-02-02
# 327 4 Red-tail Hawk
# 327 5 INACTIVE NEST
# 327 6 328
# 327 7 POINT (-105.02432 40.29233)
# 328 0 329.0
# 328 1 40.085519
# 328 2 -104.82367
# 328 3 2012-02-02
# 328 4 Swainsons Hawk
# 328 5 INACTIVE NEST
# 328 6 329
# 328 7 POINT (-104.73028 40.03769)
# 329 0 330.0
# 329 1 40.188799
# 329 2 -104.789955
# 329 3 2012-01-26
# 329 4 Red-tail Hawk
# 329 5 INACTIVE NEST
# 329 6 330
# 329 7 POINT (-104.78475 40.16966)
# 330 0 331.0
# 330 1 40.152506
# 330 2 -104.885623
# 330 3 2015-06-15
# 330 4 Red-tail Hawk
# 330 5 ACTIVE NEST
# 330 6 331
# 330 7 POINT (-104.92411 40.10052)
# 331 0 332.0
# 331 1 39.985402
# 331 2 -104.958097
# 331 3 2012-02-22
# 331 4 Red-tail Hawk
# 331 5 INACTIVE NEST
# 331 6 332
# 331 7 POINT (-104.93576 39.99537)
# 332 0 333.0
# 332 1 40.277929
# 332 2 -104.791153
# 332 3 2012-02-15
# 332 4 Swainsons Hawk
# 332 5 ACTIVE NEST
# 332 6 333
# 332 7 POINT (-104.83958 40.2346)
# 333 0 334.0
# 333 1 40.029277
# 333 2 -104.93009
# 333 3 2012-02-21
# 333 4 Red-tail Hawk
# 333 5 ACTIVE NEST
# 333 6 334
# 333 7 POINT (-104.89702 40.09847)
# 334 0 335.0
# 334 1 40.119698
# 334 2 -104.857566
# 334 3 2014-06-27
# 334 4 Swainsons Hawk
# 334 5 FLEDGED NEST
# 334 6 335
# 334 7 POINT (-104.83398 40.14198)
# 335 0 336.0
# 335 1 40.153101
# 335 2 -104.859217
# 335 3 2012-02-20
# 335 4 Swainsons Hawk
# 335 5 INACTIVE NEST
# 335 6 336
# ...
# 753 0 806.0
# 753 1 40.049147
# 753 2 -105.151991
# 753 3 2014-12-10
# 753 4 Red-tail Hawk
# 753 5 INACTIVE NEST
# 753 6 806
# 753 7 POINT (-105.08132 40.04744)
# 754 0 807.0
# 754 1 40.049775
# 754 2 -105.142429
# 754 3 2014-12-10
# 754 4 Swainsons Hawk
# 754 5 INACTIVE NEST
# 754 6 807
# 754 7 POINT (-105.10034 40.08901)
# 755 0 808.0
# 755 1 40.463831
# 755 2 -105.003302
# 755 3 2014-12-11
# 755 4 Red-tail Hawk
# 755 5 ACTIVE NEST
# 755 6 808
# 755 7 POINT (-104.92557 40.39469)
# 756 0 809.0
# 756 1 40.444
# 756 2 -105.022215
# 756 3 2014-12-11
# 756 4 Red-tail Hawk
# 756 5 FLEDGED NEST
# 756 6 809
# 756 7 POINT (-105.06452 40.40328)
# 757 0 810.0
# 757 1 40.46002
# 757 2 -105.098326
# 757 3 2014-12-11
# 757 4 Red-tail Hawk
# 757 5 INACTIVE NEST
# 757 6 810
# 757 7 POINT (-105.13229 40.43462)
# 758 0 811.0
# 758 1 40.460025
# 758 2 -105.098227
# 758 3 2014-12-11
# 758 4 Swainsons Hawk
# 758 5 FLEDGED NEST
# 758 6 811
# 758 7 POINT (-105.12911 40.47413)
# 759 0 812.0
# 759 1 40.455833
# 759 2 -105.093921
# 759 3 2014-12-11
# 759 4 Red-tail Hawk
# 759 5 INACTIVE NEST
# 759 6 812
# 759 7 POINT (-105.00742 40.41882)
# 760 0 813.0
# 760 1 40.453353
# 760 2 -105.097946
# 760 3 2014-12-11
# 760 4 Red-tail Hawk
# 760 5 INACTIVE NEST
# 760 6 813
# 760 7 POINT (-105.04713 40.48931)
# 761 0 814.0
# 761 1 40.087748
# 761 2 -104.429377
# 761 3 2015-01-06
# 761 4 Red-tail Hawk
# 761 5 INACTIVE NEST
# 761 6 814
# 761 7 POINT (-104.33836 40.13707)
# 762 0 815.0
# 762 1 40.087544
# 762 2 -104.511662
# 762 3 2015-01-08
# 762 4 Red-tail Hawk
# 762 5 INACTIVE NEST
# 762 6 815
# 762 7 POINT (-104.47385 40.14823)
# 763 0 816.0
# 763 1 40.086033
# 763 2 -104.527106
# 763 3 2015-01-08
# 763 4 Swainsons Hawk
# 763 5 INACTIVE NEST
# 763 6 816
# 763 7 POINT (-104.43836 40.10827)
# 764 0 817.0
# 764 1 40.348578
# 764 2 -104.436659
# 764 3 2015-01-14
# 764 4 Swainsons Hawk
# 764 5 INACTIVE NEST
# 764 6 817
# 764 7 POINT (-104.52794 40.38915)
# 765 0 818.0
# 765 1 40.208017
# 765 2 -104.615486
# 765 3 2015-01-16
# 765 4 Red-tail Hawk
# 765 5 INACTIVE NEST
# 765 6 818
# 765 7 POINT (-104.53505 40.23331)
# 766 0 819.0
# 766 1 40.211279
# 766 2 -104.61651
# 766 3 2015-01-16
# 766 4 Red-tail Hawk
# 766 5 INACTIVE NEST
# 766 6 819
# 766 7 POINT (-104.70512 40.20257)
# 767 0 820.0
# 767 1 40.188471
# 767 2 -104.617944
# 767 3 2015-01-16
# 767 4 Red-tail Hawk
# 767 5 FLEDGED NEST
# 767 6 820
# 767 7 POINT (-104.61153 40.22997)
# 768 0 821.0
# 768 1 40.356013
# 768 2 -104.436612
# 768 3 2015-01-19
# 768 4 Swainsons Hawk
# 768 5 FLEDGED NEST
# 768 6 821
# 768 7 POINT (-104.47879 40.38681)
# 769 0 822.0
# 769 1 40.350028
# 769 2 -104.418768
# 769 3 2015-03-31
# 769 4 Red-tail Hawk
# 769 5 FLEDGED NEST
# 769 6 822
# 769 7 POINT (-104.4959 40.29888)
# 770 0 823.0
# 770 1 40.114163
# 770 2 -104.895532
# 770 3 2015-01-21
# 770 4 Red-tail Hawk
# 770 5 INACTIVE NEST
# 770 6 823
# 770 7 POINT (-104.82137 40.1437)
# 771 0 824.0
# 771 1 40.1142
# 771 2 -104.895566
# 771 3 2015-01-21
# 771 4 Swainsons Hawk
# 771 5 INACTIVE NEST
# 771 6 824
# 771 7 POINT (-104.83308 40.10721)
# 772 0 825.0
# 772 1 40.114079
# 772 2 -104.894287
# 772 3 2015-01-21
# 772 4 Red-tail Hawk
# 772 5 ACTIVE NEST
# 772 6 825
# 772 7 POINT (-104.85768 40.13616)
# 773 0 826.0
# 773 1 40.098223
# 773 2 -104.788769
# 773 3 2015-06-23
# 773 4 Swainsons Hawk
# 773 5 FLEDGED NEST
# 773 6 826
# 773 7 POINT (-104.79081 40.0633)
# 774 0 827.0
# 774 1 40.030208
# 774 2 -104.858155
# 774 3 2015-01-28
# 774 4 Red-tail Hawk
# 774 5 ACTIVE NEST
# 774 6 827
# 774 7 POINT (-104.8655 40.07496)
# 775 0 828.0
# 775 1 40.045998
# 775 2 -104.864894
# 775 3 2015-01-28
# 775 4 Swainsons Hawk
# 775 5 INACTIVE NEST
# 775 6 828
# 775 7 POINT (-104.84975 40.04016)
# 776 0 829.0
# 776 1 40.046556
# 776 2 -104.863907
# 776 3 2015-01-28
# 776 4 Red-tail Hawk
# 776 5 INACTIVE NEST
# 776 6 829
# 776 7 POINT (-104.91933 39.9874)
# 777 0 830.0
# 777 1 40.041525
# 777 2 -104.855916
# 777 3 2015-01-28
# 777 4 Red-tail Hawk
# 777 5 ACTIVE NEST
# 777 6 830
# 777 7 POINT (-104.87996 40.03639)
# 778 0 831.0
# 778 1 40.056349
# 778 2 -104.706309
# 778 3 2015-02-06
# 778 4 Swainsons Hawk
# 778 5 INACTIVE NEST
# 778 6 831
# 778 7 POINT (-104.68996 40.06282)
# 779 0 832.0
# 779 1 40.057262
# 779 2 -104.708569
# 779 3 2015-03-16
# 779 4 Red-tail Hawk
# 779 5 FLEDGED NEST
# 779 6 832
# 779 7 POINT (-104.72566 40.12896)
# 780 0 833.0
# 780 1 40.057288
# 780 2 -104.708716
# 780 3 2015-03-16
# 780 4 Swainsons Hawk
# 780 5 ACTIVE NEST
# 780 6 833
# 780 7 POINT (-104.72688 40.04253)
# 781 0 834.0
# 781 1 40.057181
# 781 2 -104.708974
# 781 3 2015-03-16
# 781 4 Swainsons Hawk
# 781 5 INACTIVE NEST
# 781 6 834
# 781 7 POINT (-104.65004 40.02827)
# 782 0 835.0
# 782 1 40.211366
# 782 2 -104.911597
# 782 3 2015-02-09
# 782 4 Red-tail Hawk
# 782 5 FLEDGED NEST
# 782 6 835
# 782 7 POINT (-104.91519 40.23761)
# 783 0 836.0
# 783 1 40.211286
# 783 2 -104.911633
# 783 3 2015-02-09
# 783 4 Swainsons Hawk
# 783 5 INACTIVE NEST
# 783 6 836
# 783 7 POINT (-104.82068 40.14375)
# 784 0 837.0
# 784 1 40.032407
# 784 2 -104.66334
# 784 3 2015-02-09
# 784 4 Red-tail Hawk
# 784 5 INACTIVE NEST
# 784 6 837
# 784 7 POINT (-104.67659 40.06729)
# 785 0 838.0
# 785 1 40.057069
# 785 2 -104.820346
# 785 3 2015-02-12
# 785 4 Swainsons Hawk
# 785 5 INACTIVE NEST
# 785 6 838
# 785 7 POINT (-104.90945 40.06279)
# 786 0 839.0
# 786 1 40.057304
# 786 2 -104.821032
# 786 3 2015-02-12
# 786 4 Swainsons Hawk
# 786 5 INACTIVE NEST
# 786 6 839
# 786 7 POINT (-104.84752 40.11711)
# 787 0 840.0
# 787 1 40.139296
# 787 2 -104.993893
# 787 3 2015-02-18
# 787 4 Red-tail Hawk
# 787 5 INACTIVE NEST
# 787 6 840
# 787 7 POINT (-104.93848 40.16313)
# 788 0 841.0
# 788 1 40.151933
# 788 2 -104.980898
# 788 3 2015-02-20
# 788 4 Swainsons Hawk
# 788 5 INACTIVE NEST
# 788 6 841
# 788 7 POINT (-104.99521 40.11863)
# 789 0 842.0
# 789 1 40.014175
# 789 2 -105.126386
# 789 3 2015-02-20
# 789 4 Swainsons Hawk
# 789 5 FLEDGED NEST
# 789 6 842
# 789 7 POINT (-105.17925 40.0679)
# 790 0 843.0
# 790 1 40.007517
# 790 2 -105.119596
# 790 3 2015-02-20
# 790 4 Red-tail Hawk
# 790 5 INACTIVE NEST
# 790 6 843
# 790 7 POINT (-105.13401 39.93887)
# 791 0 844.0
# 791 1 40.014859
# 791 2 -105.11541
# 791 3 2015-02-20
# 791 4 Red-tail Hawk
# 791 5 INACTIVE NEST
# 791 6 844
# 791 7 POINT (-105.20091 40.03907)
# 792 0 845.0
# 792 1 40.010111
# 792 2 -105.121219
# 792 3 2015-02-20
# 792 4 Red-tail Hawk
# 792 5 FLEDGED NEST
# 792 6 845
# 792 7 POINT (-105.08961 39.98107)
# 793 0 846.0
# 793 1 40.009698
# 793 2 -105.113618
# 793 3 2015-02-20
# 793 4 Swainsons Hawk
# 793 5 INACTIVE NEST
# 793 6 846
# 793 7 POINT (-105.09268 39.94469)
# 794 0 847.0
# 794 1 40.055237
# 794 2 -104.986777
# 794 3 2015-02-24
# 794 4 Swainsons Hawk
# 794 5 FLEDGED NEST
# 794 6 847
# 794 7 POINT (-105.01906 40.00125)
# 795 0 848.0
# 795 1 40.140663
# 795 2 -104.676056
# 795 3 2015-03-19
# 795 4 Red-tail Hawk
# 795 5 INACTIVE NEST
# 795 6 848
# 795 7 POINT (-104.7536 40.20598)
# 796 0 849.0
# 796 1 40.125167
# 796 2 -104.669795
# 796 3 2015-07-09
# 796 4 Swainsons Hawk
# 796 5 FLEDGED NEST
# 796 6 849
# 796 7 POINT (-104.6928 40.13614)
# 797 0 851.0
# 797 1 40.145773
# 797 2 -104.841214
# 797 3 2015-06-12
# 797 4 Red-tail Hawk
# 797 5 FLEDGED NEST
# 797 6 851
# 797 7 POINT (-104.90825 40.17937)
# 798 0 852.0
# 798 1 40.144499
# 798 2 -104.839908
# 798 3 2015-06-12
# 798 4 Red-tail Hawk
# 798 5 INACTIVE NEST
# 798 6 852
# 798 7 POINT (-104.76546 40.15663)
# 799 0 853.0
# 799 1 40.145211
# 799 2 -104.83618
# 799 3 2015-03-13
# 799 4 Red-tail Hawk
# 799 5 INACTIVE NEST
# 799 6 853
# 799 7 POINT (-104.89834 40.11963)
# 800 0 854.0
# 800 1 40.139674
# 800 2 -104.836056
# 800 3 2015-03-13
# 800 4 Swainsons Hawk
# 800 5 ACTIVE NEST
# 800 6 854
# 800 7 POINT (-104.88898 40.12566)
# 801 0 855.0
# 801 1 40.131117
# 801 2 -104.745545
# 801 3 2015-03-16
# 801 4 Swainsons Hawk
# 801 5 ACTIVE NEST
# 801 6 855
# 801 7 POINT (-104.68922 40.09929)
# 802 0 856.0
# 802 1 40.211016
# 802 2 -104.599269
# 802 3 2015-05-22
# 802 4 Swainsons Hawk
# 802 5 COULD NOT SEE NEST
# 802 6 856
# 802 7 POINT (-104.55478 40.14262)
# 803 0 857.0
# 803 1 40.498638
# 803 2 -105.10217
# 803 3 2015-03-18
# 803 4 Red-tail Hawk
# 803 5 ACTIVE NEST
# 803 6 857
# 803 7 POINT (-105.07142 40.54964)
# 804 0 858.0
# 804 1 40.416655
# 804 2 -105.129483
# 804 3 2015-03-18
# 804 4 Swainsons Hawk
# 804 5 FLEDGED NEST
# 804 6 858
# 804 7 POINT (-105.14924 40.46454)
# 805 0 859.0
# 805 1 40.058621
# 805 2 -104.62285
# 805 3 2015-04-16
# 805 4 Red-tail Hawk
# 805 5 FLEDGED NEST
# 805 6 859
# 805 7 POINT (-104.68596 40.07383)
# 806 0 860.0
# 806 1 40.058602
# 806 2 -104.612157
# 806 3 2015-03-19
# 806 4 Red-tail Hawk
# 806 5 ACTIVE NEST
# 806 6 860
# 806 7 POINT (-104.60278 40.08161)
# 807 0 861.0
# 807 1 40.163707
# 807 2 -104.703622
# 807 3 2015-03-23
# 807 4 Red-tail Hawk
# 807 5 INACTIVE NEST
# 807 6 861
# 807 7 POINT (-104.63891 40.12857)
# 808 0 862.0
# 808 1 40.167149
# 808 2 -104.701369
# 808 3 2015-03-23
# 808 4 Red-tail Hawk
# 808 5 ACTIVE NEST
# 808 6 862
# 808 7 POINT (-104.73128 40.19092)
# 809 0 863.0
# 809 1 40.167166
# 809 2 -104.700325
# 809 3 2015-03-23
# 809 4 Red-tail Hawk
# 809 5 INACTIVE NEST
# 809 6 863
# 809 7 POINT (-104.74839 40.18424)
# 810 0 864.0
# 810 1 40.218405
# 810 2 -104.980569
# 810 3 2015-07-27
# 810 4 Red-tail Hawk
# 810 5 FLEDGED NEST
# 810 6 864
# 810 7 POINT (-105.06553 40.17014)
# 811 0 865.0
# 811 1 40.192682
# 811 2 -104.880386
# 811 3 2015-06-03
# 811 4 Red-tail Hawk
# 811 5 ACTIVE NEST
# 811 6 865
# 811 7 POINT (-104.95442 40.14821)
# 812 0 866.0
# 812 1 40.153187
# 812 2 -104.8346
# 812 3 2015-05-13
# 812 4 Swainsons Hawk
# 812 5 ACTIVE NEST
# 812 6 866
# 812 7 POINT (-104.83995 40.13489)
# 813 0 867.0
# 813 1 40.154771
# 813 2 -104.832801
# 813 3 2015-05-13
# 813 4 Red-tail Hawk
# 813 5 ACTIVE NEST
# 813 6 867
# 813 7 POINT (-104.80713 40.19204)
# 814 0 868.0
# 814 1 40.159337
# 814 2 -104.730777
# 814 3 2015-06-02
# 814 4 Red-tail Hawk
# 814 5 INACTIVE NEST
# 814 6 868
# 814 7 POINT (-104.79555 40.08931)
# 815 0 869.0
# 815 1 40.128012
# 815 2 -104.675725
# 815 3 2015-04-29
# 815 4 Swainsons Hawk
# 815 5 INACTIVE NEST
# 815 6 869
# 815 7 POINT (-104.67358 40.16967)
# 816 0 870.0
# 816 1 40.12105
# 816 2 -104.678276
# 816 3 2015-04-29
# 816 4 Red-tail Hawk
# 816 5 ACTIVE NEST
# 816 6 870
# 816 7 POINT (-104.65542 40.12024)
# 817 0 871.0
# 817 1 40.132081
# 817 2 -104.676521
# 817 3 2015-04-29
# 817 4 Swainsons Hawk
# 817 5 ACTIVE NEST
# 817 6 871
# 817 7 POINT (-104.68749 40.1987)
# 818 0 872.0
# 818 1 40.135098
# 818 2 -104.970502
# 818 3 2015-07-29
# 818 4 Swainsons Hawk
# 818 5 FLEDGED NEST
# 818 6 872
# 818 7 POINT (-105.04937 40.13417)
# 819 0 873.0
# 819 1 40.142579
# 819 2 -104.975146
# 819 3 2015-07-29
# 819 4 Swainsons Hawk
# 819 5 ACTIVE NEST
# 819 6 873
# 819 7 POINT (-105.06517 40.1029)
# 820 0 874.0
# 820 1 40.118346
# 820 2 -104.993852
# 820 3 2015-07-29
# 820 4 Swainsons Hawk
# 820 5 ACTIVE NEST
# 820 6 874
# 820 7 POINT (-104.99311 40.14737)
# 821 0 875.0
# 821 1 40.10994
# 821 2 -104.983845
# 821 3 2015-07-29
# 821 4 Swainsons Hawk
# 821 5 INACTIVE NEST
# 821 6 875
# 821 7 POINT (-104.93318 40.10669)
# 822 0 876.0
# 822 1 40.110156
# 822 2 -104.983312
# 822 3 2015-07-29
# 822 4 Red-tail Hawk
# 822 5 FLEDGED NEST
# 822 6 876
# 822 7 POINT (-104.90706 40.04251)
# 823 0 877.0
# 823 1 40.064131
# 823 2 -104.670375
# 823 3 2015-07-29
# 823 4 Swainsons Hawk
# 823 5 INACTIVE NEST
# 823 6 877
# 823 7 POINT (-104.72305 40.06901)
# 824 0 878.0
# 824 1 40.073284
# 824 2 -104.682972
# 824 3 2015-07-29
# 824 4 Red-tail Hawk
# 824 5 INACTIVE NEST
# 824 6 878
# 824 7 POINT (-104.59907 40.07846)
# 825 0 879.0
# 825 1 40.08895
# 825 2 -104.896209
# 825 3 2015-08-11
# 825 4 Red-tail Hawk
# 825 5 FLEDGED NEST
# 825 6 879
# 825 7 POINT (-104.86851 40.11922)
# 826 0 880.0
# 826 1 40.074107
# 826 2 -104.688067
# 826 3 2015-07-09
# 826 4 Red-tail Hawk
# 826 5 INACTIVE NEST
# 826 6 880
# 826 7 POINT (-104.75285 40.00713)
# 827 0 881.0
# 827 1 40.162751
# 827 2 -104.73058
# 827 3 2015-05-28
# 827 4 Swainsons Hawk
# 827 5 ACTIVE NEST
# 827 6 881
# 827 7 POINT (-104.69085 40.09987)
# 828 0 882.0
# 828 1 40.04562
# 828 2 -104.908517
# 828 3 2015-05-22
# 828 4 Red-tail Hawk
# 828 5 ACTIVE NEST
# 828 6 882
# 828 7 POINT (-104.9876 40.0091)
# 829 0 883.0
# 829 1 40.1099
# 829 2 -104.879429
# 829 3 2015-08-14
# 829 4 Red-tail Hawk
# 829 5 FLEDGED NEST
# 829 6 883
# 829 7 POINT (-104.88351 40.06975)
# 830 0 884.0
# 830 1 40.068421
# 830 2 -104.862728
# 830 3 2015-06-03
# 830 4 Red-tail Hawk
# 830 5 ACTIVE NEST
# 830 6 884
# 830 7 POINT (-104.91311 40.00704)
# 831 0 885.0
# 831 1 40.189083
# 831 2 -104.865355
# 831 3 2015-06-05
# 831 4 Red-tail Hawk
# 831 5 ACTIVE NEST
# 831 6 885
# 831 7 POINT (-104.92905 40.24316)
# 832 0 886.0
# 832 1 39.988339
# 832 2 -105.067373
# 832 3 2015-06-11
# 832 4 Swainsons Hawk
# 832 5 ACTIVE NEST
# 832 6 886
# 832 7 POINT (-105.15664 39.92748)
# 833 0 887.0
# 833 1 39.986753
# 833 2 -105.067144
# 833 3 2015-06-11
# 833 4 Swainsons Hawk
# 833 5 INACTIVE NEST
# 833 6 887
# 833 7 POINT (-105.0972 39.99392)
# 834 0 888.0
# 834 1 39.986721
# 834 2 -105.066816
# 834 3 2015-06-11
# 834 4 Red-tail Hawk
# 834 5 INACTIVE NEST
# 834 6 888
# 834 7 POINT (-105.02362 39.99817)
# 835 0 889.0
# 835 1 39.986176
# 835 2 -105.065648
# 835 3 2015-06-11
# 835 4 Red-tail Hawk
# 835 5 INACTIVE NEST
# 835 6 889
# 835 7 POINT (-105.08037 40.03062)
# 836 0 890.0
# 836 1 40.130182
# 836 2 -104.654085
# 836 3 2015-07-28
# 836 4 Swainsons Hawk
# 836 5 INACTIVE NEST
# 836 6 890
# 836 7 POINT (-104.71035 40.13155)
# 837 0 891.0
# 837 1 39.953605
# 837 2 -104.845677
# 837 3 2015-08-24
# 837 4 Red-tail Hawk
# 837 5 FLEDGED NEST
# 837 6 891
# 837 7 POINT (-104.89861 39.99438)
# 838 0 892.0
# 838 1 39.947835
# 838 2 -104.847082
# 838 3 2015-08-04
# 838 4 Swainsons Hawk
# 838 5 INACTIVE NEST
# 838 6 892
# 838 7 POINT (-104.78362 39.93726)
# 839 0 893.0
# 839 1 40.15454
# 839 2 -104.841188
# 839 3 2015-07-30
# 839 4 Red-tail Hawk
# 839 5 INACTIVE NEST
# 839 6 893
# 839 7 POINT (-104.84911 40.09943)
# 840 0 894.0
# 840 1 40.154797
# 840 2 -104.841198
# 840 3 2015-07-30
# 840 4 Red-tail Hawk
# 840 5 INACTIVE NEST
# 840 6 894
# 840 7 POINT (-104.77056 40.22599)
# 841 0 895.0
# 841 1 40.204491
# 841 2 -104.662237
# 841 3 2015-08-05
# 841 4 Swainsons Hawk
# 841 5 INACTIVE NEST
# 841 6 895
# 841 7 POINT (-104.64539 40.14265)
# 842 0 896.0
# 842 1 39.975339
# 842 2 -104.94509
# 842 3 2015-07-27
# 842 4 Swainsons Hawk
# 842 5 FLEDGED NEST
# 842 6 896
# 842 7 POINT (-104.92662 39.96089)
# 843 0 897.0
# 843 1 40.417061
# 843 2 -104.800156
# 843 3 2015-07-07
# 843 4 Red-tail Hawk
# 843 5 ACTIVE NEST
# 843 6 897
# 843 7 POINT (-104.72328 40.47858)
# 844 0 898.0
# 844 1 40.188867
# 844 2 -105.005624
# 844 3 2015-07-10
# 844 4 Red-tail Hawk
# 844 5 INACTIVE NEST
# 844 6 898
# 844 7 POINT (-104.94558 40.23595)
# 845 0 899.0
# 845 1 40.187254
# 845 2 -105.005608
# 845 3 2015-07-10
# 845 4 Swainsons Hawk
# 845 5 INACTIVE NEST
# 845 6 899
# 845 7 POINT (-104.97637 40.14121)
# 846 0 900.0
# 846 1 40.169258
# 846 2 -104.889567
# 846 3 2015-07-13
# 846 4 Swainsons Hawk
# 846 5 INACTIVE NEST
# 846 6 900
# 846 7 POINT (-104.90353 40.2323)
# 847 0 901.0
# 847 1 40.04328
# 847 2 -105.017857
# 847 3 2015-08-04
# 847 4 Red-tail Hawk
# 847 5 INACTIVE NEST
# 847 6 901
# 847 7 POINT (-104.94253 40.03679)
# 848 0 902.0
# 848 1 40.04519
# 848 2 -104.727397
# 848 3 2015-08-14
# 848 4 Swainsons Hawk
# 848 5 INACTIVE NEST
# 848 6 902
# 848 7 POINT (-104.63442 40.00987)
# 849 0 903.0
# 849 1 40.04469
# 849 2 -104.726963
# 849 3 2015-08-14
# 849 4 Red-tail Hawk
# 849 5 INACTIVE NEST
# 849 6 903
# 849 7 POINT (-104.72082 40.03216)
# 850 0 904.0
# 850 1 40.044586
# 850 2 -104.727664
# 850 3 2015-08-14
# 850 4 Red-tail Hawk
# 850 5 INACTIVE NEST
# 850 6 904
# 850 7 POINT (-104.78274 40.08121)
# 851 0 905.0
# 851 1 40.056013
# 851 2 -104.761654
# 851 3 2015-08-17
# 851 4 Red-tail Hawk
# 851 5 INACTIVE NEST
# 851 6 905
# 851 7 POINT (-104.83105 40.06771)
# 852 0 906.0
# 852 1 40.051193
# 852 2 -104.794308
# 852 3 2015-08-17
# 852 4 Red-tail Hawk
# 852 5 INACTIVE NEST
# 852 6 906
# 852 7 POINT (-104.76127 40.07742)
# 853 0 907.0
# 853 1 39.995541
# 853 2 -104.891149
# 853 3 2015-08-18
# 853 4 Red-tail Hawk
# 853 5 INACTIVE NEST
# 853 6 907
# 853 7 POINT (-104.81692 40.02965)
# 854 0 908.0
# 854 1 39.996516
# 854 2 -104.891649
# 854 3 2015-08-18
# 854 4 Red-tail Hawk
# 854 5 INACTIVE NEST
# 854 6 908
# 854 7 POINT (-104.93254 40.03877)
# 855 0 909.0
# 855 1 39.999138
# 855 2 -104.899116
# 855 3 2015-08-18
# 855 4 Swainsons Hawk
# 855 5 INACTIVE NEST
# 855 6 909
# 855 7 POINT (-104.91958 40.00116)
# 856 0 910.0
# 856 1 40.002516
# 856 2 -104.893713
# 856 3 2015-08-18
# 856 4 Red-tail Hawk
# 856 5 INACTIVE NEST
# 856 6 910
# 856 7 POINT (-104.83619 39.98674)
# 857 0 911.0
# 857 1 40.00695
# 857 2 -104.89437
# 857 3 2015-08-18
# 857 4 Red-tail Hawk
# 857 5 INACTIVE NEST
# 857 6 911
# 857 7 POINT (-104.98394 40.00297)
# 858 0 912.0
# 858 1 39.998876
# 858 2 -104.900128
# 858 3 2015-09-01
# 858 4 Red-tail Hawk
# 858 5 INACTIVE NEST
# 858 6 912
# 858 7 POINT (-104.84766 39.96975)
# 859 0 nan
# 859 1 nan
# 859 2 nan
# 859 3 2020-05-08
# 859 4 Northern Harrier
# 859 5 INACTIVE NEST
# 859 6 9991
# 859 7 POINT (-104.95039158280412 40.24431700148285)
# 860 0 nan
# 860 1 nan
# 860 2 nan
# 860 3 2020-05-05
# 860 4 SWHA
# 860 5 INACTIVE NEST
# 860 6 1001
# 860 7 POINT (-104.94501532785657 40.24442591598638)
# 861 0 nan
# 861 1 40.24386520326873
# 861 2 -104.9371695362882
# 861 3 None
# 861 4 RTHA
# 861 5 FLEDGED NEST
# 861 6 1002
# 861 7 POINT (-104.9371695362882 40.24386520326873)

# %% [markdown]
# ### at and iat - referencing single cell
#
# Similar to loc and iloc but can only be used to reference a single cell
#
# Values can be assigned

# %%
for x in range(raptors.shape[0]):
    for y in range(raptors.shape[1]):
        print(x, y, raptors.iat[x,y])
# Out:
# 0 0 361.0
# 0 1 40.267502
# 0 2 -104.870872
# 0 3 2012-03-16
# 0 4 Swainsons Hawk
# 0 5 INACTIVE NEST
# 0 6 361
# 0 7 POINT (-104.79595 40.29891)
# 1 0 362.0
# 1 1 40.264321
# 1 2 -104.860255
# 1 3 2012-03-16
# 1 4 Swainsons Hawk
# 1 5 INACTIVE NEST
# 1 6 362
# 1 7 POINT (-104.78897 40.22089)
# 2 0 2.0
# 2 1 40.309574
# 2 2 -104.932604
# 2 3 2011-01-06
# 2 4 Swainsons Hawk
# 2 5 INACTIVE NEST
# 2 6 2
# 2 7 POINT (-104.84889 40.35215)
# 3 0 3.0
# 3 1 40.219343
# 3 2 -104.729246
# 3 3 2014-07-03
# 3 4 Swainsons Hawk
# 3 5 ACTIVE NEST
# 3 6 3
# 3 7 POINT (-104.74466 40.18571)
# 4 0 4.0
# 4 1 40.217638
# 4 2 -104.779386
# 4 3 2011-01-06
# 4 4 Red-tail Hawk
# 4 5 FLEDGED NEST
# 4 6 4
# 4 7 POINT (-104.79963 40.15712)
# 5 0 5.0
# 5 1 40.271203
# 5 2 -104.740819
# 5 3 2011-01-06
# 5 4 Swainsons Hawk
# 5 5 INACTIVE NEST
# 5 6 5
# 5 7 POINT (-104.6679 40.26382)
# 6 0 6.0
# 6 1 40.357587
# 6 2 -104.737632
# 6 3 2011-01-06
# 6 4 Swainsons Hawk
# 6 5 ACTIVE NEST
# 6 6 6
# 6 7 POINT (-104.67679 40.30686)
# 7 0 7.0
# 7 1 40.35966
# 7 2 -104.730698
# 7 3 2011-01-06
# 7 4 Swainsons Hawk
# 7 5 FLEDGED NEST
# 7 6 7
# 7 7 POINT (-104.69146 40.3136)
# 8 0 8.0
# 8 1 40.358919
# 8 2 -104.725179
# 8 3 2011-01-06
# 8 4 Red-tail Hawk
# 8 5 INACTIVE NEST
# 8 6 8
# 8 7 POINT (-104.67825 40.41094)
# 9 0 9.0
# 9 1 40.000189
# 9 2 -104.860463
# 9 3 2011-01-06
# 9 4 Swainsons Hawk
# 9 5 FLEDGED NEST
# 9 6 9
# 9 7 POINT (-104.78548 39.96439)
# 10 0 10.0
# 10 1 40.198163
# 10 2 -104.918726
# 10 3 2011-01-06
# 10 4 Swainsons Hawk
# 10 5 INACTIVE NEST
# 10 6 10
# 10 7 POINT (-104.99879 40.20531)
# 11 0 11.0
# 11 1 40.033635
# 11 2 -104.833716
# 11 3 2011-01-06
# 11 4 Red-tail Hawk
# 11 5 INACTIVE NEST
# 11 6 11
# 11 7 POINT (-104.80748 40.03194)
# 12 0 12.0
# 12 1 40.327655
# 12 2 -104.574845
# 12 3 2011-01-06
# 12 4 Red-tail Hawk
# 12 5 INACTIVE NEST
# 12 6 12
# 12 7 POINT (-104.63061 40.32023)
# 13 0 13.0
# 13 1 40.220769
# 13 2 -104.731024
# 13 3 2014-07-24
# 13 4 Swainsons Hawk
# 13 5 INACTIVE NEST
# 13 6 13
# 13 7 POINT (-104.7683 40.22536)
# 14 0 14.0
# 14 1 40.12669
# 14 2 -105.020896
# 14 3 2011-01-06
# 14 4 Swainsons Hawk
# 14 5 ACTIVE NEST
# 14 6 14
# 14 7 POINT (-105.05943 40.19046)
# 15 0 15.0
# 15 1 40.225065
# 15 2 -104.627044
# 15 3 2011-01-06
# 15 4 Red-tail Hawk
# 15 5 FLEDGED NEST
# 15 6 15
# 15 7 POINT (-104.68345 40.28228)
# 16 0 371.0
# 16 1 40.18432
# 16 2 -104.77275
# 16 3 2012-03-23
# 16 4 Swainsons Hawk
# 16 5 FLEDGED NEST
# 16 6 371
# 16 7 POINT (-104.77275 40.18432)
# 17 0 913.0
# 17 1 40.138876
# 17 2 -104.976541
# 17 3 2015-09-10
# 17 4 Red-tail Hawk
# 17 5 INACTIVE NEST
# 17 6 913
# 17 7 POINT (-104.91296 40.1135)
# 18 0 914.0
# 18 1 40.140884
# 18 2 -104.951201
# 18 3 2015-09-10
# 18 4 Red-tail Hawk
# 18 5 INACTIVE NEST
# 18 6 914
# 18 7 POINT (-104.99814 40.1016)
# 19 0 915.0
# 19 1 40.131518
# 19 2 -104.963308
# 19 3 2015-09-10
# 19 4 Red-tail Hawk
# 19 5 INACTIVE NEST
# 19 6 915
# 19 7 POINT (-104.98495 40.1742)
# 20 0 916.0
# 20 1 40.131956
# 20 2 -104.959158
# 20 3 2015-09-10
# 20 4 Swainsons Hawk
# 20 5 INACTIVE NEST
# 20 6 916
# 20 7 POINT (-105.03582 40.19353)
# 21 0 917.0
# 21 1 40.368366
# 21 2 -104.963993
# 21 3 2015-10-14
# 21 4 Red-tail Hawk
# 21 5 INACTIVE NEST
# 21 6 917
# 21 7 POINT (-104.99776 40.42473)
# 22 0 918.0
# 22 1 40.357932
# 22 2 -104.965152
# 22 3 2015-10-14
# 22 4 Red-tail Hawk
# 22 5 INACTIVE NEST
# 22 6 918
# 22 7 POINT (-104.98967 40.42586)
# 23 0 919.0
# 23 1 40.35701
# 23 2 -104.963257
# 23 3 2015-10-14
# 23 4 Swainsons Hawk
# 23 5 INACTIVE NEST
# 23 6 919
# 23 7 POINT (-104.97197 40.4067)
# 24 0 16.0
# 24 1 40.243589
# 24 2 -104.730385
# 24 3 2011-01-06
# 24 4 Swainsons Hawk
# 24 5 ACTIVE NEST
# 24 6 16
# 24 7 POINT (-104.72963 40.2348)
# 25 0 17.0
# 25 1 40.185072
# 25 2 -104.844298
# 25 3 2011-01-06
# 25 4 Red-tail Hawk
# 25 5 ACTIVE NEST
# 25 6 17
# 25 7 POINT (-104.87677 40.23926)
# 26 0 18.0
# 26 1 40.240403
# 26 2 -104.860404
# 26 3 2011-01-06
# 26 4 Red-tail Hawk
# 26 5 INACTIVE NEST
# 26 6 18
# 26 7 POINT (-104.91238 40.29383)
# 27 0 19.0
# 27 1 40.226344
# 27 2 -104.850214
# 27 3 2011-01-06
# 27 4 Red-tail Hawk
# 27 5 ACTIVE NEST
# 27 6 19
# 27 7 POINT (-104.87695 40.21758)
# 28 0 20.0
# 28 1 40.229449
# 28 2 -104.8522
# 28 3 2011-01-06
# 28 4 Red-tail Hawk
# 28 5 ACTIVE NEST
# 28 6 20
# 28 7 POINT (-104.8872 40.16783)
# 29 0 21.0
# 29 1 40.301935
# 29 2 -104.947598
# 29 3 2011-01-06
# 29 4 Swainsons Hawk
# 29 5 INACTIVE NEST
# 29 6 21
# 29 7 POINT (-104.98418 40.30175)
# 30 0 22.0
# 30 1 40.196557
# 30 2 -104.851282
# 30 3 2011-01-06
# 30 4 Swainsons Hawk
# 30 5 INACTIVE NEST
# 30 6 22
# 30 7 POINT (-104.77577 40.16702)
# 31 0 23.0
# 31 1 40.138615
# 31 2 -104.989487
# 31 3 2014-06-25
# 31 4 Swainsons Hawk
# 31 5 INACTIVE NEST
# 31 6 23
# 31 7 POINT (-104.95636 40.20921)
# 32 0 24.0
# 32 1 40.140795
# 32 2 -104.714801
# 32 3 2011-01-06
# 32 4 Red-tail Hawk
# 32 5 INACTIVE NEST
# 32 6 24
# 32 7 POINT (-104.78436 40.16182)
# 33 0 25.0
# 33 1 40.231893
# 33 2 -104.860162
# 33 3 2011-01-06
# 33 4 Red-tail Hawk
# 33 5 INACTIVE NEST
# 33 6 25
# 33 7 POINT (-104.94972 40.25426)
# 34 0 26.0
# 34 1 40.141795
# 34 2 -104.714559
# 34 3 2011-01-06
# 34 4 Swainsons Hawk
# 34 5 INACTIVE NEST
# 34 6 26
# 34 7 POINT (-104.65786 40.1207)
# 35 0 27.0
# 35 1 40.196828
# 35 2 -104.830056
# 35 3 2011-01-06
# 35 4 Red-tail Hawk
# 35 5 ACTIVE NEST
# 35 6 27
# 35 7 POINT (-104.76699 40.20147)
# 36 0 28.0
# 36 1 40.181554
# 36 2 -104.603392
# 36 3 2011-01-06
# 36 4 Red-tail Hawk
# 36 5 INACTIVE NEST
# 36 6 28
# 36 7 POINT (-104.52641 40.17562)
# 37 0 29.0
# 37 1 40.182014
# 37 2 -104.660659
# 37 3 2011-01-06
# 37 4 Red-tail Hawk
# 37 5 INACTIVE NEST
# 37 6 29
# 37 7 POINT (-104.69561 40.16848)
# 38 0 30.0
# 38 1 40.195063
# 38 2 -104.849572
# 38 3 2011-01-06
# 38 4 Swainsons Hawk
# 38 5 INACTIVE NEST
# 38 6 30
# 38 7 POINT (-104.85299 40.23548)
# 39 0 31.0
# 39 1 40.175037
# 39 2 -104.946548
# 39 3 2011-01-06
# 39 4 Swainsons Hawk
# 39 5 ACTIVE NEST
# 39 6 31
# 39 7 POINT (-105.00639 40.24032)
# 40 0 32.0
# 40 1 40.22518
# 40 2 -104.838378
# 40 3 2011-01-06
# 40 4 Red-tail Hawk
# 40 5 INACTIVE NEST
# 40 6 32
# 40 7 POINT (-104.83528 40.19825)
# 41 0 33.0
# 41 1 40.174755
# 41 2 -104.799249
# 41 3 2011-01-06
# 41 4 Red-tail Hawk
# 41 5 INACTIVE NEST
# 41 6 33
# 41 7 POINT (-104.79673 40.20553)
# 42 0 34.0
# 42 1 40.019042
# 42 2 -104.942779
# 42 3 2011-01-06
# 42 4 Red-tail Hawk
# 42 5 ACTIVE NEST
# 42 6 34
# 42 7 POINT (-104.91002 39.96346)
# 43 0 35.0
# 43 1 40.181961
# 43 2 -104.847581
# 43 3 2011-01-06
# 43 4 Red-tail Hawk
# 43 5 ACTIVE NEST
# 43 6 35
# 43 7 POINT (-104.83385 40.12341)
# 44 0 36.0
# 44 1 40.18421
# 44 2 -104.876609
# 44 3 2011-01-06
# 44 4 Swainsons Hawk
# 44 5 ACTIVE NEST
# 44 6 36
# 44 7 POINT (-104.82664 40.15769)
# 45 0 37.0
# 45 1 40.185009
# 45 2 -104.876566
# 45 3 2011-01-06
# 45 4 Red-tail Hawk
# 45 5 FLEDGED NEST
# 45 6 37
# 45 7 POINT (-104.96623 40.13452)
# 46 0 38.0
# 46 1 40.074776
# 46 2 -105.047018
# 46 3 2008-04-25
# 46 4 Red-tail Hawk
# 46 5 INACTIVE NEST
# 46 6 38
# 46 7 POINT (-104.98086 40.08121)
# 47 0 39.0
# 47 1 40.143726
# 47 2 -104.984522
# 47 3 2008-04-25
# 47 4 Red-tail Hawk
# 47 5 INACTIVE NEST
# 47 6 39
# 47 7 POINT (-105.05218 40.1003)
# 48 0 40.0
# 48 1 40.231198
# 48 2 -104.626507
# 48 3 2008-04-25
# 48 4 Red-tail Hawk
# 48 5 INACTIVE NEST
# 48 6 40
# 48 7 POINT (-104.60876 40.28215)
# 49 0 41.0
# 49 1 40.14024
# 49 2 -104.984017
# 49 3 2008-04-25
# 49 4 Red-tail Hawk
# 49 5 INACTIVE NEST
# 49 6 41
# 49 7 POINT (-105.0307 40.10774)
# 50 0 42.0
# 50 1 40.280158
# 50 2 -105.023386
# 50 3 2008-04-25
# 50 4 Swainsons Hawk
# 50 5 ACTIVE NEST
# 50 6 42
# 50 7 POINT (-105.01748 40.34794)
# 51 0 43.0
# 51 1 40.441386
# 51 2 -104.852749
# 51 3 2008-04-25
# 51 4 Swainsons Hawk
# 51 5 FLEDGED NEST
# 51 6 43
# 51 7 POINT (-104.79653 40.47682)
# 52 0 44.0
# 52 1 40.2483
# 52 2 -104.598365
# 52 3 2008-04-25
# 52 4 Red-tail Hawk
# 52 5 ACTIVE NEST
# 52 6 44
# 52 7 POINT (-104.52823 40.27316)
# 53 0 45.0
# 53 1 40.25945
# 53 2 -104.594912
# 53 3 2008-04-25
# 53 4 Red-tail Hawk
# 53 5 FLEDGED NEST
# 53 6 45
# 53 7 POINT (-104.64234 40.30311)
# 54 0 46.0
# 54 1 40.322534
# 54 2 -104.630024
# 54 3 2008-04-25
# 54 4 Swainsons Hawk
# 54 5 INACTIVE NEST
# 54 6 46
# 54 7 POINT (-104.59918 40.34821)
# 55 0 47.0
# 55 1 40.271404
# 55 2 -104.629232
# 55 3 2008-04-25
# 55 4 Swainsons Hawk
# 55 5 INACTIVE NEST
# 55 6 47
# 55 7 POINT (-104.60601 40.24514)
# 56 0 48.0
# 56 1 40.27624
# 56 2 -104.578685
# 56 3 2008-04-25
# 56 4 Red-tail Hawk
# 56 5 INACTIVE NEST
# 56 6 48
# 56 7 POINT (-104.58589 40.3014)
# 57 0 49.0
# 57 1 40.283779
# 57 2 -105.026692
# 57 3 2008-04-25
# 57 4 Red-tail Hawk
# 57 5 INACTIVE NEST
# 57 6 49
# 57 7 POINT (-104.98787 40.29486)
# 58 0 50.0
# 58 1 40.275573
# 58 2 -105.019373
# 58 3 2008-04-25
# 58 4 Red-tail Hawk
# 58 5 ACTIVE NEST
# 58 6 50
# 58 7 POINT (-104.99136 40.24572)
# 59 0 51.0
# 59 1 40.485335
# 59 2 -104.452276
# 59 3 2008-04-25
# 59 4 Swainsons Hawk
# 59 5 INACTIVE NEST
# 59 6 51
# 59 7 POINT (-104.53763 40.45225)
# 60 0 52.0
# 60 1 40.341314
# 60 2 -104.617747
# 60 3 2008-04-25
# 60 4 Red-tail Hawk
# 60 5 INACTIVE NEST
# 60 6 52
# 60 7 POINT (-104.57254 40.34041)
# 61 0 53.0
# 61 1 40.275542
# 61 2 -104.67526
# 61 3 2008-04-25
# 61 4 Swainsons Hawk
# 61 5 INACTIVE NEST
# 61 6 53
# 61 7 POINT (-104.63141 40.33613)
# 62 0 54.0
# 62 1 40.270743
# 62 2 -104.679423
# 62 3 2008-04-25
# 62 4 Swainsons Hawk
# 62 5 INACTIVE NEST
# 62 6 54
# 62 7 POINT (-104.7117 40.30232)
# 63 0 55.0
# 63 1 39.84752
# 63 2 -104.61775
# 63 3 2008-04-25
# 63 4 Swainsons Hawk
# 63 5 INACTIVE NEST
# 63 6 55
# 63 7 POINT (-104.54095 39.86113)
# 64 0 56.0
# 64 1 40.25559
# 64 2 -104.58366
# 64 3 2008-04-25
# 64 4 Swainsons Hawk
# 64 5 FLEDGED NEST
# 64 6 56
# 64 7 POINT (-104.621 40.27386)
# 65 0 57.0
# 65 1 40.58071
# 65 2 -104.50874
# 65 3 2008-04-25
# 65 4 Swainsons Hawk
# 65 5 INACTIVE NEST
# 65 6 57
# 65 7 POINT (-104.46596 40.57309)
# 66 0 58.0
# 66 1 40.53128
# 66 2 -104.83036
# 66 3 2008-04-25
# 66 4 Red-tail Hawk
# 66 5 INACTIVE NEST
# 66 6 58
# 66 7 POINT (-104.8295 40.48061)
# 67 0 59.0
# 67 1 40.53205
# 67 2 -104.65707
# 67 3 2008-04-25
# 67 4 Red-tail Hawk
# 67 5 INACTIVE NEST
# 67 6 59
# 67 7 POINT (-104.61477 40.48916)
# 68 0 61.0
# 68 1 40.283752
# 68 2 -105.026892
# 68 3 2008-04-25
# 68 4 Red-tail Hawk
# 68 5 INACTIVE NEST
# 68 6 61
# 68 7 POINT (-105.07959 40.35293)
# 69 0 62.0
# 69 1 40.116947
# 69 2 -105.036532
# 69 3 2008-04-25
# 69 4 Swainsons Hawk
# 69 5 INACTIVE NEST
# 69 6 62
# 69 7 POINT (-105.09585 40.1276)
# 70 0 63.0
# 70 1 40.362427
# 70 2 -104.764271
# 70 3 2008-04-25
# 70 4 Swainsons Hawk
# 70 5 FLEDGED NEST
# 70 6 63
# 70 7 POINT (-104.84195 40.36651)
# 71 0 64.0
# 71 1 40.121593
# 71 2 -105.005058
# 71 3 2008-04-25
# 71 4 Red-tail Hawk
# 71 5 INACTIVE NEST
# 71 6 64
# 71 7 POINT (-105.01954 40.1775)
# 72 0 65.0
# 72 1 40.486637
# 72 2 -104.451427
# 72 3 2008-04-25
# 72 4 Swainsons Hawk
# 72 5 INACTIVE NEST
# 72 6 65
# 72 7 POINT (-104.41929 40.52833)
# 73 0 66.0
# 73 1 40.201173
# 73 2 -104.907319
# 73 3 2008-04-25
# 73 4 Red-tail Hawk
# 73 5 FLEDGED NEST
# 73 6 66
# 73 7 POINT (-104.94201 40.16989)
# 74 0 67.0
# 74 1 40.200841
# 74 2 -104.909011
# 74 3 2008-04-25
# 74 4 Red-tail Hawk
# 74 5 INACTIVE NEST
# 74 6 67
# 74 7 POINT (-104.91275 40.22515)
# 75 0 68.0
# 75 1 40.179032
# 75 2 -104.831177
# 75 3 2008-04-25
# 75 4 Red-tail Hawk
# 75 5 ACTIVE NEST
# 75 6 68
# 75 7 POINT (-104.83712 40.12286)
# 76 0 69.0
# 76 1 40.048844
# 76 2 -104.831487
# 76 3 2008-04-25
# 76 4 Red-tail Hawk
# 76 5 FLEDGED NEST
# 76 6 69
# 76 7 POINT (-104.83891 40.05415)
# 77 0 70.0
# 77 1 40.168236
# 77 2 -104.623535
# 77 3 2008-04-25
# 77 4 Swainsons Hawk
# 77 5 INACTIVE NEST
# 77 6 70
# 77 7 POINT (-104.57744 40.11825)
# 78 0 71.0
# 78 1 40.161225
# 78 2 -104.631465
# 78 3 2014-09-04
# 78 4 Red-tail Hawk
# 78 5 ACTIVE NEST
# 78 6 71
# 78 7 POINT (-104.61912 40.17869)
# 79 0 72.0
# 79 1 40.157045
# 79 2 -104.620332
# 79 3 2008-04-25
# 79 4 Swainsons Hawk
# 79 5 INACTIVE NEST
# 79 6 72
# 79 7 POINT (-104.64093 40.08932)
# 80 0 73.0
# 80 1 40.155659
# 80 2 -104.620748
# 80 3 2008-04-25
# 80 4 Red-tail Hawk
# 80 5 INACTIVE NEST
# 80 6 73
# 80 7 POINT (-104.56071 40.20625)
# 81 0 75.0
# 81 1 40.135336
# 81 2 -104.61632
# 81 3 2008-04-25
# 81 4 Swainsons Hawk
# 81 5 INACTIVE NEST
# 81 6 75
# 81 7 POINT (-104.60701 40.0922)
# 82 0 76.0
# 82 1 40.313602
# 82 2 -104.933598
# 82 3 2008-04-25
# 82 4 Red-tail Hawk
# 82 5 ACTIVE NEST
# 82 6 76
# 82 7 POINT (-104.99521 40.36347)
# 83 0 77.0
# 83 1 40.256101
# 83 2 -104.971308
# 83 3 2008-04-25
# 83 4 Swainsons Hawk
# 83 5 INACTIVE NEST
# 83 6 77
# 83 7 POINT (-105.05676 40.32494)
# 84 0 78.0
# 84 1 40.225608
# 84 2 -104.848821
# 84 3 2008-04-25
# 84 4 Red-tail Hawk
# 84 5 FLEDGED NEST
# 84 6 78
# 84 7 POINT (-104.89094 40.29457)
# 85 0 79.0
# 85 1 40.064704
# 85 2 -104.847137
# 85 3 2008-04-25
# 85 4 Red-tail Hawk
# 85 5 FLEDGED NEST
# 85 6 79
# 85 7 POINT (-104.90728 40.12695)
# 86 0 80.0
# 86 1 40.0586
# 86 2 -104.836715
# 86 3 2008-04-25
# 86 4 Swainsons Hawk
# 86 5 ACTIVE NEST
# 86 6 80
# 86 7 POINT (-104.88378 40.11421)
# 87 0 81.0
# 87 1 40.06284
# 87 2 -104.834489
# 87 3 2008-04-25
# 87 4 Swainsons Hawk
# 87 5 INACTIVE NEST
# 87 6 81
# 87 7 POINT (-104.83552 40.10434)
# 88 0 82.0
# 88 1 40.038086
# 88 2 -104.831619
# 88 3 2008-04-25
# 88 4 Red-tail Hawk
# 88 5 ACTIVE NEST
# 88 6 82
# 88 7 POINT (-104.84902 40.06503)
# 89 0 83.0
# 89 1 40.048069
# 89 2 -104.831336
# 89 3 2008-04-25
# 89 4 Red-tail Hawk
# 89 5 INACTIVE NEST
# 89 6 83
# 89 7 POINT (-104.91765 40.01353)
# 90 0 84.0
# 90 1 40.062771
# 90 2 -104.830749
# 90 3 2008-04-25
# 90 4 Swainsons Hawk
# 90 5 INACTIVE NEST
# 90 6 84
# 90 7 POINT (-104.91904 40.09191)
# 91 0 85.0
# 91 1 40.06178
# 91 2 -104.830306
# 91 3 2008-04-25
# 91 4 Red-tail Hawk
# 91 5 ACTIVE NEST
# 91 6 85
# 91 7 POINT (-104.92033 40.00823)
# 92 0 86.0
# 92 1 40.050671
# 92 2 -104.830275
# 92 3 2008-04-25
# 92 4 Swainsons Hawk
# 92 5 ACTIVE NEST
# 92 6 86
# 92 7 POINT (-104.75313 39.99989)
# 93 0 87.0
# 93 1 40.046409
# 93 2 -104.830121
# 93 3 2008-04-25
# 93 4 Red-tail Hawk
# 93 5 INACTIVE NEST
# 93 6 87
# 93 7 POINT (-104.78684 40.06302)
# 94 0 88.0
# 94 1 40.063599
# 94 2 -104.829832
# 94 3 2008-04-25
# 94 4 Swainsons Hawk
# 94 5 INACTIVE NEST
# 94 6 88
# 94 7 POINT (-104.89227 40.04444)
# 95 0 89.0
# 95 1 40.037714
# 95 2 -104.829709
# 95 3 2008-04-25
# 95 4 Red-tail Hawk
# 95 5 INACTIVE NEST
# 95 6 89
# 95 7 POINT (-104.8124 39.99289)
# 96 0 90.0
# 96 1 40.038471
# 96 2 -104.829695
# 96 3 2008-04-25
# 96 4 Red-tail Hawk
# 96 5 INACTIVE NEST
# 96 6 90
# 96 7 POINT (-104.8625 39.99064)
# 97 0 91.0
# 97 1 40.036795
# 97 2 -104.829582
# 97 3 2008-04-25
# 97 4 Swainsons Hawk
# 97 5 INACTIVE NEST
# 97 6 91
# 97 7 POINT (-104.81005 40.09573)
# 98 0 92.0
# 98 1 40.031947
# 98 2 -104.829477
# 98 3 2008-04-25
# 98 4 Swainsons Hawk
# 98 5 FLEDGED NEST
# 98 6 92
# 98 7 POINT (-104.83104 40.0983)
# 99 0 93.0
# 99 1 40.049804
# 99 2 -104.829175
# 99 3 2008-04-25
# 99 4 Red-tail Hawk
# 99 5 INACTIVE NEST
# 99 6 93
# 99 7 POINT (-104.77532 40.05807)
# 100 0 94.0
# 100 1 40.048244
# 100 2 -104.828065
# 100 3 2014-06-09
# 100 4 Red-tail Hawk
# 100 5 ACTIVE NEST
# 100 6 94
# 100 7 POINT (-104.77525 40.11579)
# 101 0 95.0
# 101 1 40.049477
# 101 2 -104.8271
# 101 3 2008-04-25
# 101 4 Red-tail Hawk
# 101 5 INACTIVE NEST
# 101 6 95
# 101 7 POINT (-104.87745 40.06964)
# 102 0 96.0
# 102 1 40.035529
# 102 2 -104.826561
# 102 3 2008-04-25
# 102 4 Red-tail Hawk
# 102 5 INACTIVE NEST
# 102 6 96
# 102 7 POINT (-104.73479 40.03041)
# 103 0 97.0
# 103 1 40.058384
# 103 2 -104.824545
# 103 3 2008-04-25
# 103 4 Swainsons Hawk
# 103 5 ACTIVE NEST
# 103 6 97
# 103 7 POINT (-104.86578 39.99927)
# 104 0 98.0
# 104 1 40.061459
# 104 2 -104.820562
# 104 3 2008-04-25
# 104 4 Red-tail Hawk
# 104 5 INACTIVE NEST
# 104 6 98
# 104 7 POINT (-104.82824 40.0463)
# 105 0 99.0
# 105 1 40.530799
# 105 2 -104.831797
# 105 3 2008-06-03
# 105 4 Swainsons Hawk
# 105 5 FLEDGED NEST
# 105 6 99
# 105 7 POINT (-104.91752 40.49435)
# 106 0 100.0
# 106 1 40.338229
# 106 2 -104.587601
# 106 3 2008-06-03
# 106 4 Red-tail Hawk
# 106 5 INACTIVE NEST
# 106 6 100
# 106 7 POINT (-104.53155 40.2802)
# 107 0 101.0
# 107 1 40.487824
# 107 2 -104.768116
# 107 3 2008-06-03
# 107 4 Swainsons Hawk
# 107 5 FLEDGED NEST
# 107 6 101
# 107 7 POINT (-104.76049 40.41908)
# 108 0 102.0
# 108 1 40.08835
# 108 2 -104.508468
# 108 3 2008-06-03
# 108 4 Swainsons Hawk
# 108 5 FLEDGED NEST
# 108 6 102
# 108 7 POINT (-104.49186 40.03111)
# 109 0 103.0
# 109 1 40.517867
# 109 2 -104.827522
# 109 3 2008-06-03
# 109 4 Red-tail Hawk
# 109 5 INACTIVE NEST
# 109 6 103
# 109 7 POINT (-104.75051 40.52852)
# 110 0 104.0
# 110 1 40.508454
# 110 2 -104.830224
# 110 3 2008-06-03
# 110 4 Red-tail Hawk
# 110 5 FLEDGED NEST
# 110 6 104
# 110 7 POINT (-104.765 40.48259)
# 111 0 105.0
# 111 1 40.518207
# 111 2 -104.82783
# 111 3 2008-06-03
# 111 4 Red-tail Hawk
# 111 5 FLEDGED NEST
# 111 6 105
# 111 7 POINT (-104.77397 40.45362)
# 112 0 106.0
# 112 1 40.326908
# 112 2 -104.581231
# 112 3 2008-06-03
# 112 4 Swainsons Hawk
# 112 5 INACTIVE NEST
# 112 6 106
# 112 7 POINT (-104.53068 40.33154)
# 113 0 107.0
# 113 1 40.057375
# 113 2 -104.576964
# 113 3 2008-06-03
# 113 4 Red-tail Hawk
# 113 5 INACTIVE NEST
# 113 6 107
# 113 7 POINT (-104.57046 40.02929)
# 114 0 108.0
# 114 1 40.290293
# 114 2 -104.876666
# 114 3 2008-06-03
# 114 4 Swainsons Hawk
# 114 5 INACTIVE NEST
# 114 6 108
# 114 7 POINT (-104.8441 40.34197)
# 115 0 109.0
# 115 1 40.310841
# 115 2 -104.866732
# 115 3 2008-06-03
# 115 4 Red-tail Hawk
# 115 5 ACTIVE NEST
# 115 6 109
# 115 7 POINT (-104.86989 40.29139)
# 116 0 110.0
# 116 1 40.501811
# 116 2 -104.471308
# 116 3 2008-06-03
# 116 4 Red-tail Hawk
# 116 5 INACTIVE NEST
# 116 6 110
# 116 7 POINT (-104.48078 40.56803)
# 117 0 111.0
# 117 1 40.266192
# 117 2 -104.666249
# 117 3 2008-06-03
# 117 4 Red-tail Hawk
# 117 5 INACTIVE NEST
# 117 6 111
# 117 7 POINT (-104.68259 40.27171)
# 118 0 112.0
# 118 1 40.185024
# 118 2 -105.155517
# 118 3 2008-06-03
# 118 4 Red-tail Hawk
# 118 5 INACTIVE NEST
# 118 6 112
# 118 7 POINT (-105.17062 40.23782)
# 119 0 114.0
# 119 1 40.38259
# 119 2 -104.94166
# 119 3 2008-06-03
# 119 4 Swainsons Hawk
# 119 5 FLEDGED NEST
# 119 6 114
# 119 7 POINT (-104.96513 40.43837)
# 120 0 115.0
# 120 1 40.57187
# 120 2 -104.819655
# 120 3 2008-06-03
# 120 4 Red-tail Hawk
# 120 5 ACTIVE NEST
# 120 6 115
# 120 7 POINT (-104.82919 40.54868)
# 121 0 116.0
# 121 1 40.357831
# 121 2 -104.719123
# 121 3 2008-06-03
# 121 4 Red-tail Hawk
# 121 5 INACTIVE NEST
# 121 6 116
# 121 7 POINT (-104.68079 40.31262)
# 122 0 117.0
# 122 1 40.130134
# 122 2 -104.993051
# 122 3 2008-06-03
# 122 4 Red-tail Hawk
# 122 5 FLEDGED NEST
# 122 6 117
# 122 7 POINT (-104.96794 40.20047)
# 123 0 118.0
# 123 1 40.48504
# 123 2 -104.61311
# 123 3 2008-06-03
# 123 4 Red-tail Hawk
# 123 5 ACTIVE NEST
# 123 6 118
# 123 7 POINT (-104.52014 40.44087)
# 124 0 119.0
# 124 1 40.232609
# 124 2 -104.730173
# 124 3 2014-07-16
# 124 4 Swainsons Hawk
# 124 5 INACTIVE NEST
# 124 6 119
# 124 7 POINT (-104.67131 40.25596)
# 125 0 121.0
# 125 1 40.235751
# 125 2 -104.744902
# 125 3 2014-07-18
# 125 4 Red-tail Hawk
# 125 5 INACTIVE NEST
# 125 6 121
# 125 7 POINT (-104.81498 40.23871)
# 126 0 122.0
# 126 1 40.272105
# 126 2 -104.934651
# 126 3 2014-04-30
# 126 4 Swainsons Hawk
# 126 5 ACTIVE NEST
# 126 6 122
# 126 7 POINT (-104.95209 40.23106)
# 127 0 123.0
# 127 1 40.275357
# 127 2 -104.93313
# 127 3 2014-07-23
# 127 4 Red-tail Hawk
# 127 5 FLEDGED NEST
# 127 6 123
# 127 7 POINT (-104.85054 40.26056)
# 128 0 124.0
# 128 1 40.476414
# 128 2 -104.794357
# 128 3 2008-06-03
# 128 4 Swainsons Hawk
# 128 5 FLEDGED NEST
# 128 6 124
# 128 7 POINT (-104.88624 40.45142)
# 129 0 125.0
# 129 1 40.338705
# 129 2 -104.587316
# 129 3 2008-06-03
# 129 4 Red-tail Hawk
# 129 5 FLEDGED NEST
# 129 6 125
# 129 7 POINT (-104.6084 40.33203)
# 130 0 126.0
# 130 1 40.347629
# 130 2 -104.591041
# 130 3 2008-06-03
# 130 4 Swainsons Hawk
# 130 5 INACTIVE NEST
# 130 6 126
# 130 7 POINT (-104.52545 40.28275)
# 131 0 127.0
# 131 1 40.193263
# 131 2 -104.918913
# 131 3 2014-07-11
# 131 4 Swainsons Hawk
# 131 5 ACTIVE NEST
# 131 6 127
# 131 7 POINT (-104.87129 40.12185)
# 132 0 128.0
# 132 1 40.419094
# 132 2 -104.864786
# 132 3 2009-02-16
# 132 4 Red-tail Hawk
# 132 5 FLEDGED NEST
# 132 6 128
# 132 7 POINT (-104.84771 40.39903)
# 133 0 129.0
# 133 1 40.420177
# 133 2 -104.86661
# 133 3 2009-02-16
# 133 4 Swainsons Hawk
# 133 5 ACTIVE NEST
# 133 6 129
# 133 7 POINT (-104.93307 40.40455)
# 134 0 130.0
# 134 1 40.182479
# 134 2 -105.021958
# 134 3 2009-02-16
# 134 4 Swainsons Hawk
# 134 5 ACTIVE NEST
# 134 6 130
# 134 7 POINT (-105.10449 40.15217)
# 135 0 131.0
# 135 1 40.177304
# 135 2 -104.832708
# 135 3 2009-02-16
# 135 4 Red-tail Hawk
# 135 5 INACTIVE NEST
# 135 6 131
# 135 7 POINT (-104.80508 40.12561)
# 136 0 132.0
# 136 1 40.293525
# 136 2 -104.826139
# 136 3 2009-02-16
# 136 4 Red-tail Hawk
# 136 5 FLEDGED NEST
# 136 6 132
# 136 7 POINT (-104.84461 40.36478)
# 137 0 133.0
# 137 1 40.293302
# 137 2 -104.827081
# 137 3 2009-02-16
# 137 4 Swainsons Hawk
# 137 5 INACTIVE NEST
# 137 6 133
# 137 7 POINT (-104.89419 40.35369)
# 138 0 134.0
# 138 1 40.295341
# 138 2 -104.829523
# 138 3 2009-02-16
# 138 4 Red-tail Hawk
# 138 5 INACTIVE NEST
# 138 6 134
# 138 7 POINT (-104.88737 40.3673)
# 139 0 135.0
# 139 1 40.239064
# 139 2 -104.560988
# 139 3 2009-02-16
# 139 4 Red-tail Hawk
# 139 5 ACTIVE NEST
# 139 6 135
# 139 7 POINT (-104.50898 40.29313)
# 140 0 136.0
# 140 1 40.236308
# 140 2 -104.561158
# 140 3 2009-02-16
# 140 4 Swainsons Hawk
# 140 5 INACTIVE NEST
# 140 6 136
# 140 7 POINT (-104.57135 40.19549)
# 141 0 137.0
# 141 1 40.161485
# 141 2 -104.736432
# 141 3 2009-02-16
# 141 4 Red-tail Hawk
# 141 5 INACTIVE NEST
# 141 6 137
# 141 7 POINT (-104.75732 40.22608)
# 142 0 138.0
# 142 1 40.167251
# 142 2 -104.895186
# 142 3 2009-09-21
# 142 4 Red-tail Hawk
# 142 5 ACTIVE NEST
# 142 6 138
# 142 7 POINT (-104.81781 40.12482)
# 143 0 139.0
# 143 1 40.174632
# 143 2 -104.908529
# 143 3 2009-09-21
# 143 4 Red-tail Hawk
# 143 5 FLEDGED NEST
# 143 6 139
# 143 7 POINT (-104.82487 40.1579)
# 144 0 140.0
# 144 1 40.168164
# 144 2 -104.889043
# 144 3 2009-09-21
# 144 4 Red-tail Hawk
# 144 5 ACTIVE NEST
# 144 6 140
# 144 7 POINT (-104.83257 40.18646)
# 145 0 141.0
# 145 1 40.168317
# 145 2 -104.888796
# 145 3 2009-09-21
# 145 4 Red-tail Hawk
# 145 5 INACTIVE NEST
# 145 6 141
# 145 7 POINT (-104.90306 40.13331)
# 146 0 142.0
# 146 1 39.850724
# 146 2 -104.362036
# 146 3 2009-09-21
# 146 4 Red-tail Hawk
# 146 5 ACTIVE NEST
# 146 6 142
# 146 7 POINT (-104.34477 39.86965)
# 147 0 143.0
# 147 1 40.222794
# 147 2 -104.728426
# 147 3 2014-08-14
# 147 4 Red-tail Hawk
# 147 5 ACTIVE NEST
# 147 6 143
# 147 7 POINT (-104.72085 40.1949)
# 148 0 144.0
# 148 1 40.153272
# 148 2 -104.849557
# 148 3 2009-09-21
# 148 4 Swainsons Hawk
# 148 5 FLEDGED NEST
# 148 6 144
# 148 7 POINT (-104.92554 40.13202)
# 149 0 145.0
# 149 1 40.193823
# 149 2 -104.909103
# 149 3 2009-09-21
# 149 4 Red-tail Hawk
# 149 5 FLEDGED NEST
# 149 6 145
# 149 7 POINT (-104.92416 40.23481)
# 150 0 146.0
# 150 1 40.034008
# 150 2 -104.869171
# 150 3 2009-09-21
# 150 4 Red-tail Hawk
# 150 5 INACTIVE NEST
# 150 6 146
# 150 7 POINT (-104.81893 39.9708)
# 151 0 147.0
# 151 1 40.072767
# 151 2 -104.7324
# 151 3 2009-09-21
# 151 4 Red-tail Hawk
# 151 5 INACTIVE NEST
# 151 6 147
# 151 7 POINT (-104.74471 40.06464)
# 152 0 148.0
# 152 1 40.167169
# 152 2 -104.624985
# 152 3 2009-09-21
# 152 4 Red-tail Hawk
# 152 5 FLEDGED NEST
# 152 6 148
# 152 7 POINT (-104.63358 40.19635)
# 153 0 149.0
# 153 1 40.169002
# 153 2 -104.623601
# 153 3 2009-09-21
# 153 4 Red-tail Hawk
# 153 5 INACTIVE NEST
# 153 6 149
# 153 7 POINT (-104.63727 40.12933)
# 154 0 151.0
# 154 1 40.103025
# 154 2 -105.044244
# 154 3 2009-09-21
# 154 4 Red-tail Hawk
# 154 5 INACTIVE NEST
# 154 6 151
# 154 7 POINT (-105.03273 40.05664)
# 155 0 152.0
# 155 1 40.132348
# 155 2 -104.617414
# 155 3 2014-08-13
# 155 4 Red-tail Hawk
# 155 5 ACTIVE NEST
# 155 6 152
# 155 7 POINT (-104.52344 40.19385)
# 156 0 153.0
# 156 1 40.135256
# 156 2 -104.616223
# 156 3 2009-09-21
# 156 4 Red-tail Hawk
# 156 5 INACTIVE NEST
# 156 6 153
# 156 7 POINT (-104.63036 40.17159)
# 157 0 154.0
# 157 1 40.1125
# 157 2 -105.051913
# 157 3 2009-09-21
# 157 4 Red-tail Hawk
# 157 5 FLEDGED NEST
# 157 6 154
# 157 7 POINT (-105.11649 40.14566)
# 158 0 155.0
# 158 1 40.076103
# 158 2 -105.006404
# 158 3 2009-09-21
# 158 4 Red-tail Hawk
# 158 5 INACTIVE NEST
# 158 6 155
# 158 7 POINT (-104.97112 40.13564)
# 159 0 156.0
# 159 1 40.170812
# 159 2 -104.997346
# 159 3 2014-03-28
# 159 4 Swainsons Hawk
# 159 5 FLEDGED NEST
# 159 6 156
# 159 7 POINT (-105.03309 40.17915)
# 160 0 157.0
# 160 1 40.145261
# 160 2 -104.80076
# 160 3 2009-09-21
# 160 4 Red-tail Hawk
# 160 5 INACTIVE NEST
# 160 6 157
# 160 7 POINT (-104.73093 40.15405)
# 161 0 158.0
# 161 1 40.006736
# 161 2 -104.950838
# 161 3 2009-12-01
# 161 4 Swainsons Hawk
# 161 5 INACTIVE NEST
# 161 6 158
# 161 7 POINT (-104.93439 40.02142)
# 162 0 159.0
# 162 1 40.29972
# 162 2 -104.661765
# 162 3 2009-12-01
# 162 4 Swainsons Hawk
# 162 5 INACTIVE NEST
# 162 6 159
# 162 7 POINT (-104.71062 40.23542)
# 163 0 160.0
# 163 1 40.289884
# 163 2 -104.668438
# 163 3 2009-12-01
# 163 4 Swainsons Hawk
# 163 5 INACTIVE NEST
# 163 6 160
# 163 7 POINT (-104.75082 40.29079)
# 164 0 161.0
# 164 1 40.292939
# 164 2 -104.671882
# 164 3 2009-12-01
# 164 4 Swainsons Hawk
# 164 5 ACTIVE NEST
# 164 6 161
# 164 7 POINT (-104.64941 40.29793)
# 165 0 162.0
# 165 1 40.293358
# 165 2 -104.673633
# 165 3 2009-12-01
# 165 4 Red-tail Hawk
# 165 5 ACTIVE NEST
# 165 6 162
# 165 7 POINT (-104.6791 40.33783)
# 166 0 163.0
# 166 1 40.226344
# 166 2 -104.789309
# 166 3 2009-12-01
# 166 4 Red-tail Hawk
# 166 5 ACTIVE NEST
# 166 6 163
# 166 7 POINT (-104.81088 40.25406)
# 167 0 164.0
# 167 1 40.159268
# 167 2 -104.832881
# 167 3 2009-12-01
# 167 4 Swainsons Hawk
# 167 5 INACTIVE NEST
# 167 6 164
# 167 7 POINT (-104.9125 40.21974)
# 168 0 165.0
# 168 1 40.160131
# 168 2 -104.831494
# 168 3 2009-12-01
# 168 4 Red-tail Hawk
# 168 5 INACTIVE NEST
# 168 6 165
# 168 7 POINT (-104.77161 40.2095)
# 169 0 166.0
# 169 1 40.21755
# 169 2 -104.778994
# 169 3 2009-12-01
# 169 4 Red-tail Hawk
# 169 5 ACTIVE NEST
# 169 6 166
# 169 7 POINT (-104.74842 40.16597)
# 170 0 167.0
# 170 1 40.136026
# 170 2 -104.987064
# 170 3 2014-06-25
# 170 4 Swainsons Hawk
# 170 5 FLEDGED NEST
# 170 6 167
# 170 7 POINT (-105.03474 40.06689)
# 171 0 168.0
# 171 1 40.145528
# 171 2 -104.969699
# 171 3 2014-06-25
# 171 4 Red-tail Hawk
# 171 5 INACTIVE NEST
# 171 6 168
# 171 7 POINT (-104.99082 40.15241)
# 172 0 169.0
# 172 1 39.91276
# 172 2 -104.778561
# 172 3 2010-03-23
# 172 4 Red-tail Hawk
# 172 5 FLEDGED NEST
# 172 6 169
# 172 7 POINT (-104.86037 39.9666)
# 173 0 170.0
# 173 1 39.919324
# 173 2 -104.785643
# 173 3 2010-03-23
# 173 4 Swainsons Hawk
# 173 5 INACTIVE NEST
# 173 6 170
# 173 7 POINT (-104.87099 39.89833)
# 174 0 171.0
# 174 1 39.91862
# 174 2 -104.789916
# 174 3 2010-03-23
# 174 4 Swainsons Hawk
# 174 5 ACTIVE NEST
# 174 6 171
# 174 7 POINT (-104.73176 39.86449)
# 175 0 173.0
# 175 1 40.072903
# 175 2 -104.895859
# 175 3 2010-03-23
# 175 4 Red-tail Hawk
# 175 5 INACTIVE NEST
# 175 6 173
# 175 7 POINT (-104.84726 40.02745)
# 176 0 174.0
# 176 1 40.166473
# 176 2 -104.851078
# 176 3 2014-06-26
# 176 4 Red-tail Hawk
# 176 5 ACTIVE NEST
# 176 6 174
# 176 7 POINT (-104.75938 40.12098)
# 177 0 175.0
# 177 1 40.160287
# 177 2 -104.861343
# 177 3 2010-03-23
# 177 4 Swainsons Hawk
# 177 5 INACTIVE NEST
# 177 6 175
# 177 7 POINT (-104.82586 40.13976)
# 178 0 176.0
# 178 1 40.162092
# 178 2 -104.848625
# 178 3 2014-06-26
# 178 4 Swainsons Hawk
# 178 5 ACTIVE NEST
# 178 6 176
# 178 7 POINT (-104.76202 40.10325)
# 179 0 177.0
# 179 1 40.356638
# 179 2 -104.853652
# 179 3 2010-03-23
# 179 4 Red-tail Hawk
# 179 5 INACTIVE NEST
# 179 6 177
# 179 7 POINT (-104.94406 40.30175)
# 180 0 178.0
# 180 1 40.174502
# 180 2 -104.928179
# 180 3 2010-03-23
# 180 4 Red-tail Hawk
# 180 5 ACTIVE NEST
# 180 6 178
# 180 7 POINT (-104.89967 40.20431)
# 181 0 179.0
# 181 1 40.341031
# 181 2 -104.838486
# 181 3 2010-03-23
# 181 4 Red-tail Hawk
# 181 5 INACTIVE NEST
# 181 6 179
# 181 7 POINT (-104.77919 40.28223)
# 182 0 180.0
# 182 1 40.338924
# 182 2 -104.838773
# 182 3 2010-03-23
# 182 4 Red-tail Hawk
# 182 5 INACTIVE NEST
# 182 6 180
# 182 7 POINT (-104.93145 40.31238)
# 183 0 181.0
# 183 1 40.235283
# 183 2 -104.933358
# 183 3 2010-03-23
# 183 4 Red-tail Hawk
# 183 5 ACTIVE NEST
# 183 6 181
# 183 7 POINT (-104.97757 40.18457)
# 184 0 182.0
# 184 1 40.201741
# 184 2 -104.983809
# 184 3 2010-03-23
# 184 4 Red-tail Hawk
# 184 5 ACTIVE NEST
# 184 6 182
# 184 7 POINT (-105.05784 40.20291)
# 185 0 184.0
# 185 1 39.977388
# 185 2 -104.893334
# 185 3 2010-03-23
# 185 4 Red-tail Hawk
# 185 5 INACTIVE NEST
# 185 6 184
# 185 7 POINT (-104.8283 40.02308)
# 186 0 185.0
# 186 1 39.98485
# 186 2 -104.905527
# 186 3 2010-03-23
# 186 4 Swainsons Hawk
# 186 5 INACTIVE NEST
# 186 6 185
# 186 7 POINT (-104.86663 39.91547)
# 187 0 186.0
# 187 1 40.174497
# 187 2 -104.758157
# 187 3 2010-03-23
# 187 4 Red-tail Hawk
# 187 5 INACTIVE NEST
# 187 6 186
# 187 7 POINT (-104.66622 40.20521)
# 188 0 187.0
# 188 1 40.169435
# 188 2 -104.640757
# 188 3 2010-03-23
# 188 4 Red-tail Hawk
# 188 5 INACTIVE NEST
# 188 6 187
# 188 7 POINT (-104.68392 40.15443)
# 189 0 188.0
# 189 1 40.140847
# 189 2 -104.714829
# 189 3 2010-03-23
# 189 4 Red-tail Hawk
# 189 5 ACTIVE NEST
# 189 6 188
# 189 7 POINT (-104.69689 40.18767)
# 190 0 189.0
# 190 1 40.099861
# 190 2 -105.014888
# 190 3 2010-10-26
# 190 4 Swainsons Hawk
# 190 5 ACTIVE NEST
# 190 6 189
# 190 7 POINT (-104.92674 40.16508)
# 191 0 190.0
# 191 1 40.177878
# 191 2 -104.960722
# 191 3 2014-08-15
# 191 4 Red-tail Hawk
# 191 5 INACTIVE NEST
# 191 6 190
# 191 7 POINT (-105.02043 40.11285)
# 192 0 191.0
# 192 1 40.07458
# 192 2 -104.985551
# 192 3 2010-10-26
# 192 4 Red-tail Hawk
# 192 5 INACTIVE NEST
# 192 6 191
# 192 7 POINT (-105.01651 40.0752)
# 193 0 192.0
# 193 1 40.061201
# 193 2 -105.005382
# 193 3 2010-10-26
# 193 4 Red-tail Hawk
# 193 5 ACTIVE NEST
# 193 6 192
# 193 7 POINT (-105.06703 40.11313)
# 194 0 193.0
# 194 1 40.372327
# 194 2 -104.443097
# 194 3 2010-10-26
# 194 4 Red-tail Hawk
# 194 5 ACTIVE NEST
# 194 6 193
# 194 7 POINT (-104.45843 40.41029)
# 195 0 194.0
# 195 1 40.371026
# 195 2 -104.449951
# 195 3 2010-10-26
# 195 4 Swainsons Hawk
# 195 5 FLEDGED NEST
# 195 6 194
# 195 7 POINT (-104.43838 40.33633)
# 196 0 195.0
# 196 1 40.131129
# 196 2 -104.668929
# 196 3 2010-10-26
# 196 4 Red-tail Hawk
# 196 5 FLEDGED NEST
# 196 6 195
# 196 7 POINT (-104.7198 40.15161)
# 197 0 196.0
# 197 1 40.112731
# 197 2 -104.948514
# 197 3 2011-04-06
# 197 4 Red-tail Hawk
# 197 5 ACTIVE NEST
# 197 6 196
# 197 7 POINT (-104.91655 40.09337)
# 198 0 197.0
# 198 1 40.061725
# 198 2 -104.848436
# 198 3 2011-04-06
# 198 4 Swainsons Hawk
# 198 5 ACTIVE NEST
# 198 6 197
# 198 7 POINT (-104.90909 40.09074)
# 199 0 198.0
# 199 1 40.113723
# 199 2 -104.949271
# 199 3 2011-04-06
# 199 4 Red-tail Hawk
# 199 5 ACTIVE NEST
# 199 6 198
# 199 7 POINT (-104.89801 40.11342)
# 200 0 199.0
# 200 1 40.172293
# 200 2 -104.784592
# 200 3 2011-04-06
# 200 4 Red-tail Hawk
# 200 5 INACTIVE NEST
# 200 6 199
# 200 7 POINT (-104.8704 40.13612)
# 201 0 200.0
# 201 1 40.126929
# 201 2 -104.814651
# 201 3 2011-04-06
# 201 4 Red-tail Hawk
# 201 5 INACTIVE NEST
# 201 6 200
# 201 7 POINT (-104.76846 40.11321)
# 202 0 201.0
# 202 1 40.145757
# 202 2 -104.779728
# 202 3 2011-04-06
# 202 4 Swainsons Hawk
# 202 5 INACTIVE NEST
# 202 6 201
# 202 7 POINT (-104.75637 40.14731)
# 203 0 202.0
# 203 1 40.268263
# 203 2 -104.743564
# 203 3 2011-04-06
# 203 4 Swainsons Hawk
# 203 5 INACTIVE NEST
# 203 6 202
# 203 7 POINT (-104.66766 40.2258)
# 204 0 203.0
# 204 1 40.150653
# 204 2 -104.980521
# 204 3 2011-04-06
# 204 4 Red-tail Hawk
# 204 5 ACTIVE NEST
# 204 6 203
# 204 7 POINT (-105.04248 40.22027)
# 205 0 204.0
# 205 1 40.152757
# 205 2 -104.815532
# 205 3 2011-04-06
# 205 4 Red-tail Hawk
# 205 5 INACTIVE NEST
# 205 6 204
# 205 7 POINT (-104.86334 40.21205)
# 206 0 205.0
# 206 1 40.148665
# 206 2 -104.826989
# 206 3 2011-04-06
# 206 4 Red-tail Hawk
# 206 5 INACTIVE NEST
# 206 6 205
# 206 7 POINT (-104.8047 40.08208)
# 207 0 206.0
# 207 1 40.147341
# 207 2 -104.825788
# 207 3 2011-04-06
# 207 4 Red-tail Hawk
# 207 5 INACTIVE NEST
# 207 6 206
# 207 7 POINT (-104.81832 40.1991)
# 208 0 207.0
# 208 1 40.134698
# 208 2 -104.828673
# 208 3 2011-04-06
# 208 4 Swainsons Hawk
# 208 5 ACTIVE NEST
# 208 6 207
# 208 7 POINT (-104.82777 40.12576)
# 209 0 208.0
# 209 1 40.14708
# 209 2 -104.834212
# 209 3 2011-04-06
# 209 4 Red-tail Hawk
# 209 5 INACTIVE NEST
# 209 6 208
# 209 7 POINT (-104.77567 40.21635)
# 210 0 209.0
# 210 1 40.13957
# 210 2 -104.825099
# 210 3 2011-04-06
# 210 4 Red-tail Hawk
# 210 5 INACTIVE NEST
# 210 6 209
# 210 7 POINT (-104.86175 40.12318)
# 211 0 210.0
# 211 1 40.128951
# 211 2 -104.774438
# 211 3 2014-08-13
# 211 4 Red-tail Hawk
# 211 5 INACTIVE NEST
# 211 6 210
# 211 7 POINT (-104.73089 40.08466)
# 212 0 211.0
# 212 1 40.122824
# 212 2 -104.709241
# 212 3 2011-04-06
# 212 4 Red-tail Hawk
# 212 5 INACTIVE NEST
# 212 6 211
# 212 7 POINT (-104.78983 40.12918)
# 213 0 212.0
# 213 1 40.121872
# 213 2 -104.709205
# 213 3 2011-04-06
# 213 4 Red-tail Hawk
# 213 5 FLEDGED NEST
# 213 6 212
# 213 7 POINT (-104.69793 40.19232)
# 214 0 213.0
# 214 1 40.123081
# 214 2 -104.709844
# 214 3 2011-04-06
# 214 4 Swainsons Hawk
# 214 5 INACTIVE NEST
# 214 6 213
# 214 7 POINT (-104.65041 40.1693)
# 215 0 214.0
# 215 1 40.125323
# 215 2 -104.715126
# 215 3 2011-04-06
# 215 4 Red-tail Hawk
# 215 5 ACTIVE NEST
# 215 6 214
# 215 7 POINT (-104.6936 40.11083)
# 216 0 215.0
# 216 1 40.150356
# 216 2 -104.727755
# 216 3 2015-07-17
# 216 4 Swainsons Hawk
# 216 5 INACTIVE NEST
# 216 6 215
# 216 7 POINT (-104.78471 40.11843)
# 217 0 216.0
# 217 1 40.153737
# 217 2 -104.734575
# 217 3 2011-04-06
# 217 4 Swainsons Hawk
# 217 5 ACTIVE NEST
# 217 6 216
# 217 7 POINT (-104.75618 40.15758)
# 218 0 217.0
# 218 1 40.187351
# 218 2 -104.696651
# 218 3 2011-04-06
# 218 4 Red-tail Hawk
# 218 5 INACTIVE NEST
# 218 6 217
# 218 7 POINT (-104.7882 40.13419)
# 219 0 218.0
# 219 1 40.131003
# 219 2 -104.819187
# 219 3 2011-04-06
# 219 4 Red-tail Hawk
# 219 5 FLEDGED NEST
# 219 6 218
# 219 7 POINT (-104.90224 40.09308)
# 220 0 219.0
# 220 1 40.247995
# 220 2 -104.709889
# 220 3 2011-04-06
# 220 4 Red-tail Hawk
# 220 5 INACTIVE NEST
# 220 6 219
# 220 7 POINT (-104.80145 40.30365)
# 221 0 220.0
# 221 1 40.20476
# 221 2 -104.731688
# 221 3 2014-07-09
# 221 4 Swainsons Hawk
# 221 5 INACTIVE NEST
# 221 6 220
# 221 7 POINT (-104.65619 40.26741)
# 222 0 221.0
# 222 1 40.203464
# 222 2 -104.764686
# 222 3 2011-04-06
# 222 4 Swainsons Hawk
# 222 5 INACTIVE NEST
# 222 6 221
# 222 7 POINT (-104.76316 40.22673)
# 223 0 222.0
# 223 1 40.209897
# 223 2 -104.772162
# 223 3 2014-06-10
# 223 4 Swainsons Hawk
# 223 5 FLEDGED NEST
# 223 6 222
# 223 7 POINT (-104.83038 40.27413)
# 224 0 223.0
# 224 1 40.196331
# 224 2 -104.777856
# 224 3 2011-04-06
# 224 4 Red-tail Hawk
# 224 5 INACTIVE NEST
# 224 6 223
# 224 7 POINT (-104.70182 40.12719)
# 225 0 224.0
# 225 1 40.287577
# 225 2 -104.658659
# 225 3 2011-04-06
# 225 4 Red-tail Hawk
# 225 5 INACTIVE NEST
# 225 6 224
# 225 7 POINT (-104.61904 40.29743)
# 226 0 225.0
# 226 1 40.321585
# 226 2 -104.902831
# 226 3 2011-04-06
# 226 4 Swainsons Hawk
# 226 5 INACTIVE NEST
# 226 6 225
# 226 7 POINT (-104.81706 40.3174)
# 227 0 226.0
# 227 1 40.26126
# 227 2 -104.83005
# 227 3 2011-04-06
# 227 4 Swainsons Hawk
# 227 5 INACTIVE NEST
# 227 6 226
# 227 7 POINT (-104.89886 40.30126)
# 228 0 227.0
# 228 1 40.134202
# 228 2 -104.846785
# 228 3 2011-04-06
# 228 4 Swainsons Hawk
# 228 5 FLEDGED NEST
# 228 6 227
# 228 7 POINT (-104.8052 40.15268)
# 229 0 228.0
# 229 1 40.303645
# 229 2 -104.639123
# 229 3 2011-04-06
# 229 4 Red-tail Hawk
# 229 5 INACTIVE NEST
# 229 6 228
# 229 7 POINT (-104.64396 40.30093)
# 230 0 229.0
# 230 1 40.287961
# 230 2 -104.657788
# 230 3 2011-04-06
# 230 4 Swainsons Hawk
# 230 5 INACTIVE NEST
# 230 6 229
# 230 7 POINT (-104.71123 40.27445)
# 231 0 230.0
# 231 1 40.139559
# 231 2 -104.674827
# 231 3 2015-03-19
# 231 4 Red-tail Hawk
# 231 5 ACTIVE NEST
# 231 6 230
# 231 7 POINT (-104.71889 40.13759)
# 232 0 231.0
# 232 1 40.182995
# 232 2 -104.976268
# 232 3 2011-04-06
# 232 4 Red-tail Hawk
# 232 5 FLEDGED NEST
# 232 6 231
# 232 7 POINT (-104.90873 40.1582)
# 233 0 232.0
# 233 1 40.311822
# 233 2 -104.598844
# 233 3 2011-04-06
# 233 4 Red-tail Hawk
# 233 5 ACTIVE NEST
# 233 6 232
# 233 7 POINT (-104.69255 40.36336)
# 234 0 233.0
# 234 1 40.344244
# 234 2 -104.877918
# 234 3 2011-04-06
# 234 4 Swainsons Hawk
# 234 5 FLEDGED NEST
# 234 6 233
# 234 7 POINT (-104.84487 40.29813)
# 235 0 234.0
# 235 1 40.190365
# 235 2 -104.852526
# 235 3 2014-05-12
# 235 4 Red-tail Hawk
# 235 5 FLEDGED NEST
# 235 6 234
# 235 7 POINT (-104.86094 40.24521)
# 236 0 235.0
# 236 1 40.191627
# 236 2 -104.854105
# 236 3 2011-04-06
# 236 4 Red-tail Hawk
# 236 5 ACTIVE NEST
# 236 6 235
# 236 7 POINT (-104.85656 40.12801)
# 237 0 236.0
# 237 1 40.352189
# 237 2 -104.834265
# 237 3 2011-04-06
# 237 4 Swainsons Hawk
# 237 5 ACTIVE NEST
# 237 6 236
# 237 7 POINT (-104.82238 40.42231)
# 238 0 237.0
# 238 1 40.284446
# 238 2 -104.859843
# 238 3 2011-04-06
# 238 4 Swainsons Hawk
# 238 5 INACTIVE NEST
# 238 6 237
# 238 7 POINT (-104.92195 40.31506)
# 239 0 238.0
# 239 1 40.130103
# 239 2 -104.655518
# 239 3 2015-07-28
# 239 4 Red-tail Hawk
# 239 5 ACTIVE NEST
# 239 6 238
# 239 7 POINT (-104.57469 40.13347)
# 240 0 239.0
# 240 1 40.141795
# 240 2 -104.714559
# 240 3 2011-04-06
# 240 4 Swainsons Hawk
# 240 5 INACTIVE NEST
# 240 6 239
# 240 7 POINT (-104.79265 40.21126)
# 241 0 240.0
# 241 1 40.140795
# 241 2 -104.714801
# 241 3 2011-04-06
# 241 4 Swainsons Hawk
# 241 5 FLEDGED NEST
# 241 6 240
# 241 7 POINT (-104.63907 40.13086)
# 242 0 241.0
# 242 1 40.354755
# 242 2 -104.815219
# 242 3 2011-04-06
# 242 4 Swainsons Hawk
# 242 5 FLEDGED NEST
# 242 6 241
# 242 7 POINT (-104.73975 40.40259)
# 243 0 242.0
# 243 1 40.219212
# 243 2 -104.938508
# 243 3 2014-03-24
# 243 4 Swainsons Hawk
# 243 5 FLEDGED NEST
# 243 6 242
# 243 7 POINT (-104.9475 40.27563)
# 244 0 243.0
# 244 1 40.2342
# 244 2 -104.753392
# 244 3 2011-04-06
# 244 4 Swainsons Hawk
# 244 5 ACTIVE NEST
# 244 6 243
# 244 7 POINT (-104.68992 40.30068)
# 245 0 244.0
# 245 1 40.233822
# 245 2 -104.854233
# 245 3 2011-04-06
# 245 4 Swainsons Hawk
# 245 5 INACTIVE NEST
# 245 6 244
# 245 7 POINT (-104.87252 40.29698)
# 246 0 246.0
# 246 1 40.280609
# 246 2 -104.855574
# 246 3 2011-04-06
# 246 4 Red-tail Hawk
# 246 5 ACTIVE NEST
# 246 6 246
# 246 7 POINT (-104.90768 40.3181)
# 247 0 247.0
# 247 1 40.282149
# 247 2 -104.85632
# 247 3 2011-04-06
# 247 4 Red-tail Hawk
# 247 5 FLEDGED NEST
# 247 6 247
# 247 7 POINT (-104.90453 40.21122)
# 248 0 248.0
# 248 1 40.083363
# 248 2 -104.973908
# 248 3 2011-04-06
# 248 4 Red-tail Hawk
# 248 5 INACTIVE NEST
# 248 6 248
# 248 7 POINT (-104.93681 40.10679)
# 249 0 249.0
# 249 1 40.35496
# 249 2 -104.815277
# 249 3 2011-04-06
# 249 4 Red-tail Hawk
# 249 5 INACTIVE NEST
# 249 6 249
# 249 7 POINT (-104.79235 40.35343)
# 250 0 250.0
# 250 1 40.26248
# 250 2 -104.632276
# 250 3 2011-04-06
# 250 4 Swainsons Hawk
# 250 5 ACTIVE NEST
# 250 6 250
# 250 7 POINT (-104.70629 40.32989)
# 251 0 251.0
# 251 1 40.094522
# 251 2 -104.794962
# 251 3 2011-04-06
# 251 4 Red-tail Hawk
# 251 5 INACTIVE NEST
# 251 6 251
# 251 7 POINT (-104.81605 40.11569)
# 252 0 252.0
# 252 1 40.135756
# 252 2 -104.602597
# 252 3 2011-04-06
# 252 4 Swainsons Hawk
# 252 5 INACTIVE NEST
# 252 6 252
# 252 7 POINT (-104.56551 40.07967)
# 253 0 253.0
# 253 1 40.157458
# 253 2 -104.618074
# 253 3 2011-04-06
# 253 4 Swainsons Hawk
# 253 5 INACTIVE NEST
# 253 6 253
# 253 7 POINT (-104.69824 40.12011)
# 254 0 254.0
# 254 1 40.156475
# 254 2 -104.870785
# 254 3 2015-08-10
# 254 4 Swainsons Hawk
# 254 5 FLEDGED NEST
# 254 6 254
# 254 7 POINT (-104.91081 40.1328)
# 255 0 255.0
# 255 1 40.166938
# 255 2 -104.650126
# 255 3 2011-04-06
# 255 4 Red-tail Hawk
# 255 5 INACTIVE NEST
# 255 6 255
# 255 7 POINT (-104.6612 40.20892)
# 256 0 256.0
# 256 1 40.074878
# 256 2 -104.775723
# 256 3 2011-04-06
# 256 4 Red-tail Hawk
# 256 5 INACTIVE NEST
# 256 6 256
# 256 7 POINT (-104.8674 40.10971)
# 257 0 257.0
# 257 1 40.040354
# 257 2 -104.976636
# 257 3 2011-04-06
# 257 4 Red-tail Hawk
# 257 5 INACTIVE NEST
# 257 6 257
# 257 7 POINT (-104.97253 39.97542)
# 258 0 258.0
# 258 1 40.082473
# 258 2 -104.972632
# 258 3 2011-04-06
# 258 4 Swainsons Hawk
# 258 5 FLEDGED NEST
# 258 6 258
# 258 7 POINT (-104.94112 40.08915)
# 259 0 259.0
# 259 1 40.369841
# 259 2 -104.630526
# 259 3 2011-04-06
# 259 4 Red-tail Hawk
# 259 5 INACTIVE NEST
# 259 6 259
# 259 7 POINT (-104.71191 40.37316)
# 260 0 260.0
# 260 1 40.356707
# 260 2 -104.815209
# 260 3 2011-04-06
# 260 4 Swainsons Hawk
# 260 5 ACTIVE NEST
# 260 6 260
# 260 7 POINT (-104.76325 40.3786)
# 261 0 261.0
# 261 1 40.184555
# 261 2 -104.842425
# 261 3 2011-04-06
# 261 4 Red-tail Hawk
# 261 5 INACTIVE NEST
# 261 6 261
# 261 7 POINT (-104.93341 40.19634)
# 262 0 262.0
# 262 1 40.221135
# 262 2 -104.752757
# 262 3 2014-06-26
# 262 4 Swainsons Hawk
# 262 5 ACTIVE NEST
# 262 6 262
# 262 7 POINT (-104.73169 40.20356)
# 263 0 263.0
# 263 1 40.217543
# 263 2 -104.967378
# 263 3 2011-04-06
# 263 4 Swainsons Hawk
# 263 5 INACTIVE NEST
# 263 6 263
# 263 7 POINT (-105.03344 40.22257)
# 264 0 264.0
# 264 1 40.238115
# 264 2 -104.633649
# 264 3 2011-04-06
# 264 4 Red-tail Hawk
# 264 5 ACTIVE NEST
# 264 6 264
# 264 7 POINT (-104.61773 40.20718)
# 265 0 265.0
# 265 1 40.139405
# 265 2 -104.67469
# 265 3 2015-03-03
# 265 4 Red-tail Hawk
# 265 5 ACTIVE NEST
# 265 6 265
# 265 7 POINT (-104.68158 40.12377)
# 266 0 266.0
# 266 1 40.14141
# 266 2 -104.659302
# 266 3 2011-04-06
# 266 4 Red-tail Hawk
# 266 5 INACTIVE NEST
# 266 6 266
# 266 7 POINT (-104.61384 40.08174)
# 267 0 267.0
# 267 1 40.152424
# 267 2 -104.655317
# 267 3 2011-04-06
# 267 4 Red-tail Hawk
# 267 5 INACTIVE NEST
# 267 6 267
# 267 7 POINT (-104.69766 40.11934)
# 268 0 268.0
# 268 1 40.132348
# 268 2 -104.876502
# 268 3 2015-03-17
# 268 4 Swainsons Hawk
# 268 5 FLEDGED NEST
# 268 6 268
# 268 7 POINT (-104.90477 40.08878)
# 269 0 269.0
# 269 1 40.13096
# 269 2 -104.867264
# 269 3 2011-04-06
# 269 4 Red-tail Hawk
# 269 5 INACTIVE NEST
# 269 6 269
# 269 7 POINT (-104.82515 40.10568)
# 270 0 270.0
# 270 1 40.271286
# 270 2 -104.680353
# 270 3 2011-04-06
# 270 4 Swainsons Hawk
# 270 5 INACTIVE NEST
# 270 6 270
# 270 7 POINT (-104.73904 40.33248)
# 271 0 271.0
# 271 1 40.149666
# 271 2 -104.871301
# 271 3 2015-07-27
# 271 4 Red-tail Hawk
# 271 5 INACTIVE NEST
# 271 6 271
# 271 7 POINT (-104.9482 40.20404)
# 272 0 272.0
# 272 1 40.149492
# 272 2 -104.8725
# 272 3 2015-07-27
# 272 4 Red-tail Hawk
# 272 5 FLEDGED NEST
# 272 6 272
# 272 7 POINT (-104.89206 40.13798)
# 273 0 273.0
# 273 1 40.15034
# 273 2 -104.872404
# 273 3 2015-07-27
# 273 4 Red-tail Hawk
# 273 5 ACTIVE NEST
# 273 6 273
# 273 7 POINT (-104.92523 40.2018)
# 274 0 274.0
# 274 1 40.246646
# 274 2 -104.730501
# 274 3 2011-04-06
# 274 4 Red-tail Hawk
# 274 5 INACTIVE NEST
# 274 6 274
# 274 7 POINT (-104.76461 40.26577)
# 275 0 276.0
# 275 1 40.246662
# 275 2 -104.731529
# 275 3 2011-04-06
# 275 4 Swainsons Hawk
# 275 5 INACTIVE NEST
# 275 6 276
# 275 7 POINT (-104.69659 40.20409)
# 276 0 277.0
# 276 1 40.24669
# 276 2 -104.728128
# 276 3 2011-04-06
# 276 4 Swainsons Hawk
# 276 5 ACTIVE NEST
# 276 6 277
# 276 7 POINT (-104.72966 40.28346)
# 277 0 278.0
# 277 1 40.215623
# 277 2 -104.650392
# 277 3 2011-04-06
# 277 4 Red-tail Hawk
# 277 5 INACTIVE NEST
# 277 6 278
# 277 7 POINT (-104.64259 40.26394)
# 278 0 279.0
# 278 1 40.215362
# 278 2 -104.650986
# 278 3 2011-04-06
# 278 4 Red-tail Hawk
# 278 5 ACTIVE NEST
# 278 6 279
# 278 7 POINT (-104.6723 40.16059)
# 279 0 280.0
# 279 1 40.264665
# 279 2 -104.665357
# 279 3 2011-04-06
# 279 4 Red-tail Hawk
# 279 5 ACTIVE NEST
# 279 6 280
# 279 7 POINT (-104.69779 40.31752)
# 280 0 281.0
# 280 1 40.265551
# 280 2 -104.666134
# 280 3 2011-04-06
# 280 4 Red-tail Hawk
# 280 5 ACTIVE NEST
# 280 6 281
# 280 7 POINT (-104.58348 40.2747)
# 281 0 282.0
# 281 1 40.246151
# 281 2 -104.711471
# 281 3 2011-08-02
# 281 4 Red-tail Hawk
# 281 5 INACTIVE NEST
# 281 6 282
# 281 7 POINT (-104.6707 40.21222)
# 282 0 283.0
# 282 1 39.979003
# 282 2 -104.960247
# 282 3 2011-08-02
# 282 4 Swainsons Hawk
# 282 5 INACTIVE NEST
# 282 6 283
# 282 7 POINT (-104.96309 39.91229)
# 283 0 284.0
# 283 1 39.940391
# 283 2 -105.024798
# 283 3 2011-08-02
# 283 4 Red-tail Hawk
# 283 5 ACTIVE NEST
# 283 6 284
# 283 7 POINT (-104.95535 39.88169)
# 284 0 285.0
# 284 1 40.155977
# 284 2 -104.637058
# 284 3 2011-08-02
# 284 4 Swainsons Hawk
# 284 5 ACTIVE NEST
# 284 6 285
# 284 7 POINT (-104.64998 40.09792)
# 285 0 286.0
# 285 1 40.140005
# 285 2 -104.675341
# 285 3 2015-03-19
# 285 4 Swainsons Hawk
# 285 5 ACTIVE NEST
# 285 6 286
# 285 7 POINT (-104.69465 40.16759)
# 286 0 287.0
# 286 1 40.140923
# 286 2 -104.676326
# 286 3 2015-03-19
# 286 4 Swainsons Hawk
# 286 5 ACTIVE NEST
# 286 6 287
# 286 7 POINT (-104.65516 40.18008)
# 287 0 288.0
# 287 1 40.262209
# 287 2 -104.677883
# 287 3 2011-08-02
# 287 4 Red-tail Hawk
# 287 5 FLEDGED NEST
# 287 6 288
# 287 7 POINT (-104.74047 40.30813)
# 288 0 289.0
# 288 1 40.151287
# 288 2 -104.73021
# 288 3 2014-04-08
# 288 4 Red-tail Hawk
# 288 5 INACTIVE NEST
# 288 6 289
# 288 7 POINT (-104.78174 40.20089)
# 289 0 290.0
# 289 1 40.151167
# 289 2 -104.729671
# 289 3 2014-04-08
# 289 4 Swainsons Hawk
# 289 5 ACTIVE NEST
# 289 6 290
# 289 7 POINT (-104.716 40.0965)
# 290 0 291.0
# 290 1 40.152257
# 290 2 -104.668938
# 290 3 2011-08-02
# 290 4 Red-tail Hawk
# 290 5 INACTIVE NEST
# 290 6 291
# 290 7 POINT (-104.72083 40.16656)
# 291 0 292.0
# 291 1 40.478033
# 291 2 -104.594495
# 291 3 2011-11-07
# 291 4 Swainsons Hawk
# 291 5 INACTIVE NEST
# 291 6 292
# 291 7 POINT (-104.64909 40.41189)
# 292 0 293.0
# 292 1 40.106174
# 292 2 -105.041608
# 292 3 2011-11-07
# 292 4 Swainsons Hawk
# 292 5 INACTIVE NEST
# 292 6 293
# 292 7 POINT (-105.08851 40.06113)
# 293 0 294.0
# 293 1 40.104407
# 293 2 -104.981466
# 293 3 2011-11-07
# 293 4 Swainsons Hawk
# 293 5 INACTIVE NEST
# 293 6 294
# 293 7 POINT (-104.92816 40.08412)
# 294 0 295.0
# 294 1 40.137484
# 294 2 -104.859462
# 294 3 2011-11-07
# 294 4 Swainsons Hawk
# 294 5 FLEDGED NEST
# 294 6 295
# 294 7 POINT (-104.88158 40.08582)
# 295 0 296.0
# 295 1 40.131479
# 295 2 -104.930555
# 295 3 2011-11-07
# 295 4 Red-tail Hawk
# 295 5 ACTIVE NEST
# 295 6 296
# 295 7 POINT (-105.02018 40.15646)
# 296 0 297.0
# 296 1 40.149371
# 296 2 -104.713464
# 296 3 2015-06-02
# 296 4 Swainsons Hawk
# 296 5 ACTIVE NEST
# 296 6 297
# 296 7 POINT (-104.77323 40.09031)
# 297 0 298.0
# 297 1 40.21415
# 297 2 -104.902777
# 297 3 2011-11-07
# 297 4 Red-tail Hawk
# 297 5 ACTIVE NEST
# 297 6 298
# 297 7 POINT (-104.81285 40.24195)
# 298 0 299.0
# 298 1 40.106174
# 298 2 -105.041608
# 298 3 2011-11-07
# 298 4 Swainsons Hawk
# 298 5 INACTIVE NEST
# 298 6 299
# 298 7 POINT (-105.05372 40.0753)
# 299 0 300.0
# 299 1 40.199408
# 299 2 -104.989102
# 299 3 2011-11-07
# 299 4 Red-tail Hawk
# 299 5 ACTIVE NEST
# 299 6 300
# 299 7 POINT (-105.0724 40.26148)
# 300 0 301.0
# 300 1 40.174876
# 300 2 -105.002315
# 300 3 2011-11-07
# 300 4 Red-tail Hawk
# 300 5 INACTIVE NEST
# 300 6 301
# 300 7 POINT (-104.96824 40.18357)
# 301 0 302.0
# 301 1 40.261584
# 301 2 -104.692032
# 301 3 2011-11-07
# 301 4 Swainsons Hawk
# 301 5 INACTIVE NEST
# 301 6 302
# 301 7 POINT (-104.72059 40.32503)
# 302 0 303.0
# 302 1 40.030949
# 302 2 -104.693082
# 302 3 2011-12-29
# 302 4 Swainsons Hawk
# 302 5 ACTIVE NEST
# 302 6 303
# 302 7 POINT (-104.77518 39.96141)
# 303 0 304.0
# 303 1 40.163862
# 303 2 -104.584823
# 303 3 2011-12-29
# 303 4 Swainsons Hawk
# 303 5 ACTIVE NEST
# 303 6 304
# 303 7 POINT (-104.51274 40.15899)
# 304 0 305.0
# 304 1 40.199161
# 304 2 -104.916275
# 304 3 2011-12-29
# 304 4 Red-tail Hawk
# 304 5 INACTIVE NEST
# 304 6 305
# 304 7 POINT (-104.93908 40.25292)
# 305 0 306.0
# 305 1 40.36628
# 305 2 -104.6398
# 305 3 2011-12-29
# 305 4 Red-tail Hawk
# 305 5 ACTIVE NEST
# 305 6 306
# 305 7 POINT (-104.67893 40.40555)
# 306 0 307.0
# 306 1 40.178074
# 306 2 -104.858927
# 306 3 2015-04-03
# 306 4 Red-tail Hawk
# 306 5 ACTIVE NEST
# 306 6 307
# 306 7 POINT (-104.7762 40.14175)
# 307 0 308.0
# 307 1 40.318213
# 307 2 -104.818666
# 307 3 2011-12-29
# 307 4 Swainsons Hawk
# 307 5 INACTIVE NEST
# 307 6 308
# 307 7 POINT (-104.79386 40.31468)
# 308 0 309.0
# 308 1 40.152794
# 308 2 -104.80164
# 308 3 2011-12-29
# 308 4 Red-tail Hawk
# 308 5 ACTIVE NEST
# 308 6 309
# 308 7 POINT (-104.77532 40.19692)
# 309 0 310.0
# 309 1 40.100899
# 309 2 -104.783573
# 309 3 2015-06-02
# 309 4 Swainsons Hawk
# 309 5 ACTIVE NEST
# 309 6 310
# 309 7 POINT (-104.79807 40.09809)
# 310 0 311.0
# 310 1 40.102859
# 310 2 -104.77759
# 310 3 2012-01-09
# 310 4 Swainsons Hawk
# 310 5 INACTIVE NEST
# 310 6 311
# 310 7 POINT (-104.82053 40.14107)
# 311 0 312.0
# 311 1 40.091474
# 311 2 -104.762668
# 311 3 2012-01-09
# 311 4 Swainsons Hawk
# 311 5 INACTIVE NEST
# 311 6 312
# 311 7 POINT (-104.73218 40.13379)
# 312 0 313.0
# 312 1 40.099226
# 312 2 -104.760892
# 312 3 2012-01-09
# 312 4 Swainsons Hawk
# 312 5 INACTIVE NEST
# 312 6 313
# 312 7 POINT (-104.70071 40.05732)
# 313 0 314.0
# 313 1 40.134344
# 313 2 -104.631084
# 313 3 2012-01-09
# 313 4 Swainsons Hawk
# 313 5 INACTIVE NEST
# 313 6 314
# 313 7 POINT (-104.56255 40.10769)
# 314 0 315.0
# 314 1 40.210835
# 314 2 -104.588448
# 314 3 2012-01-09
# 314 4 Red-tail Hawk
# 314 5 ACTIVE NEST
# 314 6 315
# 314 7 POINT (-104.66642 40.19258)
# 315 0 316.0
# 315 1 40.076373
# 315 2 -104.774093
# 315 3 2012-01-25
# 315 4 Red-tail Hawk
# 315 5 INACTIVE NEST
# 315 6 316
# 315 7 POINT (-104.68533 40.06504)
# 316 0 317.0
# 316 1 40.075321
# 316 2 -104.775908
# 316 3 2014-08-12
# 316 4 Red-tail Hawk
# 316 5 ACTIVE NEST
# 316 6 317
# 316 7 POINT (-104.76088 40.02459)
# 317 0 318.0
# 317 1 40.147013
# 317 2 -104.652264
# 317 3 2015-08-05
# 317 4 Swainsons Hawk
# 317 5 ACTIVE NEST
# 317 6 318
# 317 7 POINT (-104.55929 40.07828)
# 318 0 319.0
# 318 1 40.358378
# 318 2 -104.632159
# 318 3 2012-01-25
# 318 4 Swainsons Hawk
# 318 5 ACTIVE NEST
# 318 6 319
# 318 7 POINT (-104.5922 40.30088)
# 319 0 320.0
# 319 1 40.353379
# 319 2 -104.639655
# 319 3 2012-01-25
# 319 4 Swainsons Hawk
# 319 5 ACTIVE NEST
# 319 6 320
# 319 7 POINT (-104.54761 40.40162)
# 320 0 321.0
# 320 1 40.255879
# 320 2 -104.629572
# 320 3 2012-01-25
# 320 4 Red-tail Hawk
# 320 5 ACTIVE NEST
# 320 6 321
# 320 7 POINT (-104.66833 40.23653)
# 321 0 322.0
# 321 1 40.211309
# 321 2 -104.64166
# 321 3 2012-01-25
# 321 4 Red-tail Hawk
# 321 5 ACTIVE NEST
# 321 6 322
# 321 7 POINT (-104.55826 40.26254)
# 322 0 323.0
# 322 1 40.203439
# 322 2 -104.616571
# 322 3 2014-08-11
# 322 4 Swainsons Hawk
# 322 5 ACTIVE NEST
# 322 6 323
# 322 7 POINT (-104.70008 40.21558)
# 323 0 324.0
# 323 1 40.344228
# 323 2 -104.878427
# 323 3 2012-02-02
# 323 4 Swainsons Hawk
# 323 5 ACTIVE NEST
# 323 6 324
# 323 7 POINT (-104.86709 40.4066)
# 324 0 325.0
# 324 1 40.155485
# 324 2 -104.62063
# 324 3 2012-02-02
# 324 4 Red-tail Hawk
# 324 5 FLEDGED NEST
# 324 6 325
# 324 7 POINT (-104.61962 40.17535)
# 325 0 326.0
# 325 1 40.313547
# 325 2 -104.93944
# 325 3 2012-02-02
# 325 4 Red-tail Hawk
# 325 5 INACTIVE NEST
# 325 6 326
# 325 7 POINT (-104.92065 40.30481)
# 326 0 327.0
# 326 1 40.3144
# 326 2 -104.943768
# 326 3 2012-02-02
# 326 4 Red-tail Hawk
# 326 5 ACTIVE NEST
# 326 6 327
# 326 7 POINT (-104.86216 40.35976)
# 327 0 328.0
# 327 1 40.315032
# 327 2 -104.944199
# 327 3 2012-02-02
# 327 4 Red-tail Hawk
# 327 5 INACTIVE NEST
# 327 6 328
# 327 7 POINT (-105.02432 40.29233)
# 328 0 329.0
# 328 1 40.085519
# 328 2 -104.82367
# 328 3 2012-02-02
# 328 4 Swainsons Hawk
# 328 5 INACTIVE NEST
# 328 6 329
# 328 7 POINT (-104.73028 40.03769)
# 329 0 330.0
# 329 1 40.188799
# 329 2 -104.789955
# 329 3 2012-01-26
# 329 4 Red-tail Hawk
# 329 5 INACTIVE NEST
# 329 6 330
# 329 7 POINT (-104.78475 40.16966)
# 330 0 331.0
# 330 1 40.152506
# 330 2 -104.885623
# 330 3 2015-06-15
# 330 4 Red-tail Hawk
# 330 5 ACTIVE NEST
# 330 6 331
# 330 7 POINT (-104.92411 40.10052)
# 331 0 332.0
# 331 1 39.985402
# 331 2 -104.958097
# 331 3 2012-02-22
# 331 4 Red-tail Hawk
# 331 5 INACTIVE NEST
# 331 6 332
# 331 7 POINT (-104.93576 39.99537)
# 332 0 333.0
# 332 1 40.277929
# 332 2 -104.791153
# 332 3 2012-02-15
# 332 4 Swainsons Hawk
# 332 5 ACTIVE NEST
# 332 6 333
# 332 7 POINT (-104.83958 40.2346)
# 333 0 334.0
# 333 1 40.029277
# 333 2 -104.93009
# 333 3 2012-02-21
# 333 4 Red-tail Hawk
# 333 5 ACTIVE NEST
# 333 6 334
# 333 7 POINT (-104.89702 40.09847)
# 334 0 335.0
# 334 1 40.119698
# 334 2 -104.857566
# 334 3 2014-06-27
# 334 4 Swainsons Hawk
# 334 5 FLEDGED NEST
# 334 6 335
# 334 7 POINT (-104.83398 40.14198)
# 335 0 336.0
# 335 1 40.153101
# 335 2 -104.859217
# 335 3 2012-02-20
# 335 4 Swainsons Hawk
# 335 5 INACTIVE NEST
# 335 6 336
# ...
# 753 0 806.0
# 753 1 40.049147
# 753 2 -105.151991
# 753 3 2014-12-10
# 753 4 Red-tail Hawk
# 753 5 INACTIVE NEST
# 753 6 806
# 753 7 POINT (-105.08132 40.04744)
# 754 0 807.0
# 754 1 40.049775
# 754 2 -105.142429
# 754 3 2014-12-10
# 754 4 Swainsons Hawk
# 754 5 INACTIVE NEST
# 754 6 807
# 754 7 POINT (-105.10034 40.08901)
# 755 0 808.0
# 755 1 40.463831
# 755 2 -105.003302
# 755 3 2014-12-11
# 755 4 Red-tail Hawk
# 755 5 ACTIVE NEST
# 755 6 808
# 755 7 POINT (-104.92557 40.39469)
# 756 0 809.0
# 756 1 40.444
# 756 2 -105.022215
# 756 3 2014-12-11
# 756 4 Red-tail Hawk
# 756 5 FLEDGED NEST
# 756 6 809
# 756 7 POINT (-105.06452 40.40328)
# 757 0 810.0
# 757 1 40.46002
# 757 2 -105.098326
# 757 3 2014-12-11
# 757 4 Red-tail Hawk
# 757 5 INACTIVE NEST
# 757 6 810
# 757 7 POINT (-105.13229 40.43462)
# 758 0 811.0
# 758 1 40.460025
# 758 2 -105.098227
# 758 3 2014-12-11
# 758 4 Swainsons Hawk
# 758 5 FLEDGED NEST
# 758 6 811
# 758 7 POINT (-105.12911 40.47413)
# 759 0 812.0
# 759 1 40.455833
# 759 2 -105.093921
# 759 3 2014-12-11
# 759 4 Red-tail Hawk
# 759 5 INACTIVE NEST
# 759 6 812
# 759 7 POINT (-105.00742 40.41882)
# 760 0 813.0
# 760 1 40.453353
# 760 2 -105.097946
# 760 3 2014-12-11
# 760 4 Red-tail Hawk
# 760 5 INACTIVE NEST
# 760 6 813
# 760 7 POINT (-105.04713 40.48931)
# 761 0 814.0
# 761 1 40.087748
# 761 2 -104.429377
# 761 3 2015-01-06
# 761 4 Red-tail Hawk
# 761 5 INACTIVE NEST
# 761 6 814
# 761 7 POINT (-104.33836 40.13707)
# 762 0 815.0
# 762 1 40.087544
# 762 2 -104.511662
# 762 3 2015-01-08
# 762 4 Red-tail Hawk
# 762 5 INACTIVE NEST
# 762 6 815
# 762 7 POINT (-104.47385 40.14823)
# 763 0 816.0
# 763 1 40.086033
# 763 2 -104.527106
# 763 3 2015-01-08
# 763 4 Swainsons Hawk
# 763 5 INACTIVE NEST
# 763 6 816
# 763 7 POINT (-104.43836 40.10827)
# 764 0 817.0
# 764 1 40.348578
# 764 2 -104.436659
# 764 3 2015-01-14
# 764 4 Swainsons Hawk
# 764 5 INACTIVE NEST
# 764 6 817
# 764 7 POINT (-104.52794 40.38915)
# 765 0 818.0
# 765 1 40.208017
# 765 2 -104.615486
# 765 3 2015-01-16
# 765 4 Red-tail Hawk
# 765 5 INACTIVE NEST
# 765 6 818
# 765 7 POINT (-104.53505 40.23331)
# 766 0 819.0
# 766 1 40.211279
# 766 2 -104.61651
# 766 3 2015-01-16
# 766 4 Red-tail Hawk
# 766 5 INACTIVE NEST
# 766 6 819
# 766 7 POINT (-104.70512 40.20257)
# 767 0 820.0
# 767 1 40.188471
# 767 2 -104.617944
# 767 3 2015-01-16
# 767 4 Red-tail Hawk
# 767 5 FLEDGED NEST
# 767 6 820
# 767 7 POINT (-104.61153 40.22997)
# 768 0 821.0
# 768 1 40.356013
# 768 2 -104.436612
# 768 3 2015-01-19
# 768 4 Swainsons Hawk
# 768 5 FLEDGED NEST
# 768 6 821
# 768 7 POINT (-104.47879 40.38681)
# 769 0 822.0
# 769 1 40.350028
# 769 2 -104.418768
# 769 3 2015-03-31
# 769 4 Red-tail Hawk
# 769 5 FLEDGED NEST
# 769 6 822
# 769 7 POINT (-104.4959 40.29888)
# 770 0 823.0
# 770 1 40.114163
# 770 2 -104.895532
# 770 3 2015-01-21
# 770 4 Red-tail Hawk
# 770 5 INACTIVE NEST
# 770 6 823
# 770 7 POINT (-104.82137 40.1437)
# 771 0 824.0
# 771 1 40.1142
# 771 2 -104.895566
# 771 3 2015-01-21
# 771 4 Swainsons Hawk
# 771 5 INACTIVE NEST
# 771 6 824
# 771 7 POINT (-104.83308 40.10721)
# 772 0 825.0
# 772 1 40.114079
# 772 2 -104.894287
# 772 3 2015-01-21
# 772 4 Red-tail Hawk
# 772 5 ACTIVE NEST
# 772 6 825
# 772 7 POINT (-104.85768 40.13616)
# 773 0 826.0
# 773 1 40.098223
# 773 2 -104.788769
# 773 3 2015-06-23
# 773 4 Swainsons Hawk
# 773 5 FLEDGED NEST
# 773 6 826
# 773 7 POINT (-104.79081 40.0633)
# 774 0 827.0
# 774 1 40.030208
# 774 2 -104.858155
# 774 3 2015-01-28
# 774 4 Red-tail Hawk
# 774 5 ACTIVE NEST
# 774 6 827
# 774 7 POINT (-104.8655 40.07496)
# 775 0 828.0
# 775 1 40.045998
# 775 2 -104.864894
# 775 3 2015-01-28
# 775 4 Swainsons Hawk
# 775 5 INACTIVE NEST
# 775 6 828
# 775 7 POINT (-104.84975 40.04016)
# 776 0 829.0
# 776 1 40.046556
# 776 2 -104.863907
# 776 3 2015-01-28
# 776 4 Red-tail Hawk
# 776 5 INACTIVE NEST
# 776 6 829
# 776 7 POINT (-104.91933 39.9874)
# 777 0 830.0
# 777 1 40.041525
# 777 2 -104.855916
# 777 3 2015-01-28
# 777 4 Red-tail Hawk
# 777 5 ACTIVE NEST
# 777 6 830
# 777 7 POINT (-104.87996 40.03639)
# 778 0 831.0
# 778 1 40.056349
# 778 2 -104.706309
# 778 3 2015-02-06
# 778 4 Swainsons Hawk
# 778 5 INACTIVE NEST
# 778 6 831
# 778 7 POINT (-104.68996 40.06282)
# 779 0 832.0
# 779 1 40.057262
# 779 2 -104.708569
# 779 3 2015-03-16
# 779 4 Red-tail Hawk
# 779 5 FLEDGED NEST
# 779 6 832
# 779 7 POINT (-104.72566 40.12896)
# 780 0 833.0
# 780 1 40.057288
# 780 2 -104.708716
# 780 3 2015-03-16
# 780 4 Swainsons Hawk
# 780 5 ACTIVE NEST
# 780 6 833
# 780 7 POINT (-104.72688 40.04253)
# 781 0 834.0
# 781 1 40.057181
# 781 2 -104.708974
# 781 3 2015-03-16
# 781 4 Swainsons Hawk
# 781 5 INACTIVE NEST
# 781 6 834
# 781 7 POINT (-104.65004 40.02827)
# 782 0 835.0
# 782 1 40.211366
# 782 2 -104.911597
# 782 3 2015-02-09
# 782 4 Red-tail Hawk
# 782 5 FLEDGED NEST
# 782 6 835
# 782 7 POINT (-104.91519 40.23761)
# 783 0 836.0
# 783 1 40.211286
# 783 2 -104.911633
# 783 3 2015-02-09
# 783 4 Swainsons Hawk
# 783 5 INACTIVE NEST
# 783 6 836
# 783 7 POINT (-104.82068 40.14375)
# 784 0 837.0
# 784 1 40.032407
# 784 2 -104.66334
# 784 3 2015-02-09
# 784 4 Red-tail Hawk
# 784 5 INACTIVE NEST
# 784 6 837
# 784 7 POINT (-104.67659 40.06729)
# 785 0 838.0
# 785 1 40.057069
# 785 2 -104.820346
# 785 3 2015-02-12
# 785 4 Swainsons Hawk
# 785 5 INACTIVE NEST
# 785 6 838
# 785 7 POINT (-104.90945 40.06279)
# 786 0 839.0
# 786 1 40.057304
# 786 2 -104.821032
# 786 3 2015-02-12
# 786 4 Swainsons Hawk
# 786 5 INACTIVE NEST
# 786 6 839
# 786 7 POINT (-104.84752 40.11711)
# 787 0 840.0
# 787 1 40.139296
# 787 2 -104.993893
# 787 3 2015-02-18
# 787 4 Red-tail Hawk
# 787 5 INACTIVE NEST
# 787 6 840
# 787 7 POINT (-104.93848 40.16313)
# 788 0 841.0
# 788 1 40.151933
# 788 2 -104.980898
# 788 3 2015-02-20
# 788 4 Swainsons Hawk
# 788 5 INACTIVE NEST
# 788 6 841
# 788 7 POINT (-104.99521 40.11863)
# 789 0 842.0
# 789 1 40.014175
# 789 2 -105.126386
# 789 3 2015-02-20
# 789 4 Swainsons Hawk
# 789 5 FLEDGED NEST
# 789 6 842
# 789 7 POINT (-105.17925 40.0679)
# 790 0 843.0
# 790 1 40.007517
# 790 2 -105.119596
# 790 3 2015-02-20
# 790 4 Red-tail Hawk
# 790 5 INACTIVE NEST
# 790 6 843
# 790 7 POINT (-105.13401 39.93887)
# 791 0 844.0
# 791 1 40.014859
# 791 2 -105.11541
# 791 3 2015-02-20
# 791 4 Red-tail Hawk
# 791 5 INACTIVE NEST
# 791 6 844
# 791 7 POINT (-105.20091 40.03907)
# 792 0 845.0
# 792 1 40.010111
# 792 2 -105.121219
# 792 3 2015-02-20
# 792 4 Red-tail Hawk
# 792 5 FLEDGED NEST
# 792 6 845
# 792 7 POINT (-105.08961 39.98107)
# 793 0 846.0
# 793 1 40.009698
# 793 2 -105.113618
# 793 3 2015-02-20
# 793 4 Swainsons Hawk
# 793 5 INACTIVE NEST
# 793 6 846
# 793 7 POINT (-105.09268 39.94469)
# 794 0 847.0
# 794 1 40.055237
# 794 2 -104.986777
# 794 3 2015-02-24
# 794 4 Swainsons Hawk
# 794 5 FLEDGED NEST
# 794 6 847
# 794 7 POINT (-105.01906 40.00125)
# 795 0 848.0
# 795 1 40.140663
# 795 2 -104.676056
# 795 3 2015-03-19
# 795 4 Red-tail Hawk
# 795 5 INACTIVE NEST
# 795 6 848
# 795 7 POINT (-104.7536 40.20598)
# 796 0 849.0
# 796 1 40.125167
# 796 2 -104.669795
# 796 3 2015-07-09
# 796 4 Swainsons Hawk
# 796 5 FLEDGED NEST
# 796 6 849
# 796 7 POINT (-104.6928 40.13614)
# 797 0 851.0
# 797 1 40.145773
# 797 2 -104.841214
# 797 3 2015-06-12
# 797 4 Red-tail Hawk
# 797 5 FLEDGED NEST
# 797 6 851
# 797 7 POINT (-104.90825 40.17937)
# 798 0 852.0
# 798 1 40.144499
# 798 2 -104.839908
# 798 3 2015-06-12
# 798 4 Red-tail Hawk
# 798 5 INACTIVE NEST
# 798 6 852
# 798 7 POINT (-104.76546 40.15663)
# 799 0 853.0
# 799 1 40.145211
# 799 2 -104.83618
# 799 3 2015-03-13
# 799 4 Red-tail Hawk
# 799 5 INACTIVE NEST
# 799 6 853
# 799 7 POINT (-104.89834 40.11963)
# 800 0 854.0
# 800 1 40.139674
# 800 2 -104.836056
# 800 3 2015-03-13
# 800 4 Swainsons Hawk
# 800 5 ACTIVE NEST
# 800 6 854
# 800 7 POINT (-104.88898 40.12566)
# 801 0 855.0
# 801 1 40.131117
# 801 2 -104.745545
# 801 3 2015-03-16
# 801 4 Swainsons Hawk
# 801 5 ACTIVE NEST
# 801 6 855
# 801 7 POINT (-104.68922 40.09929)
# 802 0 856.0
# 802 1 40.211016
# 802 2 -104.599269
# 802 3 2015-05-22
# 802 4 Swainsons Hawk
# 802 5 COULD NOT SEE NEST
# 802 6 856
# 802 7 POINT (-104.55478 40.14262)
# 803 0 857.0
# 803 1 40.498638
# 803 2 -105.10217
# 803 3 2015-03-18
# 803 4 Red-tail Hawk
# 803 5 ACTIVE NEST
# 803 6 857
# 803 7 POINT (-105.07142 40.54964)
# 804 0 858.0
# 804 1 40.416655
# 804 2 -105.129483
# 804 3 2015-03-18
# 804 4 Swainsons Hawk
# 804 5 FLEDGED NEST
# 804 6 858
# 804 7 POINT (-105.14924 40.46454)
# 805 0 859.0
# 805 1 40.058621
# 805 2 -104.62285
# 805 3 2015-04-16
# 805 4 Red-tail Hawk
# 805 5 FLEDGED NEST
# 805 6 859
# 805 7 POINT (-104.68596 40.07383)
# 806 0 860.0
# 806 1 40.058602
# 806 2 -104.612157
# 806 3 2015-03-19
# 806 4 Red-tail Hawk
# 806 5 ACTIVE NEST
# 806 6 860
# 806 7 POINT (-104.60278 40.08161)
# 807 0 861.0
# 807 1 40.163707
# 807 2 -104.703622
# 807 3 2015-03-23
# 807 4 Red-tail Hawk
# 807 5 INACTIVE NEST
# 807 6 861
# 807 7 POINT (-104.63891 40.12857)
# 808 0 862.0
# 808 1 40.167149
# 808 2 -104.701369
# 808 3 2015-03-23
# 808 4 Red-tail Hawk
# 808 5 ACTIVE NEST
# 808 6 862
# 808 7 POINT (-104.73128 40.19092)
# 809 0 863.0
# 809 1 40.167166
# 809 2 -104.700325
# 809 3 2015-03-23
# 809 4 Red-tail Hawk
# 809 5 INACTIVE NEST
# 809 6 863
# 809 7 POINT (-104.74839 40.18424)
# 810 0 864.0
# 810 1 40.218405
# 810 2 -104.980569
# 810 3 2015-07-27
# 810 4 Red-tail Hawk
# 810 5 FLEDGED NEST
# 810 6 864
# 810 7 POINT (-105.06553 40.17014)
# 811 0 865.0
# 811 1 40.192682
# 811 2 -104.880386
# 811 3 2015-06-03
# 811 4 Red-tail Hawk
# 811 5 ACTIVE NEST
# 811 6 865
# 811 7 POINT (-104.95442 40.14821)
# 812 0 866.0
# 812 1 40.153187
# 812 2 -104.8346
# 812 3 2015-05-13
# 812 4 Swainsons Hawk
# 812 5 ACTIVE NEST
# 812 6 866
# 812 7 POINT (-104.83995 40.13489)
# 813 0 867.0
# 813 1 40.154771
# 813 2 -104.832801
# 813 3 2015-05-13
# 813 4 Red-tail Hawk
# 813 5 ACTIVE NEST
# 813 6 867
# 813 7 POINT (-104.80713 40.19204)
# 814 0 868.0
# 814 1 40.159337
# 814 2 -104.730777
# 814 3 2015-06-02
# 814 4 Red-tail Hawk
# 814 5 INACTIVE NEST
# 814 6 868
# 814 7 POINT (-104.79555 40.08931)
# 815 0 869.0
# 815 1 40.128012
# 815 2 -104.675725
# 815 3 2015-04-29
# 815 4 Swainsons Hawk
# 815 5 INACTIVE NEST
# 815 6 869
# 815 7 POINT (-104.67358 40.16967)
# 816 0 870.0
# 816 1 40.12105
# 816 2 -104.678276
# 816 3 2015-04-29
# 816 4 Red-tail Hawk
# 816 5 ACTIVE NEST
# 816 6 870
# 816 7 POINT (-104.65542 40.12024)
# 817 0 871.0
# 817 1 40.132081
# 817 2 -104.676521
# 817 3 2015-04-29
# 817 4 Swainsons Hawk
# 817 5 ACTIVE NEST
# 817 6 871
# 817 7 POINT (-104.68749 40.1987)
# 818 0 872.0
# 818 1 40.135098
# 818 2 -104.970502
# 818 3 2015-07-29
# 818 4 Swainsons Hawk
# 818 5 FLEDGED NEST
# 818 6 872
# 818 7 POINT (-105.04937 40.13417)
# 819 0 873.0
# 819 1 40.142579
# 819 2 -104.975146
# 819 3 2015-07-29
# 819 4 Swainsons Hawk
# 819 5 ACTIVE NEST
# 819 6 873
# 819 7 POINT (-105.06517 40.1029)
# 820 0 874.0
# 820 1 40.118346
# 820 2 -104.993852
# 820 3 2015-07-29
# 820 4 Swainsons Hawk
# 820 5 ACTIVE NEST
# 820 6 874
# 820 7 POINT (-104.99311 40.14737)
# 821 0 875.0
# 821 1 40.10994
# 821 2 -104.983845
# 821 3 2015-07-29
# 821 4 Swainsons Hawk
# 821 5 INACTIVE NEST
# 821 6 875
# 821 7 POINT (-104.93318 40.10669)
# 822 0 876.0
# 822 1 40.110156
# 822 2 -104.983312
# 822 3 2015-07-29
# 822 4 Red-tail Hawk
# 822 5 FLEDGED NEST
# 822 6 876
# 822 7 POINT (-104.90706 40.04251)
# 823 0 877.0
# 823 1 40.064131
# 823 2 -104.670375
# 823 3 2015-07-29
# 823 4 Swainsons Hawk
# 823 5 INACTIVE NEST
# 823 6 877
# 823 7 POINT (-104.72305 40.06901)
# 824 0 878.0
# 824 1 40.073284
# 824 2 -104.682972
# 824 3 2015-07-29
# 824 4 Red-tail Hawk
# 824 5 INACTIVE NEST
# 824 6 878
# 824 7 POINT (-104.59907 40.07846)
# 825 0 879.0
# 825 1 40.08895
# 825 2 -104.896209
# 825 3 2015-08-11
# 825 4 Red-tail Hawk
# 825 5 FLEDGED NEST
# 825 6 879
# 825 7 POINT (-104.86851 40.11922)
# 826 0 880.0
# 826 1 40.074107
# 826 2 -104.688067
# 826 3 2015-07-09
# 826 4 Red-tail Hawk
# 826 5 INACTIVE NEST
# 826 6 880
# 826 7 POINT (-104.75285 40.00713)
# 827 0 881.0
# 827 1 40.162751
# 827 2 -104.73058
# 827 3 2015-05-28
# 827 4 Swainsons Hawk
# 827 5 ACTIVE NEST
# 827 6 881
# 827 7 POINT (-104.69085 40.09987)
# 828 0 882.0
# 828 1 40.04562
# 828 2 -104.908517
# 828 3 2015-05-22
# 828 4 Red-tail Hawk
# 828 5 ACTIVE NEST
# 828 6 882
# 828 7 POINT (-104.9876 40.0091)
# 829 0 883.0
# 829 1 40.1099
# 829 2 -104.879429
# 829 3 2015-08-14
# 829 4 Red-tail Hawk
# 829 5 FLEDGED NEST
# 829 6 883
# 829 7 POINT (-104.88351 40.06975)
# 830 0 884.0
# 830 1 40.068421
# 830 2 -104.862728
# 830 3 2015-06-03
# 830 4 Red-tail Hawk
# 830 5 ACTIVE NEST
# 830 6 884
# 830 7 POINT (-104.91311 40.00704)
# 831 0 885.0
# 831 1 40.189083
# 831 2 -104.865355
# 831 3 2015-06-05
# 831 4 Red-tail Hawk
# 831 5 ACTIVE NEST
# 831 6 885
# 831 7 POINT (-104.92905 40.24316)
# 832 0 886.0
# 832 1 39.988339
# 832 2 -105.067373
# 832 3 2015-06-11
# 832 4 Swainsons Hawk
# 832 5 ACTIVE NEST
# 832 6 886
# 832 7 POINT (-105.15664 39.92748)
# 833 0 887.0
# 833 1 39.986753
# 833 2 -105.067144
# 833 3 2015-06-11
# 833 4 Swainsons Hawk
# 833 5 INACTIVE NEST
# 833 6 887
# 833 7 POINT (-105.0972 39.99392)
# 834 0 888.0
# 834 1 39.986721
# 834 2 -105.066816
# 834 3 2015-06-11
# 834 4 Red-tail Hawk
# 834 5 INACTIVE NEST
# 834 6 888
# 834 7 POINT (-105.02362 39.99817)
# 835 0 889.0
# 835 1 39.986176
# 835 2 -105.065648
# 835 3 2015-06-11
# 835 4 Red-tail Hawk
# 835 5 INACTIVE NEST
# 835 6 889
# 835 7 POINT (-105.08037 40.03062)
# 836 0 890.0
# 836 1 40.130182
# 836 2 -104.654085
# 836 3 2015-07-28
# 836 4 Swainsons Hawk
# 836 5 INACTIVE NEST
# 836 6 890
# 836 7 POINT (-104.71035 40.13155)
# 837 0 891.0
# 837 1 39.953605
# 837 2 -104.845677
# 837 3 2015-08-24
# 837 4 Red-tail Hawk
# 837 5 FLEDGED NEST
# 837 6 891
# 837 7 POINT (-104.89861 39.99438)
# 838 0 892.0
# 838 1 39.947835
# 838 2 -104.847082
# 838 3 2015-08-04
# 838 4 Swainsons Hawk
# 838 5 INACTIVE NEST
# 838 6 892
# 838 7 POINT (-104.78362 39.93726)
# 839 0 893.0
# 839 1 40.15454
# 839 2 -104.841188
# 839 3 2015-07-30
# 839 4 Red-tail Hawk
# 839 5 INACTIVE NEST
# 839 6 893
# 839 7 POINT (-104.84911 40.09943)
# 840 0 894.0
# 840 1 40.154797
# 840 2 -104.841198
# 840 3 2015-07-30
# 840 4 Red-tail Hawk
# 840 5 INACTIVE NEST
# 840 6 894
# 840 7 POINT (-104.77056 40.22599)
# 841 0 895.0
# 841 1 40.204491
# 841 2 -104.662237
# 841 3 2015-08-05
# 841 4 Swainsons Hawk
# 841 5 INACTIVE NEST
# 841 6 895
# 841 7 POINT (-104.64539 40.14265)
# 842 0 896.0
# 842 1 39.975339
# 842 2 -104.94509
# 842 3 2015-07-27
# 842 4 Swainsons Hawk
# 842 5 FLEDGED NEST
# 842 6 896
# 842 7 POINT (-104.92662 39.96089)
# 843 0 897.0
# 843 1 40.417061
# 843 2 -104.800156
# 843 3 2015-07-07
# 843 4 Red-tail Hawk
# 843 5 ACTIVE NEST
# 843 6 897
# 843 7 POINT (-104.72328 40.47858)
# 844 0 898.0
# 844 1 40.188867
# 844 2 -105.005624
# 844 3 2015-07-10
# 844 4 Red-tail Hawk
# 844 5 INACTIVE NEST
# 844 6 898
# 844 7 POINT (-104.94558 40.23595)
# 845 0 899.0
# 845 1 40.187254
# 845 2 -105.005608
# 845 3 2015-07-10
# 845 4 Swainsons Hawk
# 845 5 INACTIVE NEST
# 845 6 899
# 845 7 POINT (-104.97637 40.14121)
# 846 0 900.0
# 846 1 40.169258
# 846 2 -104.889567
# 846 3 2015-07-13
# 846 4 Swainsons Hawk
# 846 5 INACTIVE NEST
# 846 6 900
# 846 7 POINT (-104.90353 40.2323)
# 847 0 901.0
# 847 1 40.04328
# 847 2 -105.017857
# 847 3 2015-08-04
# 847 4 Red-tail Hawk
# 847 5 INACTIVE NEST
# 847 6 901
# 847 7 POINT (-104.94253 40.03679)
# 848 0 902.0
# 848 1 40.04519
# 848 2 -104.727397
# 848 3 2015-08-14
# 848 4 Swainsons Hawk
# 848 5 INACTIVE NEST
# 848 6 902
# 848 7 POINT (-104.63442 40.00987)
# 849 0 903.0
# 849 1 40.04469
# 849 2 -104.726963
# 849 3 2015-08-14
# 849 4 Red-tail Hawk
# 849 5 INACTIVE NEST
# 849 6 903
# 849 7 POINT (-104.72082 40.03216)
# 850 0 904.0
# 850 1 40.044586
# 850 2 -104.727664
# 850 3 2015-08-14
# 850 4 Red-tail Hawk
# 850 5 INACTIVE NEST
# 850 6 904
# 850 7 POINT (-104.78274 40.08121)
# 851 0 905.0
# 851 1 40.056013
# 851 2 -104.761654
# 851 3 2015-08-17
# 851 4 Red-tail Hawk
# 851 5 INACTIVE NEST
# 851 6 905
# 851 7 POINT (-104.83105 40.06771)
# 852 0 906.0
# 852 1 40.051193
# 852 2 -104.794308
# 852 3 2015-08-17
# 852 4 Red-tail Hawk
# 852 5 INACTIVE NEST
# 852 6 906
# 852 7 POINT (-104.76127 40.07742)
# 853 0 907.0
# 853 1 39.995541
# 853 2 -104.891149
# 853 3 2015-08-18
# 853 4 Red-tail Hawk
# 853 5 INACTIVE NEST
# 853 6 907
# 853 7 POINT (-104.81692 40.02965)
# 854 0 908.0
# 854 1 39.996516
# 854 2 -104.891649
# 854 3 2015-08-18
# 854 4 Red-tail Hawk
# 854 5 INACTIVE NEST
# 854 6 908
# 854 7 POINT (-104.93254 40.03877)
# 855 0 909.0
# 855 1 39.999138
# 855 2 -104.899116
# 855 3 2015-08-18
# 855 4 Swainsons Hawk
# 855 5 INACTIVE NEST
# 855 6 909
# 855 7 POINT (-104.91958 40.00116)
# 856 0 910.0
# 856 1 40.002516
# 856 2 -104.893713
# 856 3 2015-08-18
# 856 4 Red-tail Hawk
# 856 5 INACTIVE NEST
# 856 6 910
# 856 7 POINT (-104.83619 39.98674)
# 857 0 911.0
# 857 1 40.00695
# 857 2 -104.89437
# 857 3 2015-08-18
# 857 4 Red-tail Hawk
# 857 5 INACTIVE NEST
# 857 6 911
# 857 7 POINT (-104.98394 40.00297)
# 858 0 912.0
# 858 1 39.998876
# 858 2 -104.900128
# 858 3 2015-09-01
# 858 4 Red-tail Hawk
# 858 5 INACTIVE NEST
# 858 6 912
# 858 7 POINT (-104.84766 39.96975)
# 859 0 nan
# 859 1 nan
# 859 2 nan
# 859 3 2020-05-08
# 859 4 Northern Harrier
# 859 5 INACTIVE NEST
# 859 6 9991
# 859 7 POINT (-104.95039158280412 40.24431700148285)
# 860 0 nan
# 860 1 nan
# 860 2 nan
# 860 3 2020-05-05
# 860 4 SWHA
# 860 5 INACTIVE NEST
# 860 6 1001
# 860 7 POINT (-104.94501532785657 40.24442591598638)
# 861 0 nan
# 861 1 40.24386520326873
# 861 2 -104.9371695362882
# 861 3 None
# 861 4 RTHA
# 861 5 FLEDGED NEST
# 861 6 1002
# 861 7 POINT (-104.9371695362882 40.24386520326873)

# %%
raptors.iat[200, 4]
# Out:
# 'Red-tail Hawk'

# %%
raptors['recentspec'].unique()
# Out:
# array(['Swainsons Hawk', 'Red-tail Hawk', 'Northern Harrier', 'SWHA',
#        'RTHA'], dtype=object)

# %%
raptors.iat[200,4] = "Great Blue Heron"
raptors.iat[200,4]
# Out:
# 'Great Blue Heron'

# %%
raptors['recentspec'].unique()
# Out:
# array(['Swainsons Hawk', 'Red-tail Hawk', 'Great Blue Heron',
#        'Northern Harrier', 'SWHA', 'RTHA'], dtype=object)

# %% [markdown]
# ## Series Math

# %%
raptors['long_x_dd']/raptors['lat_y_dd']
# Out:
# 0     -2.604355
# 1     -2.604297
# 3     -2.603168
# 4     -2.603952
# 5     -2.605309
#          ...
# 874   -2.621904
# 875   -2.622577
# 876         NaN
# 877         NaN
# 878   -2.607532
# Length: 862, dtype: float64

# %% [markdown]
# ### Creating a new column

# %%
raptors['long_plus_lat'] = raptors['long_x_dd']+raptors['lat_y_dd']

# %%
raptors
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16    Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16    Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06    Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03    Swainsons Hawk
# 5           4.0  40.217638 -104.779386  2011-01-06     Red-tail Hawk
# ..          ...        ...         ...         ...               ...
# 874       911.0  40.006950 -104.894370  2015-08-18     Red-tail Hawk
# 875       912.0  39.998876 -104.900128  2015-09-01     Red-tail Hawk
# 876         NaN        NaN         NaN  2020-05-08  Northern Harrier
# 877         NaN        NaN         NaN  2020-05-05              SWHA
# 878         NaN  40.243865 -104.937170        None              RTHA
#
#         recentstat  Nest_ID                     geometry  long_plus_lat
# 0    INACTIVE NEST      361  POINT (-104.79595 40.29891)     -64.603370
# 1    INACTIVE NEST      362  POINT (-104.78897 40.22089)     -64.595934
# 3    INACTIVE NEST        2  POINT (-104.84889 40.35215)     -64.623030
# 4      ACTIVE NEST        3  POINT (-104.74466 40.18571)     -64.509903
# 5     FLEDGED NEST        4  POINT (-104.79963 40.15712)     -64.561748
# ..             ...      ...                          ...            ...
# 874  INACTIVE NEST      911  POINT (-104.98394 40.00297)     -64.887420
# 875  INACTIVE NEST      912  POINT (-104.84766 39.96975)     -64.901252
# 876  INACTIVE NEST     9991  POINT (-104.95039 40.24432)            NaN
# 877  INACTIVE NEST     1001  POINT (-104.94502 40.24443)            NaN
# 878   FLEDGED NEST     1002  POINT (-104.93717 40.24387)     -64.693304
#
# [862 rows x 9 columns]

# %% [markdown]
# ### dropping a row

# %%
raptors
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16    Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16    Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06    Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03    Swainsons Hawk
# 5           4.0  40.217638 -104.779386  2011-01-06     Red-tail Hawk
# ..          ...        ...         ...         ...               ...
# 874       911.0  40.006950 -104.894370  2015-08-18     Red-tail Hawk
# 875       912.0  39.998876 -104.900128  2015-09-01     Red-tail Hawk
# 876         NaN        NaN         NaN  2020-05-08  Northern Harrier
# 877         NaN        NaN         NaN  2020-05-05              SWHA
# 878         NaN  40.243865 -104.937170        None              RTHA
#
#         recentstat  Nest_ID                     geometry  long_plus_lat
# 0    INACTIVE NEST      361  POINT (-104.79595 40.29891)     -64.603370
# 1    INACTIVE NEST      362  POINT (-104.78897 40.22089)     -64.595934
# 3    INACTIVE NEST        2  POINT (-104.84889 40.35215)     -64.623030
# 4      ACTIVE NEST        3  POINT (-104.74466 40.18571)     -64.509903
# 5     FLEDGED NEST        4  POINT (-104.79963 40.15712)     -64.561748
# ..             ...      ...                          ...            ...
# 874  INACTIVE NEST      911  POINT (-104.98394 40.00297)     -64.887420
# 875  INACTIVE NEST      912  POINT (-104.84766 39.96975)     -64.901252
# 876  INACTIVE NEST     9991  POINT (-104.95039 40.24432)            NaN
# 877  INACTIVE NEST     1001  POINT (-104.94502 40.24443)            NaN
# 878   FLEDGED NEST     1002  POINT (-104.93717 40.24387)     -64.693304
#
# [862 rows x 9 columns]

# %%
raptors.drop(877, inplace=True)

# %% [markdown]
# ### dropping a column

# %%
raptors.drop('long_plus_lat', axis=1, inplace=True)

# %% [markdown]
# ## Choosing a column to use as an index

# %%
raptors.set_index('Nest_ID', verify_integrity=True, inplace=True)

# %%
raptors.drop(1002, inplace=True)

# %%
raptors
# Out:
#          postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# Nest_ID
# 361           361.0  40.267502 -104.870872  2012-03-16    Swainsons Hawk
# 362           362.0  40.264321 -104.860255  2012-03-16    Swainsons Hawk
# 2               2.0  40.309574 -104.932604  2011-01-06    Swainsons Hawk
# 3               3.0  40.219343 -104.729246  2014-07-03    Swainsons Hawk
# 4               4.0  40.217638 -104.779386  2011-01-06     Red-tail Hawk
# ...             ...        ...         ...         ...               ...
# 909           909.0  39.999138 -104.899116  2015-08-18    Swainsons Hawk
# 910           910.0  40.002516 -104.893713  2015-08-18     Red-tail Hawk
# 911           911.0  40.006950 -104.894370  2015-08-18     Red-tail Hawk
# 912           912.0  39.998876 -104.900128  2015-09-01     Red-tail Hawk
# 9991            NaN        NaN         NaN  2020-05-08  Northern Harrier
#
#             recentstat                     geometry
# Nest_ID
# 361      INACTIVE NEST  POINT (-104.79595 40.29891)
# 362      INACTIVE NEST  POINT (-104.78897 40.22089)
# 2        INACTIVE NEST  POINT (-104.84889 40.35215)
# 3          ACTIVE NEST  POINT (-104.74466 40.18571)
# 4         FLEDGED NEST  POINT (-104.79963 40.15712)
# ...                ...                          ...
# 909      INACTIVE NEST  POINT (-104.91958 40.00116)
# 910      INACTIVE NEST  POINT (-104.83619 39.98674)
# 911      INACTIVE NEST  POINT (-104.98394 40.00297)
# 912      INACTIVE NEST  POINT (-104.84766 39.96975)
# 9991     INACTIVE NEST  POINT (-104.95039 40.24432)
#
# [860 rows x 7 columns]

# %%
raptors.sort_values(['recentspec', 'recentstat', 'lastsurvey'], ascending=[True, True, False])
# Out:
#          postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# Nest_ID
# 199           199.0  40.172293 -104.784592  2011-04-06  Great Blue Heron
# 9991            NaN        NaN         NaN  2020-05-08  Northern Harrier
# 425           425.0  40.145475 -104.650133  2015-08-18     Red-tail Hawk
# 589           589.0  40.204444 -104.659728  2015-08-05     Red-tail Hawk
# 238           238.0  40.130103 -104.655518  2015-07-28     Red-tail Hawk
# ...             ...        ...         ...         ...               ...
# 81             81.0  40.062840 -104.834489  2008-04-25    Swainsons Hawk
# 84             84.0  40.062771 -104.830749  2008-04-25    Swainsons Hawk
# 88             88.0  40.063599 -104.829832  2008-04-25    Swainsons Hawk
# 91             91.0  40.036795 -104.829582  2008-04-25    Swainsons Hawk
# 658           658.0  40.203626 -104.865479  2001-01-01    Swainsons Hawk
#
#             recentstat                     geometry
# Nest_ID
# 199      INACTIVE NEST  POINT (-104.87040 40.13612)
# 9991     INACTIVE NEST  POINT (-104.95039 40.24432)
# 425        ACTIVE NEST  POINT (-104.60960 40.18963)
# 589        ACTIVE NEST  POINT (-104.58424 40.14329)
# 238        ACTIVE NEST  POINT (-104.57469 40.13347)
# ...                ...                          ...
# 81       INACTIVE NEST  POINT (-104.83552 40.10434)
# 84       INACTIVE NEST  POINT (-104.91904 40.09191)
# 88       INACTIVE NEST  POINT (-104.89227 40.04444)
# 91       INACTIVE NEST  POINT (-104.81005 40.09573)
# 658      INACTIVE NEST  POINT (-104.78869 40.26283)
#
# [860 rows x 7 columns]

# %%
# Out:
#   Cell In[50], line 1
#     jupyter nbconvert --to pdf --log-level=DEBUG
#             ^
# SyntaxError: invalid syntax
